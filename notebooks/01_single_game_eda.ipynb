# %% [markdown]
# # 01 - SINGLE-GAME EDA
# - This was the single-game notebook I used to examine the columns, clean data, and create new features before applying the same logic to all games.

# %%
import numpy as np
import pandas as pd

# Column and row display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_seq_items', None)
pd.reset_option('display.max_colwidth')

# Notebook cell width display
from IPython.display import display, HTML
display(HTML("<style>:root { --jp-notebook-max-width: 98% !important; }</style>"))

# Float appearance, Pandas and NumPy
pd.set_option('display.float_format', '{:.0f}'.format)
np.set_printoptions(suppress=True, precision=0)
# Out:
# <style>:root { --jp-notebook-max-width: 98% !important; }</style>

# %% [markdown]
# # DATA IMPORT
# - Let's make a call to the Sportradar API for a single game so that we can get an idea of what the data look like before trying to work with all games in the 2022 season.
# - The game example in this case is 2021's week 3 game featuring the Seattle Seahawks at the Minnesota Vikings.

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api.sportradar.us")

# 2021, Week 3, SEA at MIN
# 7d06369a-382a-448a-b295-6da9eab53245

# 2022, Week 16, BUF at CIN
# 7c0c0abf-f566-4a1f-a482-b74a991e1663

# 2022, Week 1, BUF at LAR
# bf60c8fc-35cd-4749-a29e-4f48d66da57c

# 2022, Week 1, CLE at CAR
# c4a110f2-847b-4710-9a54-7be66fdb3c99
conn.request("GET", "/nfl/official/trial/v7/en/games/7d06369a-382a-448a-b295-6da9eab53245/pbp.json?api_key={replace_with_your_api_key}")

res = conn.getresponse()
data = res.read()

json_data = json.loads(data.decode("utf-8"))

# %% [markdown]
# #### An <u>EXTREMELY</u> complex dataset
# - For the sake of my audience, I won't show `json_data` or even a single entry because the data are all in multiple nestings, making the structure very difficult to interpret.
# - This will require a lot of exploration to understand.

# %% [markdown]
# # DICTIONARY UNNESTING
# ## Game Data

# %%
games = pd.json_normalize(json_data, errors='ignore')

# %% [markdown]
# #### Games --> Periods
# - The resulting dataframe is one row for the single game we're exploring
# - The `periods` column seems to have multiple rows nested within it, so we'll drill into that.
# - Having gone through this game's data before, I know there are some fields with the same name across multiple nestings
#   - I will rename or delete some of these columns.
# - I also know that some of these columns are not relevant to categorizing NFL wide receivers. I will delete these columns. Examples include:
#   - Team records
#   - Season week
#   - Venue information
#   - Timeouts used

# %%
# Delete unnecessary columns
# 'game_type' used for 2022 season, but not 2021?
games = games.drop(columns = ['status', 'scheduled', 'attendance', 'entry_mode', 'clock', 'quarter', 'conference_game', 'duration', 'periods', '_comment', 'weather.wind.direction', 'summary.season.id', 
       'summary.season.name', 'summary.week.id', 'summary.week.title', 'summary.venue.id', 'summary.venue.name', 'summary.venue.city', 'summary.venue.state', 'summary.venue.country',
       'summary.venue.zip', 'summary.venue.address', 'summary.venue.capacity', 'summary.venue.sr_id', 'summary.venue.location.lat', 'summary.venue.location.lng', 'summary.home.id', 'summary.home.name',
       'summary.home.market', 'summary.home.sr_id', 'summary.home.used_timeouts', 'summary.home.remaining_timeouts', 'summary.home.points', 'summary.home.used_challenges',
       'summary.home.remaining_challenges', 'summary.home.record.wins', 'summary.home.record.losses', 'summary.home.record.ties', 'summary.away.id', 'summary.away.name', 'summary.away.market',
       'summary.away.sr_id', 'summary.away.used_timeouts', 'summary.away.remaining_timeouts', 'summary.away.points', 'summary.away.used_challenges', 'summary.away.remaining_challenges', 'summary.away.record.wins', 'summary.away.record.losses', 'summary.away.record.ties'], errors = 'ignore')

# %% [markdown]
# `id` appears in multiple nestings of this dataset, so let's rename it to `game_id` here.

# %%
games = games.rename(columns={"id": "game_id"})

# %%
games.columns
# Out:
# Index(['game_id', 'sr_id', 'weather.condition', 'weather.humidity',
#        'weather.temp', 'weather.wind.speed', 'summary.season.year',
#        'summary.season.type', 'summary.week.sequence', 'summary.venue.surface',
#        'summary.venue.roof_type', 'summary.home.alias', 'summary.away.alias'],
#       dtype='object')

# %%
games.head()
# Out:
#                                 game_id              sr_id  \
# 0  7d06369a-382a-448a-b295-6da9eab53245  sr:match:27305854
#
#     weather.condition  weather.humidity  weather.temp  weather.wind.speed  \
# 0  Controlled Climate                44            77                   7
#
#    summary.season.year summary.season.type  summary.week.sequence  \
# 0                 2021                 REG                      3
#
#   summary.venue.surface summary.venue.roof_type summary.home.alias  \
# 0            artificial                    dome                MIN
#
#   summary.away.alias
# 0                SEA

# %% [markdown]
# ## Period Data
# - After unnesting `periods`, the data break into 4 rows, each one representing a quarter of a game.
#   - If this game had gone to overtime, a new row would be created for the OT period.
#   - The `period_type` value would be 'overtime' and the `number` value would be 1.

# %%
periods = pd.json_normalize(json_data, record_path=['periods'], errors='ignore')
periods.head()
# Out:
#   period_type                                    id  number  sequence  \
# 0     quarter  01ef6fa1-eda6-4689-836e-82dbc78b3e69       1         1
# 1     quarter  83b89666-c594-42cb-bff1-47afecda9cb5       2         2
# 2     quarter  e2f686c4-854f-467e-9db9-1825b04d6a6c       3         3
# 3     quarter  2920eec3-0e9c-4dc6-99af-d6ffc21122b5       4         4
#
#                                                  pbp  \
# 0  [{'type': 'drive', 'id': '01ebde76-2065-4995-8...
# 1  [{'type': 'drive', 'id': '8928b7d9-711a-41c7-a...
# 2  [{'type': 'drive', 'id': 'f1e1b3bb-9d19-40c8-9...
# 3  [{'type': 'drive', 'id': '164f459d-6c89-4603-b...
#
#                         scoring.home.id scoring.home.name scoring.home.market  \
# 0  33405046-04ee-4058-a950-d606f8c30852           Vikings           Minnesota
# 1  33405046-04ee-4058-a950-d606f8c30852           Vikings           Minnesota
# 2  33405046-04ee-4058-a950-d606f8c30852           Vikings           Minnesota
# 3  33405046-04ee-4058-a950-d606f8c30852           Vikings           Minnesota
#
#   scoring.home.alias  scoring.home.sr_id  scoring.home.points  \
# 0                MIN  sr:competitor:4423                    7
# 1                MIN  sr:competitor:4423                   14
# 2                MIN  sr:competitor:4423                    3
# 3                MIN  sr:competitor:4423                    6
#
#                         scoring.away.id scoring.away.name scoring.away.market  \
# 0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8          Seahawks             Seattle
# 1  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8          Seahawks             Seattle
# 2  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8          Seahawks             Seattle
# 3  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8          Seahawks             Seattle
#
#   scoring.away.alias  scoring.away.sr_id  scoring.away.points  \
# 0                SEA  sr:competitor:4430                   10
# 1                SEA  sr:competitor:4430                    7
# 2                SEA  sr:competitor:4430                    0
# 3                SEA  sr:competitor:4430                    0
#
#   coin_toss.home.outcome coin_toss.home.decision coin_toss.home.direction  \
# 0                    won                   defer                    north
# 1                    NaN                     NaN                      NaN
# 2                    won                 receive                    south
# 3                    NaN                     NaN                      NaN
#
#   coin_toss.away.outcome coin_toss.away.decision coin_toss.away.direction
# 0                   lost                 receive                    north
# 1                    NaN                     NaN                      NaN
# 2                   lost                    kick                    south
# 3                    NaN                     NaN                      NaN

# %%
periods.columns
# Out:
# Index(['period_type', 'id', 'number', 'sequence', 'pbp', 'scoring.home.id',
#        'scoring.home.name', 'scoring.home.market', 'scoring.home.alias',
#        'scoring.home.sr_id', 'scoring.home.points', 'scoring.away.id',
#        'scoring.away.name', 'scoring.away.market', 'scoring.away.alias',
#        'scoring.away.sr_id', 'scoring.away.points', 'coin_toss.home.outcome',
#        'coin_toss.home.decision', 'coin_toss.home.direction',
#        'coin_toss.away.outcome', 'coin_toss.away.decision',
#        'coin_toss.away.direction'],
#       dtype='object')

# %% [markdown]
# #### More columns to drop
# - Dropping more columns that are not relevant or have the same names as columns in deeper nestings

# %%
periods = periods.drop(columns = ['id', 'sequence', 'scoring.home.name', 'scoring.home.market', 'scoring.home.points', 'scoring.away.name', 'scoring.away.market', 'scoring.away.points', 'coin_toss.home.outcome',
       'coin_toss.home.decision', 'coin_toss.home.direction', 'coin_toss.away.outcome', 'coin_toss.away.decision', 'coin_toss.away.direction'], errors = 'ignore')

# %%
periods.head()
# Out:
#   period_type  number                                                pbp  \
# 0     quarter       1  [{'type': 'drive', 'id': '01ebde76-2065-4995-8...
# 1     quarter       2  [{'type': 'drive', 'id': '8928b7d9-711a-41c7-a...
# 2     quarter       3  [{'type': 'drive', 'id': 'f1e1b3bb-9d19-40c8-9...
# 3     quarter       4  [{'type': 'drive', 'id': '164f459d-6c89-4603-b...
#
#                         scoring.home.id scoring.home.alias  \
# 0  33405046-04ee-4058-a950-d606f8c30852                MIN
# 1  33405046-04ee-4058-a950-d606f8c30852                MIN
# 2  33405046-04ee-4058-a950-d606f8c30852                MIN
# 3  33405046-04ee-4058-a950-d606f8c30852                MIN
#
#    scoring.home.sr_id                       scoring.away.id  \
# 0  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 1  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 2  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 3  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
#
#   scoring.away.alias  scoring.away.sr_id
# 0                SEA  sr:competitor:4430
# 1                SEA  sr:competitor:4430
# 2                SEA  sr:competitor:4430
# 3                SEA  sr:competitor:4430

# %% [markdown]
# ## PBP Data

# %% [markdown]
# ### Access PBP data
# - We'll explode the `pbp` column so that each row in the `periods` is multiplied by the number of rows in the `pbp` column for that period

# %%
periods_pbp_exploded = periods.explode('pbp')

# Convert pbp column to its own flattened dataframe
pbp = pd.json_normalize(periods_pbp_exploded['pbp'])

# %%
periods_pbp_exploded.head()
# Out:
#   period_type  number                                                pbp  \
# 0     quarter       1  {'type': 'drive', 'id': '01ebde76-2065-4995-88...
# 0     quarter       1  {'type': 'event', 'id': 'ec9240d0-1f08-11ec-a6...
# 0     quarter       1  {'type': 'drive', 'id': 'b67eb032-3253-4577-93...
# 0     quarter       1  {'type': 'event', 'id': '25cf0120-1f0a-11ec-b3...
# 0     quarter       1  {'type': 'drive', 'id': 'c20efd4b-36b7-4ee9-84...
#
#                         scoring.home.id scoring.home.alias  \
# 0  33405046-04ee-4058-a950-d606f8c30852                MIN
# 0  33405046-04ee-4058-a950-d606f8c30852                MIN
# 0  33405046-04ee-4058-a950-d606f8c30852                MIN
# 0  33405046-04ee-4058-a950-d606f8c30852                MIN
# 0  33405046-04ee-4058-a950-d606f8c30852                MIN
#
#    scoring.home.sr_id                       scoring.away.id  \
# 0  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 0  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 0  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 0  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 0  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
#
#   scoring.away.alias  scoring.away.sr_id
# 0                SEA  sr:competitor:4430
# 0                SEA  sr:competitor:4430
# 0                SEA  sr:competitor:4430
# 0                SEA  sr:competitor:4430
# 0                SEA  sr:competitor:4430

# %%
pbp.head()
# Out:
#     type                                    id      sequence start_reason  \
# 0  drive  01ebde76-2065-4995-8871-5156d235c3fd             1      Kickoff
# 1  event  ec9240d0-1f08-11ec-a67f-c75e589fa3a4 1632688380473          NaN
# 2  drive  b67eb032-3253-4577-9387-8461866cdec0             2      Kickoff
# 3  event  25cf0120-1f0a-11ec-b36d-a3b2acec3de6 1632688906057          NaN
# 4  drive  c20efd4b-36b7-4ee9-8474-cf681cfee895             3      Kickoff
#
#    end_reason  play_count duration  first_downs  gain  penalty_yards  \
# 0   Touchdown           9     4:34            4    75              0
# 1         NaN         NaN      NaN          NaN   NaN            NaN
# 2   Touchdown           7     3:49            4    70              0
# 3         NaN         NaN      NaN          NaN   NaN            NaN
# 4  Field Goal          11     6:10            3    50            -10
#
#   inside_20 scoring_drive                 created_at  \
# 0      True          True  2021-09-26T20:26:01+00:00
# 1       NaN           NaN  2021-09-26T20:33:00+00:00
# 2      True          True  2021-09-26T20:35:51+00:00
# 3       NaN           NaN  2021-09-26T20:41:46+00:00
# 4       NaN          True  2021-09-26T20:44:42+00:00
#
#                   updated_at  team_sequence start_clock end_clock  \
# 0  2023-07-27T16:06:08+00:00              1       15:00     10:26
# 1  2021-09-26T20:33:00+00:00            NaN         NaN       NaN
# 2  2023-07-27T16:06:10+00:00              1       10:26      6:37
# 3  2021-09-26T20:41:46+00:00            NaN         NaN       NaN
# 4  2023-07-27T16:06:11+00:00              2        6:37     00:27
#
#    first_drive_yardline  last_drive_yardline  net_yards pat_successful  \
# 0                    75                   10         75           True
# 1                   NaN                  NaN        NaN            NaN
# 2                    70                    7         70           True
# 3                   NaN                  NaN        NaN            NaN
# 4                    75                   35         40            NaN
#
#    pat_points_attempted                                             events  \
# 0                     1  [{'type': 'play', 'id': 'e62ee710-1eff-11ec-a6...
# 1                   NaN                                                NaN
# 2                     1  [{'type': 'play', 'id': 'f15ee410-1f08-11ec-a6...
# 3                   NaN                                                NaN
# 4                     0  [{'type': 'play', 'id': '2a57bd90-1f0a-11ec-b3...
#
#    offensive_team.points                     offensive_team.id  \
# 0                      7  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 1                    NaN                                   NaN
# 2                      7  33405046-04ee-4058-a950-d606f8c30852
# 3                    NaN                                   NaN
# 4                      3  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
#
#    defensive_team.points                     defensive_team.id  clock  \
# 0                      0  33405046-04ee-4058-a950-d606f8c30852    NaN
# 1                    NaN                                   NaN  10:26
# 2                      0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8    NaN
# 3                    NaN                                   NaN   6:37
# 4                      0  33405046-04ee-4058-a950-d606f8c30852    NaN
#
#    event_type description                 wall_clock  home_points  \
# 0         NaN         NaN                        NaN          NaN
# 1  tv_timeout  TV Timeout  2021-09-26T20:32:58+00:00          NaN
# 2         NaN         NaN                        NaN          NaN
# 3  tv_timeout  TV Timeout  2021-09-26T20:41:43+00:00          NaN
# 4         NaN         NaN                        NaN          NaN
#
#    away_points play_type fake_punt fake_field_goal screen_pass play_action  \
# 0          NaN       NaN       NaN             NaN         NaN         NaN
# 1          NaN       NaN       NaN             NaN         NaN         NaN
# 2          NaN       NaN       NaN             NaN         NaN         NaN
# 3          NaN       NaN       NaN             NaN         NaN         NaN
# 4          NaN       NaN       NaN             NaN         NaN         NaN
#
#   run_pass_option statistics details start_situation.clock  \
# 0             NaN        NaN     NaN                   NaN
# 1             NaN        NaN     NaN                   NaN
# 2             NaN        NaN     NaN                   NaN
# 3             NaN        NaN     NaN                   NaN
# 4             NaN        NaN     NaN                   NaN
#
#    start_situation.down  start_situation.yfd start_situation.possession.id  \
# 0                   NaN                  NaN                           NaN
# 1                   NaN                  NaN                           NaN
# 2                   NaN                  NaN                           NaN
# 3                   NaN                  NaN                           NaN
# 4                   NaN                  NaN                           NaN
#
#   start_situation.possession.name start_situation.possession.market  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
#
#   start_situation.possession.alias start_situation.possession.sr_id  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   start_situation.location.id start_situation.location.name  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   start_situation.location.market start_situation.location.alias  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   start_situation.location.sr_id  start_situation.location.yardline  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#   end_situation.clock  end_situation.down  end_situation.yfd  \
# 0                 NaN                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2                 NaN                 NaN                NaN
# 3                 NaN                 NaN                NaN
# 4                 NaN                 NaN                NaN
#
#   end_situation.possession.id end_situation.possession.name  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   end_situation.possession.market end_situation.possession.alias  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   end_situation.possession.sr_id end_situation.location.id  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
#
#   end_situation.location.name end_situation.location.market  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   end_situation.location.alias end_situation.location.sr_id  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    end_situation.location.yardline
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %% [markdown]
# #### PBP data represented by drives
# - Each row in the PBP dataset is a drive or possession
#   - A drive/possession is a series of plays in which one team possess the ball while the other team is on defense
#   - A drive ends when the ball changes possession, a score is made, a game half ends, or the game concludes
# - There are also other rows that are not for drives, but for "events," which appear to be TV timeouts and other intermissions

# %%
periods_pbp_exploded.columns
# Out:
# Index(['period_type', 'number', 'pbp', 'scoring.home.id', 'scoring.home.alias',
#        'scoring.home.sr_id', 'scoring.away.id', 'scoring.away.alias',
#        'scoring.away.sr_id'],
#       dtype='object')

# %%
# Delete unnecessary columns
periods_pbp_exploded = periods_pbp_exploded.drop(columns = ['pbp'])

# %% [markdown]
# #### More columns to drop
# - Dropping more columns that are not relevant or have the same names as columns in deeper nestings

# %%
# Delete unnecessary columns
pbp = pbp.drop(columns = ['home_points', 'away_points', 'play_type', 'fake_punt', 'fake_field_goal', 'screen_pass', 'play_action', 'run_pass_option', 'statistics', 'details', 'start_situation.clock', 'start_situation.down', 'start_situation.yfd', 'start_situation.possession.id', 'start_situation.possession.name',
                          'start_situation.possession.market', 'start_situation.possession.alias', 'start_situation.possession.sr_id', 'start_situation.location.id', 'start_situation.location.name', 'start_situation.location.market', 'start_situation.location.alias', 'start_situation.location.sr_id', 'start_situation.location.yardline',
                          'end_situation.clock', 'end_situation.down', 'end_situation.yfd', 'end_situation.possession.id', 'end_situation.possession.name', 'end_situation.possession.market', 'end_situation.possession.alias', 'end_situation.possession.sr_id', 'end_situation.location.id', 'end_situation.location.name',
                          'end_situation.location.market', 'end_situation.location.alias', 'end_situation.location.sr_id', 'end_situation.location.yardline', 'event_type', 'description', 'type', 'inside_20', 'created_at', 'sequence', 'start_reason', 'end_reason', 'play_count', 'duration', 'first_downs', 'gain', 'penalty_yards', 
                          'scoring_drive', 'created_at', 'updated_at', 'start_clock', 'end_clock', 'first_drive_yardline', 'last_drive_yardline', 'net_yards', 'pat_successful', 'pat_points_attempted', 'offensive_team.points', 'offensive_team.id', 'defensive_team.points', 'defensive_team.id', 'clock', 'wall_clock', 'scoring_play', 
                          'scoring_description', 'hash_mark'], errors = 'ignore')

# %%
pbp.head()
# Out:
#                                      id  team_sequence  \
# 0  01ebde76-2065-4995-8871-5156d235c3fd              1
# 1  ec9240d0-1f08-11ec-a67f-c75e589fa3a4            NaN
# 2  b67eb032-3253-4577-9387-8461866cdec0              1
# 3  25cf0120-1f0a-11ec-b36d-a3b2acec3de6            NaN
# 4  c20efd4b-36b7-4ee9-8474-cf681cfee895              2
#
#                                               events
# 0  [{'type': 'play', 'id': 'e62ee710-1eff-11ec-a6...
# 1                                                NaN
# 2  [{'type': 'play', 'id': 'f15ee410-1f08-11ec-a6...
# 3                                                NaN
# 4  [{'type': 'play', 'id': '2a57bd90-1f0a-11ec-b3...

# %%
# Rename id to event_id to avoid confusion
pbp = pbp.rename(columns={"id": "event_id"})

# %%
pbp.shape, periods_pbp_exploded.shape
# Out:
# ((34, 3), (34, 8))

# %% [markdown]
# ### Concatenate periods and pbp dataframes
# - With the `periods` dataframe expanded to accommodate the exploded `pbp` column we can merge it with the `pbp` dataframe.
# - Note the naming convention I'm using so I can keep better track of the steps I've taken thus far and don't get lost along the way:
#   - `periods` dataframe, with `pbp` column exploded, merged with `pbp` dataframe
#     - `periods_pbp_exploded_pbp`

# %%
periods_pbp_exploded = periods_pbp_exploded.reset_index(drop = True)
pbp = pbp.reset_index(drop = True)

periods_pbp_exploded_pbp = pd.concat([periods_pbp_exploded, pbp], axis=1)
periods_pbp_exploded_pbp.head()
# Out:
#   period_type  number                       scoring.home.id  \
# 0     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 1     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 2     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 3     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 4     quarter       1  33405046-04ee-4058-a950-d606f8c30852
#
#   scoring.home.alias  scoring.home.sr_id  \
# 0                MIN  sr:competitor:4423
# 1                MIN  sr:competitor:4423
# 2                MIN  sr:competitor:4423
# 3                MIN  sr:competitor:4423
# 4                MIN  sr:competitor:4423
#
#                         scoring.away.id scoring.away.alias  \
# 0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 1  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 2  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 3  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 4  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
#
#    scoring.away.sr_id                              event_id  team_sequence  \
# 0  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 1  sr:competitor:4430  ec9240d0-1f08-11ec-a67f-c75e589fa3a4            NaN
# 2  sr:competitor:4430  b67eb032-3253-4577-9387-8461866cdec0              1
# 3  sr:competitor:4430  25cf0120-1f0a-11ec-b36d-a3b2acec3de6            NaN
# 4  sr:competitor:4430  c20efd4b-36b7-4ee9-8474-cf681cfee895              2
#
#                                               events
# 0  [{'type': 'play', 'id': 'e62ee710-1eff-11ec-a6...
# 1                                                NaN
# 2  [{'type': 'play', 'id': 'f15ee410-1f08-11ec-a6...
# 3                                                NaN
# 4  [{'type': 'play', 'id': '2a57bd90-1f0a-11ec-b3...

# %% [markdown]
# ## Events Data
# ### Access Events data
# - As we did before with the `periods` dataframe and `pbp` column, we'll explode the `events` column.
# - The naming convention still holds
#   - `periods` dataframe, with `pbp` column exploded, merged with `pbp` dataframe, with `events` column exploded
#     - `periods_pbp_exploded_pbp_events_exploded`

# %%
periods_pbp_exploded_pbp_events_exploded = periods_pbp_exploded_pbp.explode('events')

# Convert events column to its owned flattened dataframe
events_flattened = pd.json_normalize(periods_pbp_exploded_pbp_events_exploded['events'])

# %%
periods_pbp_exploded_pbp_events_exploded.shape, events_flattened.shape
# Out:
# ((185, 11), (185, 70))

# %%
periods_pbp_exploded_pbp_events_exploded.head()
# Out:
#   period_type  number                       scoring.home.id  \
# 0     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 0     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 0     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 0     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 0     quarter       1  33405046-04ee-4058-a950-d606f8c30852
#
#   scoring.home.alias  scoring.home.sr_id  \
# 0                MIN  sr:competitor:4423
# 0                MIN  sr:competitor:4423
# 0                MIN  sr:competitor:4423
# 0                MIN  sr:competitor:4423
# 0                MIN  sr:competitor:4423
#
#                         scoring.away.id scoring.away.alias  \
# 0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
#
#    scoring.away.sr_id                              event_id  team_sequence  \
# 0  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 0  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 0  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 0  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 0  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
#
#                                               events
# 0  {'type': 'play', 'id': 'e62ee710-1eff-11ec-a67...
# 0  {'type': 'play', 'id': 'f72f3120-1f07-11ec-a67...
# 0  {'type': 'play', 'id': '1f47ee90-1f08-11ec-a67...
# 0  {'type': 'play', 'id': '27e018c0-1f08-11ec-a67...
# 0  {'type': 'play', 'id': '38edf100-1f08-11ec-a67...

# %%
events_flattened.head(15)
# Out:
#     type                                    id      sequence  clock  \
# 0   play  e62ee710-1eff-11ec-a67f-c75e589fa3a4 1632687960945  15:00
# 1   play  f72f3120-1f07-11ec-a67f-c75e589fa3a4 1632688011269  15:00
# 2   play  1f47ee90-1f08-11ec-a67f-c75e589fa3a4 1632688042628  14:24
# 3   play  27e018c0-1f08-11ec-a67f-c75e589fa3a4 1632688071270  14:00
# 4   play  38edf100-1f08-11ec-a67f-c75e589fa3a4 1632688103467  13:26
# 5   play  4c3a6ea0-1f08-11ec-a67f-c75e589fa3a4 1632688142485  12:50
# 6   play  64bba020-1f08-11ec-a67f-c75e589fa3a4 1632688188679  12:02
# 7   play  8e3944c0-1f08-11ec-a67f-c75e589fa3a4 1632688230041  11:24
# 8   play  9fc15610-1f08-11ec-a67f-c75e589fa3a4 1632688272229  10:41
# 9   play  b0cb36b0-1f08-11ec-a67f-c75e589fa3a4 1632688365676  10:32
# 10  play  e8bf66e0-1f08-11ec-a67f-c75e589fa3a4 1632688372596  10:26
# 11   NaN                                   NaN           NaN    NaN
# 12  play  f15ee410-1f08-11ec-a67f-c75e589fa3a4 1632688551357  10:26
# 13  play  78daba90-1f09-11ec-a67f-c75e589fa3a4 1632688630161  10:26
# 14  play  86a1cc40-1f09-11ec-a67f-c75e589fa3a4 1632688670807   9:51
#
#     home_points  away_points    play_type                 wall_clock  \
# 0             0            0      kickoff  2021-09-26T20:25:58+00:00
# 1             0            0         pass  2021-09-26T20:26:38+00:00
# 2             0            0         rush  2021-09-26T20:27:16+00:00
# 3             0            0         rush  2021-09-26T20:27:40+00:00
# 4             0            0         rush  2021-09-26T20:28:13+00:00
# 5             0            0         pass  2021-09-26T20:28:49+00:00
# 6             0            0         rush  2021-09-26T20:29:37+00:00
# 7             0            0         pass  2021-09-26T20:30:20+00:00
# 8             0            0         pass  2021-09-26T20:31:05+00:00
# 9             0            6         pass  2021-09-26T20:31:47+00:00
# 10            0            7  extra_point  2021-09-26T20:32:49+00:00
# 11          NaN          NaN          NaN                        NaN
# 12            0            7      kickoff  2021-09-26T20:35:46+00:00
# 13            0            7         rush  2021-09-26T20:37:04+00:00
# 14            0            7         pass  2021-09-26T20:37:37+00:00
#
#                                           description fake_punt  \
# 0   G.Joseph kicks 65 yards from MIN 35 to the SEA...     False
# 1   R.Wilson pass short right complete to SEA 36. ...     False
# 2   C.Carson rushed left tackle to SEA 44 for 2 ya...     False
# 3   C.Carson rushed right tackle to MIN 49 for 7 y...     False
# 4   C.Carson rushed right end to MIN 45 for 4 yard...     False
# 5   R.Wilson pass short right complete to MIN 42. ...     False
# 6   A.Collins rushed to MIN 38 for 2 yards. Tackle...     False
# 7   R.Wilson pass short left complete to MIN 27. C...     False
# 8   R.Wilson steps back to pass. R.Wilson pass inc...     False
# 9   R.Wilson pass short right complete to MIN 3. C...     False
# 10                       J.Myers extra point is good.     False
# 11                                                NaN       NaN
# 12  J.Myers kicks 65 yards from SEA 35 to the MIN ...     False
# 13  A.Mattison rushed up the middle to MIN 37 for ...     False
# 14  K.Cousins pass short left complete to MIN 35. ...     False
#
#    fake_field_goal screen_pass   hash_mark play_action run_pass_option  \
# 0            False       False      Middle       False           False
# 1            False       False      Middle        True           False
# 2            False       False  Right Hash       False           False
# 3            False       False   Left Hash       False            True
# 4            False       False  Right Hash       False            True
# 5            False       False  Right Hash        True            True
# 6            False       False  Right Hash       False            True
# 7            False       False  Right Hash       False           False
# 8            False       False  Right Hash       False           False
# 9            False       False  Right Hash       False           False
# 10           False       False   Left Hash       False           False
# 11             NaN         NaN         NaN         NaN             NaN
# 12           False       False      Middle       False           False
# 13           False       False  Right Hash       False           False
# 14           False        True      Middle        True           False
#
#                    created_at                 updated_at  \
# 0   2021-09-26T20:26:00+00:00  2021-09-27T15:00:45+00:00
# 1   2021-09-26T20:26:51+00:00  2021-09-27T15:03:42+00:00
# 2   2021-09-26T20:27:22+00:00  2021-09-27T15:04:37+00:00
# 3   2021-09-26T20:27:51+00:00  2021-09-27T15:11:07+00:00
# 4   2021-09-26T20:28:23+00:00  2021-09-27T15:11:17+00:00
# 5   2021-09-26T20:29:02+00:00  2021-09-27T15:11:20+00:00
# 6   2021-09-26T20:29:48+00:00  2021-09-27T15:12:58+00:00
# 7   2021-09-26T20:30:30+00:00  2021-09-27T15:15:23+00:00
# 8   2021-09-26T20:31:12+00:00  2023-07-27T16:06:08+00:00
# 9   2021-09-26T20:32:45+00:00  2023-07-27T16:06:08+00:00
# 10  2021-09-26T20:32:52+00:00  2023-07-27T16:06:08+00:00
# 11                        NaN                        NaN
# 12  2021-09-26T20:35:51+00:00  2021-09-30T23:13:48+00:00
# 13  2021-09-26T20:37:10+00:00  2021-09-27T15:25:55+00:00
# 14  2021-09-26T20:37:50+00:00  2021-09-28T21:01:09+00:00
#
#                                            statistics  \
# 0   [{'stat_type': 'kick', 'attempt': 1, 'yards': ...
# 1   [{'stat_type': 'pass', 'attempt': 1, 'complete...
# 2   [{'stat_type': 'rush', 'attempt': 1, 'yards': ...
# 3   [{'stat_type': 'rush', 'attempt': 1, 'yards': ...
# 4   [{'stat_type': 'rush', 'attempt': 1, 'yards': ...
# 5   [{'stat_type': 'pass', 'attempt': 1, 'complete...
# 6   [{'stat_type': 'rush', 'attempt': 1, 'yards': ...
# 7   [{'stat_type': 'pass', 'attempt': 1, 'complete...
# 8   [{'stat_type': 'pass', 'attempt': 1, 'complete...
# 9   [{'stat_type': 'pass', 'attempt': 1, 'complete...
# 10  [{'stat_type': 'extra_point', 'attempt': 1, 'm...
# 11                                                NaN
# 12  [{'stat_type': 'kick', 'attempt': 1, 'yards': ...
# 13  [{'stat_type': 'rush', 'attempt': 1, 'yards': ...
# 14  [{'stat_type': 'pass', 'attempt': 1, 'complete...
#
#                                               details start_situation.clock  \
# 0   [{'category': 'kick_off', 'description': 'G.Jo...                 15:00
# 1   [{'category': 'pass_completion', 'description'...                 15:00
# 2   [{'category': 'rush', 'description': 'C.Carson...                 14:24
# 3   [{'category': 'rush', 'description': 'C.Carson...                 14:00
# 4   [{'category': 'rush', 'description': 'C.Carson...                 13:26
# 5   [{'category': 'pass_completion', 'description'...                 12:50
# 6   [{'category': 'rush', 'description': 'A.Collin...                 12:02
# 7   [{'category': 'pass_completion', 'description'...                 11:24
# 8   [{'category': 'pass', 'description': 'R.Wilson...                 10:41
# 9   [{'category': 'pass_completion', 'description'...                 10:32
# 10  [{'category': 'extra_point_attempt', 'descript...                 10:26
# 11                                                NaN                   NaN
# 12  [{'category': 'kick_off', 'description': 'J.My...                 10:26
# 13  [{'category': 'rush', 'description': 'A.Mattis...                 10:26
# 14  [{'category': 'pass_completion', 'description'...                  9:51
#
#     start_situation.down  start_situation.yfd  \
# 0                      0                    0
# 1                      1                   10
# 2                      1                   10
# 3                      2                    8
# 4                      3                    1
# 5                      1                   10
# 6                      2                    5
# 7                      3                    3
# 8                      1                   10
# 9                      2                   10
# 10                     0                    0
# 11                   NaN                  NaN
# 12                     0                    0
# 13                     1                   10
# 14                     2                    3
#
#            start_situation.possession.id start_situation.possession.name  \
# 0   33405046-04ee-4058-a950-d606f8c30852                         Vikings
# 1   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 2   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 3   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 4   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 5   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 6   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 7   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 8   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 9   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 10  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 11                                   NaN                             NaN
# 12  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                        Seahawks
# 13  33405046-04ee-4058-a950-d606f8c30852                         Vikings
# 14  33405046-04ee-4058-a950-d606f8c30852                         Vikings
#
#    start_situation.possession.market start_situation.possession.alias  \
# 0                          Minnesota                              MIN
# 1                            Seattle                              SEA
# 2                            Seattle                              SEA
# 3                            Seattle                              SEA
# 4                            Seattle                              SEA
# 5                            Seattle                              SEA
# 6                            Seattle                              SEA
# 7                            Seattle                              SEA
# 8                            Seattle                              SEA
# 9                            Seattle                              SEA
# 10                           Seattle                              SEA
# 11                               NaN                              NaN
# 12                           Seattle                              SEA
# 13                         Minnesota                              MIN
# 14                         Minnesota                              MIN
#
#    start_situation.possession.sr_id           start_situation.location.id  \
# 0                sr:competitor:4423  33405046-04ee-4058-a950-d606f8c30852
# 1                sr:competitor:4430  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 2                sr:competitor:4430  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 3                sr:competitor:4430  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 4                sr:competitor:4430  33405046-04ee-4058-a950-d606f8c30852
# 5                sr:competitor:4430  33405046-04ee-4058-a950-d606f8c30852
# 6                sr:competitor:4430  33405046-04ee-4058-a950-d606f8c30852
# 7                sr:competitor:4430  33405046-04ee-4058-a950-d606f8c30852
# 8                sr:competitor:4430  33405046-04ee-4058-a950-d606f8c30852
# 9                sr:competitor:4430  33405046-04ee-4058-a950-d606f8c30852
# 10               sr:competitor:4430  33405046-04ee-4058-a950-d606f8c30852
# 11                              NaN                                   NaN
# 12               sr:competitor:4430  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 13               sr:competitor:4423  33405046-04ee-4058-a950-d606f8c30852
# 14               sr:competitor:4423  33405046-04ee-4058-a950-d606f8c30852
#
#    start_situation.location.name start_situation.location.market  \
# 0                        Vikings                       Minnesota
# 1                       Seahawks                         Seattle
# 2                       Seahawks                         Seattle
# 3                       Seahawks                         Seattle
# 4                        Vikings                       Minnesota
# 5                        Vikings                       Minnesota
# 6                        Vikings                       Minnesota
# 7                        Vikings                       Minnesota
# 8                        Vikings                       Minnesota
# 9                        Vikings                       Minnesota
# 10                       Vikings                       Minnesota
# 11                           NaN                             NaN
# 12                      Seahawks                         Seattle
# 13                       Vikings                       Minnesota
# 14                       Vikings                       Minnesota
#
#    start_situation.location.alias start_situation.location.sr_id  \
# 0                             MIN             sr:competitor:4423
# 1                             SEA             sr:competitor:4430
# 2                             SEA             sr:competitor:4430
# 3                             SEA             sr:competitor:4430
# 4                             MIN             sr:competitor:4423
# 5                             MIN             sr:competitor:4423
# 6                             MIN             sr:competitor:4423
# 7                             MIN             sr:competitor:4423
# 8                             MIN             sr:competitor:4423
# 9                             MIN             sr:competitor:4423
# 10                            MIN             sr:competitor:4423
# 11                            NaN                            NaN
# 12                            SEA             sr:competitor:4430
# 13                            MIN             sr:competitor:4423
# 14                            MIN             sr:competitor:4423
#
#     start_situation.location.yardline end_situation.clock  end_situation.down  \
# 0                                  35               15:00                   1
# 1                                  25               14:24                   1
# 2                                  42               14:00                   2
# 3                                  44               13:26                   3
# 4                                  49               12:50                   1
# 5                                  45               12:02                   2
# 6                                  40               11:24                   3
# 7                                  38               10:41                   1
# 8                                  10               10:32                   2
# 9                                  10               10:26                   0
# 10                                 15               10:26                   0
# 11                                NaN                 NaN                 NaN
# 12                                 35               10:26                   1
# 13                                 30                9:51                   2
# 14                                 37                9:11                   1
#
#     end_situation.yfd           end_situation.possession.id  \
# 0                  10  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 1                  10  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 2                   8  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 3                   1  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 4                  10  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 5                   5  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 6                   2  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 7                  10  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 8                  10  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 9                   0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 10                  0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 11                NaN                                   NaN
# 12                 10  33405046-04ee-4058-a950-d606f8c30852
# 13                  3  33405046-04ee-4058-a950-d606f8c30852
# 14                 10  33405046-04ee-4058-a950-d606f8c30852
#
#    end_situation.possession.name end_situation.possession.market  \
# 0                       Seahawks                         Seattle
# 1                       Seahawks                         Seattle
# 2                       Seahawks                         Seattle
# 3                       Seahawks                         Seattle
# 4                       Seahawks                         Seattle
# 5                       Seahawks                         Seattle
# 6                       Seahawks                         Seattle
# 7                       Seahawks                         Seattle
# 8                       Seahawks                         Seattle
# 9                       Seahawks                         Seattle
# 10                      Seahawks                         Seattle
# 11                           NaN                             NaN
# 12                       Vikings                       Minnesota
# 13                       Vikings                       Minnesota
# 14                       Vikings                       Minnesota
#
#    end_situation.possession.alias end_situation.possession.sr_id  \
# 0                             SEA             sr:competitor:4430
# 1                             SEA             sr:competitor:4430
# 2                             SEA             sr:competitor:4430
# 3                             SEA             sr:competitor:4430
# 4                             SEA             sr:competitor:4430
# 5                             SEA             sr:competitor:4430
# 6                             SEA             sr:competitor:4430
# 7                             SEA             sr:competitor:4430
# 8                             SEA             sr:competitor:4430
# 9                             SEA             sr:competitor:4430
# 10                            SEA             sr:competitor:4430
# 11                            NaN                            NaN
# 12                            MIN             sr:competitor:4423
# 13                            MIN             sr:competitor:4423
# 14                            MIN             sr:competitor:4423
#
#                end_situation.location.id end_situation.location.name  \
# 0   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                    Seahawks
# 1   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                    Seahawks
# 2   3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                    Seahawks
# 3   33405046-04ee-4058-a950-d606f8c30852                     Vikings
# 4   33405046-04ee-4058-a950-d606f8c30852                     Vikings
# 5   33405046-04ee-4058-a950-d606f8c30852                     Vikings
# 6   33405046-04ee-4058-a950-d606f8c30852                     Vikings
# 7   33405046-04ee-4058-a950-d606f8c30852                     Vikings
# 8   33405046-04ee-4058-a950-d606f8c30852                     Vikings
# 9   33405046-04ee-4058-a950-d606f8c30852                     Vikings
# 10  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                    Seahawks
# 11                                   NaN                         NaN
# 12  33405046-04ee-4058-a950-d606f8c30852                     Vikings
# 13  33405046-04ee-4058-a950-d606f8c30852                     Vikings
# 14  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                    Seahawks
#
#    end_situation.location.market end_situation.location.alias  \
# 0                        Seattle                          SEA
# 1                        Seattle                          SEA
# 2                        Seattle                          SEA
# 3                      Minnesota                          MIN
# 4                      Minnesota                          MIN
# 5                      Minnesota                          MIN
# 6                      Minnesota                          MIN
# 7                      Minnesota                          MIN
# 8                      Minnesota                          MIN
# 9                      Minnesota                          MIN
# 10                       Seattle                          SEA
# 11                           NaN                          NaN
# 12                     Minnesota                          MIN
# 13                     Minnesota                          MIN
# 14                       Seattle                          SEA
#
#    end_situation.location.sr_id  end_situation.location.yardline  \
# 0            sr:competitor:4430                               25
# 1            sr:competitor:4430                               42
# 2            sr:competitor:4430                               44
# 3            sr:competitor:4423                               49
# 4            sr:competitor:4423                               45
# 5            sr:competitor:4423                               40
# 6            sr:competitor:4423                               37
# 7            sr:competitor:4423                               10
# 8            sr:competitor:4423                               10
# 9            sr:competitor:4423                               15
# 10           sr:competitor:4430                               35
# 11                          NaN                              NaN
# 12           sr:competitor:4423                               30
# 13           sr:competitor:4423                               37
# 14           sr:competitor:4430                               43
#
#     players_rushed  men_in_box  blitz  play_direction  left_tightends  \
# 0              NaN         NaN    NaN             NaN             NaN
# 1                4           7  False           Right               0
# 2              NaN           6  False          Middle               0
# 3              NaN           6  False           Right               1
# 4              NaN           7  False  Right Sideline               0
# 5                4           7  False           Right               0
# 6              NaN           6  False           Right               0
# 7                4           7  False            Left               0
# 8                4           6  False            Left               0
# 9                4           7  False  Right Sideline               0
# 10             NaN         NaN    NaN             NaN             NaN
# 11             NaN         NaN    NaN             NaN             NaN
# 12             NaN         NaN    NaN             NaN             NaN
# 13             NaN           8  False          Middle               0
# 14               4           8  False   Left Sideline               0
#
#     right_tightends pocket_location    qb_at_snap     huddle  \
# 0               NaN             NaN           NaN        NaN
# 1                 2      Boot Right  Under Center     Huddle
# 2                 1             NaN  Under Center     Huddle
# 3                 0             NaN       Shotgun  No Huddle
# 4                 1             NaN       Shotgun     Huddle
# 5                 1          Middle       Shotgun  No Huddle
# 6                 0             NaN       Shotgun     Huddle
# 7                 1          Middle       Shotgun  No Huddle
# 8                 0   Scramble Left       Shotgun     Huddle
# 9                 1          Middle       Shotgun     Huddle
# 10              NaN             NaN           NaN        NaN
# 11              NaN             NaN           NaN        NaN
# 12              NaN             NaN           NaN        NaN
# 13                1             NaN  Under Center     Huddle
# 14                1          Middle  Under Center     Huddle
#
#            pass_route  running_lane goaltogo scoring_play  \
# 0                 NaN           NaN      NaN          NaN
# 1               Cross           NaN      NaN          NaN
# 2                 NaN             5      NaN          NaN
# 3                 NaN             6      NaN          NaN
# 4                 NaN             8      NaN          NaN
# 5                Curl           NaN      NaN          NaN
# 6                 NaN             2      NaN          NaN
# 7                Post           NaN      NaN          NaN
# 8                 NaN           NaN     True          NaN
# 9                 Out           NaN     True         True
# 10                NaN           NaN      NaN         True
# 11                NaN           NaN      NaN          NaN
# 12                NaN           NaN      NaN          NaN
# 13                NaN             1      NaN          NaN
# 14  Underneath Screen           NaN      NaN          NaN
#
#                                   scoring_description  score.sequence  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9   R.Wilson pass short right complete to MIN 3. C...               2
# 10  R.Wilson pass short right complete to MIN 3. C...             NaN
# 11                                                NaN             NaN
# 12                                                NaN             NaN
# 13                                                NaN             NaN
# 14                                                NaN             NaN
#
#    score.clock  score.points  score.home_points  score.away_points  \
# 0          NaN           NaN                NaN                NaN
# 1          NaN           NaN                NaN                NaN
# 2          NaN           NaN                NaN                NaN
# 3          NaN           NaN                NaN                NaN
# 4          NaN           NaN                NaN                NaN
# 5          NaN           NaN                NaN                NaN
# 6          NaN           NaN                NaN                NaN
# 7          NaN           NaN                NaN                NaN
# 8          NaN           NaN                NaN                NaN
# 9        10:26             7                  0                  6
# 10         NaN           NaN                NaN                NaN
# 11         NaN           NaN                NaN                NaN
# 12         NaN           NaN                NaN                NaN
# 13         NaN           NaN                NaN                NaN
# 14         NaN           NaN                NaN                NaN
#
#               score.points-after-play.id  score.points-after-play.sequence  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# 5                                    NaN                               NaN
# 6                                    NaN                               NaN
# 7                                    NaN                               NaN
# 8                                    NaN                               NaN
# 9   e8bf66e0-1f08-11ec-a67f-c75e589fa3a4                     1632688372596
# 10                                   NaN                               NaN
# 11                                   NaN                               NaN
# 12                                   NaN                               NaN
# 13                                   NaN                               NaN
# 14                                   NaN                               NaN
#
#    score.points-after-play.type event_type
# 0                           NaN        NaN
# 1                           NaN        NaN
# 2                           NaN        NaN
# 3                           NaN        NaN
# 4                           NaN        NaN
# 5                           NaN        NaN
# 6                           NaN        NaN
# 7                           NaN        NaN
# 8                           NaN        NaN
# 9                   extra_point        NaN
# 10                          NaN        NaN
# 11                          NaN        NaN
# 12                          NaN        NaN
# 13                          NaN        NaN
# 14                          NaN        NaN

# %% [markdown]
# #### Each event row is a play
# - Each event row is a play within a drive. We're getting closer to the data we want to see.

# %%
events_flattened.columns
# Out:
# Index(['type', 'id', 'sequence', 'clock', 'home_points', 'away_points',
#        'play_type', 'wall_clock', 'description', 'fake_punt',
#        'fake_field_goal', 'screen_pass', 'hash_mark', 'play_action',
#        'run_pass_option', 'created_at', 'updated_at', 'statistics', 'details',
#        'start_situation.clock', 'start_situation.down', 'start_situation.yfd',
#        'start_situation.possession.id', 'start_situation.possession.name',
#        'start_situation.possession.market', 'start_situation.possession.alias',
#        'start_situation.possession.sr_id', 'start_situation.location.id',
#        'start_situation.location.name', 'start_situation.location.market',
#        'start_situation.location.alias', 'start_situation.location.sr_id',
#        'start_situation.location.yardline', 'end_situation.clock',
#        'end_situation.down', 'end_situation.yfd',
#        'end_situation.possession.id', 'end_situation.possession.name',
#        'end_situation.possession.market', 'end_situation.possession.alias',
#        'end_situation.possession.sr_id', 'end_situation.location.id',
#        'end_situation.location.name', 'end_situation.location.market',
#        'end_situation.location.alias', 'end_situation.location.sr_id',
#        'end_situation.location.yardline', 'players_rushed', 'men_in_box',
#        'blitz', 'play_direction', 'left_tightends', 'right_tightends',
#        'pocket_location', 'qb_at_snap', 'huddle', 'pass_route', 'running_lane',
#        'goaltogo', 'scoring_play', 'scoring_description', 'score.sequence',
#        'score.clock', 'score.points', 'score.home_points', 'score.away_points',
#        'score.points-after-play.id', 'score.points-after-play.sequence',
#        'score.points-after-play.type', 'event_type'],
#       dtype='object')

# %%
events_flattened = events_flattened.drop(['event_type', 'blitz', 'goaltogo', 'sequence', 'created_at', 'updated_at', 'start_situation.possession.id', 'start_situation.possession.name', 'start_situation.possession.market', 'start_situation.location.id', 'start_situation.location.name', 'start_situation.location.market', 'score.sequence', 'score.clock', 
                                          'score.points', 'score.home_points', 'score.away_points', 'score.points-after-play.id', 'score.points-after-play.sequence', 'score.points-after-play.type', 'event_type', 'running_lane', 'end_situation.location.name',	'end_situation.location.market', 'end_situation.possession.name',
                                          'end_situation.possession.market', 'end_situation.location.id', 'end_situation.location.sr_id', 'start_situation.possession.sr_id', 'start_situation.location.sr_id', 'end_situation.possession.id', 'end_situation.possession.sr_id', 'details'], 
                                         axis = 1, errors = 'ignore')

# %%
# Rename events `id` column to `play_id`
events_flattened = events_flattened.rename(columns={"id": "play_id"})

# %%
# Drop redundant exploded `events` column from original dataframe
periods_pbp_exploded_pbp_events_exploded = periods_pbp_exploded_pbp_events_exploded.drop('events', axis=1)

# %% [markdown]
# ### Concatenate periods and events dataframes
# - `periods` dataframe, with `pbp` column exploded, merged with `pbp` dataframe, with `events` exploded, merged with `events` dataframe
#   - `periods_pbp_exploded_pbp_events_exploded_events`

# %%
periods_pbp_exploded_pbp_events_exploded = periods_pbp_exploded_pbp_events_exploded.reset_index(drop = True)
events_flattened = events_flattened.reset_index(drop = True)

periods_pbp_exploded_pbp_events_exploded_events = pd.concat([periods_pbp_exploded_pbp_events_exploded, events_flattened], axis=1)
periods_pbp_exploded_pbp_events_exploded_events.head()
# Out:
#   period_type  number                       scoring.home.id  \
# 0     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 1     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 2     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 3     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 4     quarter       1  33405046-04ee-4058-a950-d606f8c30852
#
#   scoring.home.alias  scoring.home.sr_id  \
# 0                MIN  sr:competitor:4423
# 1                MIN  sr:competitor:4423
# 2                MIN  sr:competitor:4423
# 3                MIN  sr:competitor:4423
# 4                MIN  sr:competitor:4423
#
#                         scoring.away.id scoring.away.alias  \
# 0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 1  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 2  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 3  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 4  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
#
#    scoring.away.sr_id                              event_id  team_sequence  \
# 0  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 1  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 2  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 3  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 4  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
#
#    type                               play_id  clock  home_points  \
# 0  play  e62ee710-1eff-11ec-a67f-c75e589fa3a4  15:00            0
# 1  play  f72f3120-1f07-11ec-a67f-c75e589fa3a4  15:00            0
# 2  play  1f47ee90-1f08-11ec-a67f-c75e589fa3a4  14:24            0
# 3  play  27e018c0-1f08-11ec-a67f-c75e589fa3a4  14:00            0
# 4  play  38edf100-1f08-11ec-a67f-c75e589fa3a4  13:26            0
#
#    away_points play_type                 wall_clock  \
# 0            0   kickoff  2021-09-26T20:25:58+00:00
# 1            0      pass  2021-09-26T20:26:38+00:00
# 2            0      rush  2021-09-26T20:27:16+00:00
# 3            0      rush  2021-09-26T20:27:40+00:00
# 4            0      rush  2021-09-26T20:28:13+00:00
#
#                                          description fake_punt  \
# 0  G.Joseph kicks 65 yards from MIN 35 to the SEA...     False
# 1  R.Wilson pass short right complete to SEA 36. ...     False
# 2  C.Carson rushed left tackle to SEA 44 for 2 ya...     False
# 3  C.Carson rushed right tackle to MIN 49 for 7 y...     False
# 4  C.Carson rushed right end to MIN 45 for 4 yard...     False
#
#   fake_field_goal screen_pass   hash_mark play_action run_pass_option  \
# 0           False       False      Middle       False           False
# 1           False       False      Middle        True           False
# 2           False       False  Right Hash       False           False
# 3           False       False   Left Hash       False            True
# 4           False       False  Right Hash       False            True
#
#                                           statistics start_situation.clock  \
# 0  [{'stat_type': 'kick', 'attempt': 1, 'yards': ...                 15:00
# 1  [{'stat_type': 'pass', 'attempt': 1, 'complete...                 15:00
# 2  [{'stat_type': 'rush', 'attempt': 1, 'yards': ...                 14:24
# 3  [{'stat_type': 'rush', 'attempt': 1, 'yards': ...                 14:00
# 4  [{'stat_type': 'rush', 'attempt': 1, 'yards': ...                 13:26
#
#    start_situation.down  start_situation.yfd start_situation.possession.alias  \
# 0                     0                    0                              MIN
# 1                     1                   10                              SEA
# 2                     1                   10                              SEA
# 3                     2                    8                              SEA
# 4                     3                    1                              SEA
#
#   start_situation.location.alias  start_situation.location.yardline  \
# 0                            MIN                                 35
# 1                            SEA                                 25
# 2                            SEA                                 42
# 3                            SEA                                 44
# 4                            MIN                                 49
#
#   end_situation.clock  end_situation.down  end_situation.yfd  \
# 0               15:00                   1                 10
# 1               14:24                   1                 10
# 2               14:00                   2                  8
# 3               13:26                   3                  1
# 4               12:50                   1                 10
#
#   end_situation.possession.alias end_situation.location.alias  \
# 0                            SEA                          SEA
# 1                            SEA                          SEA
# 2                            SEA                          SEA
# 3                            SEA                          MIN
# 4                            SEA                          MIN
#
#    end_situation.location.yardline  players_rushed  men_in_box  \
# 0                               25             NaN         NaN
# 1                               42               4           7
# 2                               44             NaN           6
# 3                               49             NaN           6
# 4                               45             NaN           7
#
#    play_direction  left_tightends  right_tightends pocket_location  \
# 0             NaN             NaN              NaN             NaN
# 1           Right               0                2      Boot Right
# 2          Middle               0                1             NaN
# 3           Right               1                0             NaN
# 4  Right Sideline               0                1             NaN
#
#      qb_at_snap     huddle pass_route scoring_play scoring_description
# 0           NaN        NaN        NaN          NaN                 NaN
# 1  Under Center     Huddle      Cross          NaN                 NaN
# 2  Under Center     Huddle        NaN          NaN                 NaN
# 3       Shotgun  No Huddle        NaN          NaN                 NaN
# 4       Shotgun     Huddle        NaN          NaN                 NaN

# %%
periods_pbp_exploded_pbp_events_exploded_events.shape
# Out:
# (185, 48)

# %% [markdown]
# ## Statistics Data

# %%
periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded = periods_pbp_exploded_pbp_events_exploded_events.explode('statistics')

# Convert events column to its owned flattened dataframe
statistics_flattened = pd.json_normalize(periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded['statistics'])

# %%
statistics_flattened.head()
# Out:
#   stat_type  attempt  yards  net_yards  touchback  onside_attempt  \
# 0      kick        1     65         40          1               0
# 1    return      NaN    NaN        NaN          1             NaN
# 2      pass        1     17        NaN        NaN             NaN
# 3   receive      NaN     17        NaN        NaN             NaN
# 4   defense      NaN    NaN        NaN        NaN             NaN
#
#    onside_success  squib_kick                             player.id  \
# 0               0           0  a2aab80d-174c-4639-beac-e2b70bb3625f
# 1             NaN         NaN                                   NaN
# 2             NaN         NaN  409d4cac-ee90-4470-9710-ebe671678339
# 3             NaN         NaN  754faf0f-40f7-45f0-b23b-6ce990ecaf26
# 4             NaN         NaN  c44b31cd-0480-4aa0-b500-12e9ba0765ac
#
#       player.name player.jersey player.position       player.sr_id  \
# 0     Greg Joseph            01               K  sr:player:1184234
# 1             NaN           NaN             NaN                NaN
# 2  Russell Wilson            03              QB   sr:player:831309
# 3      DK Metcalf            14              WR  sr:player:1230010
# 4      Nick Vigil            59              LB  sr:player:1074088
#
#                                 team.id team.name team.market team.alias  \
# 0  33405046-04ee-4058-a950-d606f8c30852   Vikings   Minnesota        MIN
# 1  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8  Seahawks     Seattle        SEA
# 2  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8  Seahawks     Seattle        SEA
# 3  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8  Seahawks     Seattle        SEA
# 4  33405046-04ee-4058-a950-d606f8c30852   Vikings   Minnesota        MIN
#
#            team.sr_id     category  complete  att_yards  firstdown  inside_20  \
# 0  sr:competitor:4423          NaN       NaN        NaN        NaN        NaN
# 1  sr:competitor:4430  kick_return       NaN        NaN        NaN        NaN
# 2  sr:competitor:4430          NaN         1         11          1          0
# 3  sr:competitor:4430          NaN       NaN        NaN          1          0
# 4  sr:competitor:4423          NaN       NaN        NaN        NaN        NaN
#
#    goaltogo  blitz  hurry  knockdown  pocket_time  on_target_throw  \
# 0       NaN    NaN    NaN        NaN          NaN              NaN
# 1       NaN    NaN    NaN        NaN          NaN              NaN
# 2         0      0      1          0            3                1
# 3         0    NaN    NaN        NaN          NaN              NaN
# 4       NaN      0      0          0          NaN              NaN
#
#    batted_pass  target  reception  yards_after_catch  dropped  catchable  \
# 0          NaN     NaN        NaN                NaN      NaN        NaN
# 1          NaN     NaN        NaN                NaN      NaN        NaN
# 2            0     NaN        NaN                NaN      NaN        NaN
# 3          NaN       1          1                  6        0          0
# 4            0     NaN        NaN                NaN      NaN        NaN
#
#    missed_tackles  def_target  def_comp  tackle  broken_tackles  kneel_down  \
# 0             NaN         NaN       NaN     NaN             NaN         NaN
# 1             NaN         NaN       NaN     NaN             NaN         NaN
# 2             NaN         NaN       NaN     NaN             NaN         NaN
# 3             NaN         NaN       NaN     NaN             NaN         NaN
# 4               0           1         1     NaN             NaN         NaN
#
#    scramble  yards_after_contact  ast_tackle  down incompletion_type  \
# 0       NaN                  NaN         NaN   NaN               NaN
# 1       NaN                  NaN         NaN   NaN               NaN
# 2       NaN                  NaN         NaN   NaN               NaN
# 3       NaN                  NaN         NaN   NaN               NaN
# 4       NaN                  NaN         NaN   NaN               NaN
#
#    touchdown  made  penalty  qb_hit  missed  endzone  return  pass_defended  \
# 0        NaN   NaN      NaN     NaN     NaN      NaN     NaN            NaN
# 1        NaN   NaN      NaN     NaN     NaN      NaN     NaN            NaN
# 2        NaN   NaN      NaN     NaN     NaN      NaN     NaN            NaN
# 3        NaN   NaN      NaN     NaN     NaN      NaN     NaN            NaN
# 4        NaN   NaN      NaN     NaN     NaN      NaN     NaN            NaN
#
#    hang_time  faircatch nullified  sack  sack_yards  ast_sack  tlost  \
# 0        NaN        NaN       NaN   NaN         NaN       NaN    NaN
# 1        NaN        NaN       NaN   NaN         NaN       NaN    NaN
# 2        NaN        NaN       NaN   NaN         NaN       NaN    NaN
# 3        NaN        NaN       NaN   NaN         NaN       NaN    NaN
# 4        NaN        NaN       NaN   NaN         NaN       NaN    NaN
#
#    tlost_yards  ast_tlost  fumble  forced  own_rec  own_rec_yards  \
# 0          NaN        NaN     NaN     NaN      NaN            NaN
# 1          NaN        NaN     NaN     NaN      NaN            NaN
# 2          NaN        NaN     NaN     NaN      NaN            NaN
# 3          NaN        NaN     NaN     NaN      NaN            NaN
# 4          NaN        NaN     NaN     NaN      NaN            NaN
#
#   play_category  forced_fumble  out_of_bounds
# 0           NaN            NaN            NaN
# 1           NaN            NaN            NaN
# 2           NaN            NaN            NaN
# 3           NaN            NaN            NaN
# 4           NaN            NaN            NaN

# %% [markdown]
# ### Each row is a player
# - Each row represents a player's involvement with the play
#   - On a kickoff
#     - The kicker
#     - The kick returner
#   - On a punt
#     - The punter
#     - The punt returner
#   - On a pass play
#     - The passer (usually the quarterback, `stat_type` == 'pass')
#     - The receiver (`stat_type` == 'receive')
#     - The player who tackled the receiver (`stat_type` == 'defense')
#   - On a run play
#     - The runner (`stat_type` == 'run')
#     - The player who tackled the runner (`stat_type` == 'defense')

# %%
statistics_flattened.columns
# Out:
# Index(['stat_type', 'attempt', 'yards', 'net_yards', 'touchback',
#        'onside_attempt', 'onside_success', 'squib_kick', 'player.id',
#        'player.name', 'player.jersey', 'player.position', 'player.sr_id',
#        'team.id', 'team.name', 'team.market', 'team.alias', 'team.sr_id',
#        'category', 'complete', 'att_yards', 'firstdown', 'inside_20',
#        'goaltogo', 'blitz', 'hurry', 'knockdown', 'pocket_time',
#        'on_target_throw', 'batted_pass', 'target', 'reception',
#        'yards_after_catch', 'dropped', 'catchable', 'missed_tackles',
#        'def_target', 'def_comp', 'tackle', 'broken_tackles', 'kneel_down',
#        'scramble', 'yards_after_contact', 'ast_tackle', 'down',
#        'incompletion_type', 'touchdown', 'made', 'penalty', 'qb_hit', 'missed',
#        'endzone', 'return', 'pass_defended', 'hang_time', 'faircatch',
#        'nullified', 'sack', 'sack_yards', 'ast_sack', 'tlost', 'tlost_yards',
#        'ast_tlost', 'fumble', 'forced', 'own_rec', 'own_rec_yards',
#        'play_category', 'forced_fumble', 'out_of_bounds'],
#       dtype='object')

# %%
statistics_flattened = statistics_flattened.drop(columns = ['missed_tackles', 'def_comp', 'hang_time', 'faircatch', 'nullified', 'sack', 'sack_yards', 'ast_sack', 'tlost', 'tlost_yards', 'ast_tlost', 'fumble', 'forced', 'own_rec', 'own_rec_yards', 'squib_kick', 'onside_attempt', 'onside_success', 'play_category', 
                                                            'forced_fumble', 'out_of_bounds', 'category', 'team.name', 'team.market', 'touchback', 'net_yards', 'kneel_down', 'scramble', 'ast_tackle', 'down', 'made', 'penalty', 'qb_hit', 'missed', 'return', 'pass_defended'], axis = 1, errors = 'ignore')

# %%
periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded.shape, statistics_flattened.shape
# Out:
# ((576, 48), (576, 34))

# %%
# Drop redundant exploded statistics column
periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded = periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded.drop('statistics', axis=1)

# %% [markdown]
# ### Concatenate pbp and statistics dataframes
# - Now we can do one last concatenation to get the statistics data into our working dataframe

# %%
periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded = periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded.reset_index(drop = True)
statistics_flattened = statistics_flattened.reset_index(drop = True)

periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded_statistics = pd.concat([periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded, statistics_flattened], axis=1)
periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded_statistics.head()
# Out:
#   period_type  number                       scoring.home.id  \
# 0     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 1     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 2     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 3     quarter       1  33405046-04ee-4058-a950-d606f8c30852
# 4     quarter       1  33405046-04ee-4058-a950-d606f8c30852
#
#   scoring.home.alias  scoring.home.sr_id  \
# 0                MIN  sr:competitor:4423
# 1                MIN  sr:competitor:4423
# 2                MIN  sr:competitor:4423
# 3                MIN  sr:competitor:4423
# 4                MIN  sr:competitor:4423
#
#                         scoring.away.id scoring.away.alias  \
# 0  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 1  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 2  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 3  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
# 4  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8                SEA
#
#    scoring.away.sr_id                              event_id  team_sequence  \
# 0  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 1  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 2  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 3  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
# 4  sr:competitor:4430  01ebde76-2065-4995-8871-5156d235c3fd              1
#
#    type                               play_id  clock  home_points  \
# 0  play  e62ee710-1eff-11ec-a67f-c75e589fa3a4  15:00            0
# 1  play  e62ee710-1eff-11ec-a67f-c75e589fa3a4  15:00            0
# 2  play  f72f3120-1f07-11ec-a67f-c75e589fa3a4  15:00            0
# 3  play  f72f3120-1f07-11ec-a67f-c75e589fa3a4  15:00            0
# 4  play  f72f3120-1f07-11ec-a67f-c75e589fa3a4  15:00            0
#
#    away_points play_type                 wall_clock  \
# 0            0   kickoff  2021-09-26T20:25:58+00:00
# 1            0   kickoff  2021-09-26T20:25:58+00:00
# 2            0      pass  2021-09-26T20:26:38+00:00
# 3            0      pass  2021-09-26T20:26:38+00:00
# 4            0      pass  2021-09-26T20:26:38+00:00
#
#                                          description fake_punt  \
# 0  G.Joseph kicks 65 yards from MIN 35 to the SEA...     False
# 1  G.Joseph kicks 65 yards from MIN 35 to the SEA...     False
# 2  R.Wilson pass short right complete to SEA 36. ...     False
# 3  R.Wilson pass short right complete to SEA 36. ...     False
# 4  R.Wilson pass short right complete to SEA 36. ...     False
#
#   fake_field_goal screen_pass hash_mark play_action run_pass_option  \
# 0           False       False    Middle       False           False
# 1           False       False    Middle       False           False
# 2           False       False    Middle        True           False
# 3           False       False    Middle        True           False
# 4           False       False    Middle        True           False
#
#   start_situation.clock  start_situation.down  start_situation.yfd  \
# 0                 15:00                     0                    0
# 1                 15:00                     0                    0
# 2                 15:00                     1                   10
# 3                 15:00                     1                   10
# 4                 15:00                     1                   10
#
#   start_situation.possession.alias start_situation.location.alias  \
# 0                              MIN                            MIN
# 1                              MIN                            MIN
# 2                              SEA                            SEA
# 3                              SEA                            SEA
# 4                              SEA                            SEA
#
#    start_situation.location.yardline end_situation.clock  end_situation.down  \
# 0                                 35               15:00                   1
# 1                                 35               15:00                   1
# 2                                 25               14:24                   1
# 3                                 25               14:24                   1
# 4                                 25               14:24                   1
#
#    end_situation.yfd end_situation.possession.alias  \
# 0                 10                            SEA
# 1                 10                            SEA
# 2                 10                            SEA
# 3                 10                            SEA
# 4                 10                            SEA
#
#   end_situation.location.alias  end_situation.location.yardline  \
# 0                          SEA                               25
# 1                          SEA                               25
# 2                          SEA                               42
# 3                          SEA                               42
# 4                          SEA                               42
#
#    players_rushed  men_in_box play_direction  left_tightends  right_tightends  \
# 0             NaN         NaN            NaN             NaN              NaN
# 1             NaN         NaN            NaN             NaN              NaN
# 2               4           7          Right               0                2
# 3               4           7          Right               0                2
# 4               4           7          Right               0                2
#
#   pocket_location    qb_at_snap  huddle pass_route scoring_play  \
# 0             NaN           NaN     NaN        NaN          NaN
# 1             NaN           NaN     NaN        NaN          NaN
# 2      Boot Right  Under Center  Huddle      Cross          NaN
# 3      Boot Right  Under Center  Huddle      Cross          NaN
# 4      Boot Right  Under Center  Huddle      Cross          NaN
#
#   scoring_description stat_type  attempt  yards  \
# 0                 NaN      kick        1     65
# 1                 NaN    return      NaN    NaN
# 2                 NaN      pass        1     17
# 3                 NaN   receive      NaN     17
# 4                 NaN   defense      NaN    NaN
#
#                               player.id     player.name player.jersey  \
# 0  a2aab80d-174c-4639-beac-e2b70bb3625f     Greg Joseph            01
# 1                                   NaN             NaN           NaN
# 2  409d4cac-ee90-4470-9710-ebe671678339  Russell Wilson            03
# 3  754faf0f-40f7-45f0-b23b-6ce990ecaf26      DK Metcalf            14
# 4  c44b31cd-0480-4aa0-b500-12e9ba0765ac      Nick Vigil            59
#
#   player.position       player.sr_id                               team.id  \
# 0               K  sr:player:1184234  33405046-04ee-4058-a950-d606f8c30852
# 1             NaN                NaN  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 2              QB   sr:player:831309  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 3              WR  sr:player:1230010  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 4              LB  sr:player:1074088  33405046-04ee-4058-a950-d606f8c30852
#
#   team.alias          team.sr_id  complete  att_yards  firstdown  inside_20  \
# 0        MIN  sr:competitor:4423       NaN        NaN        NaN        NaN
# 1        SEA  sr:competitor:4430       NaN        NaN        NaN        NaN
# 2        SEA  sr:competitor:4430         1         11          1          0
# 3        SEA  sr:competitor:4430       NaN        NaN          1          0
# 4        MIN  sr:competitor:4423       NaN        NaN        NaN        NaN
#
#    goaltogo  blitz  hurry  knockdown  pocket_time  on_target_throw  \
# 0       NaN    NaN    NaN        NaN          NaN              NaN
# 1       NaN    NaN    NaN        NaN          NaN              NaN
# 2         0      0      1          0            3                1
# 3         0    NaN    NaN        NaN          NaN              NaN
# 4       NaN      0      0          0          NaN              NaN
#
#    batted_pass  target  reception  yards_after_catch  dropped  catchable  \
# 0          NaN     NaN        NaN                NaN      NaN        NaN
# 1          NaN     NaN        NaN                NaN      NaN        NaN
# 2            0     NaN        NaN                NaN      NaN        NaN
# 3          NaN       1          1                  6        0          0
# 4            0     NaN        NaN                NaN      NaN        NaN
#
#    def_target  tackle  broken_tackles  yards_after_contact incompletion_type  \
# 0         NaN     NaN             NaN                  NaN               NaN
# 1         NaN     NaN             NaN                  NaN               NaN
# 2         NaN     NaN             NaN                  NaN               NaN
# 3         NaN     NaN             NaN                  NaN               NaN
# 4           1     NaN             NaN                  NaN               NaN
#
#    touchdown  endzone
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN

# %% [markdown]
# # MERGE DATAFRAMES
# - Now we can merge this concatenated dataframe to the `games` dataframe we created earlier.
# - The `games` dataframe will have rows below it with missing data, so we'll have to do a forward-fill to populate those.

# %%
games = games.reset_index(drop = True)
periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded_statistics = periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded_statistics.reset_index(drop = True)

sportradar = pd.concat([games, periods_pbp_exploded_pbp_events_exploded_events_statistics_exploded_statistics], axis=1)

# %%
# Max column width so we can read play descriptions
pd.set_option('display.max_colwidth', None)

# %%
# Check for duplicate columns
column_names = list(sportradar.columns)
duplicate_columns = set([x for x in column_names if column_names.count(x) > 1])
duplicate_columns_list = list(duplicate_columns)
duplicate_columns_list
# Out:
# []

# %% [markdown]
# Forward-filling here to make sure every row has the game data from top row

# %%
# Forward-fill rows with null values for game columns

# Columns to forward fill
columns_to_fill = [
    'game_id', 'weather.condition', 'weather.humidity', 'weather.temp', 'weather.wind.speed', 'summary.season.year', 'summary.season.type',
    'summary.week.sequence', 'summary.venue.surface', 'summary.venue.roof_type', 'summary.home.alias', 'summary.away.alias'
]

# Applying forward fill to the specified columns
sportradar[columns_to_fill] = sportradar[columns_to_fill].ffill()

# Displaying the first few rows to verify the changes
sportradar.head()
# Out:
#                                 game_id              sr_id  \
# 0  7d06369a-382a-448a-b295-6da9eab53245  sr:match:27305854
# 1  7d06369a-382a-448a-b295-6da9eab53245                NaN
# 2  7d06369a-382a-448a-b295-6da9eab53245                NaN
# 3  7d06369a-382a-448a-b295-6da9eab53245                NaN
# 4  7d06369a-382a-448a-b295-6da9eab53245                NaN
#
#     weather.condition  weather.humidity  weather.temp  weather.wind.speed  \
# 0  Controlled Climate                44            77                   7
# 1  Controlled Climate                44            77                   7
# 2  Controlled Climate                44            77                   7
# 3  Controlled Climate                44            77                   7
# 4  Controlled Climate                44            77                   7
#
#    summary.season.year summary.season.type  summary.week.sequence  \
# 0                 2021                 REG                      3
# 1                 2021                 REG                      3
# 2                 2021                 REG                      3
# 3                 2021                 REG                      3
# 4                 2021                 REG                      3
#
#   summary.venue.surface summary.venue.roof_type summary.home.alias  \
# 0            artificial                    dome                MIN
# 1            artificial                    dome                MIN
# 2            artificial                    dome                MIN
# 3            artificial                    dome                MIN
# 4            artificial                    dome                MIN
#
#   summary.away.alias period_type  number  \
# 0                SEA     quarter       1
# 1                SEA     quarter       1
# 2                SEA     quarter       1
# 3                SEA     quarter       1
# 4                SEA     quarter       1
#
#                         scoring.home.id scoring.home.alias  \
# 0  33405046-04ee-4058-a950-d606f8c30852                MIN
# 1  33405046-04ee-4058-a950-d606f8c30852                MIN
# 2  33405046-04ee-4058-a950-d606f8c30852                MIN
# 3  33405046-04ee-4058-a950-d606f8c30852                MIN
# 4  33405046-04ee-4058-a950-d606f8c30852                MIN
#
#    scoring.home.sr_id                       scoring.away.id  \
# 0  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 1  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 2  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 3  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 4  sr:competitor:4423  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
#
#   scoring.away.alias  scoring.away.sr_id  \
# 0                SEA  sr:competitor:4430
# 1                SEA  sr:competitor:4430
# 2                SEA  sr:competitor:4430
# 3                SEA  sr:competitor:4430
# 4                SEA  sr:competitor:4430
#
#                                event_id  team_sequence  type  \
# 0  01ebde76-2065-4995-8871-5156d235c3fd              1  play
# 1  01ebde76-2065-4995-8871-5156d235c3fd              1  play
# 2  01ebde76-2065-4995-8871-5156d235c3fd              1  play
# 3  01ebde76-2065-4995-8871-5156d235c3fd              1  play
# 4  01ebde76-2065-4995-8871-5156d235c3fd              1  play
#
#                                 play_id  clock  home_points  away_points  \
# 0  e62ee710-1eff-11ec-a67f-c75e589fa3a4  15:00            0            0
# 1  e62ee710-1eff-11ec-a67f-c75e589fa3a4  15:00            0            0
# 2  f72f3120-1f07-11ec-a67f-c75e589fa3a4  15:00            0            0
# 3  f72f3120-1f07-11ec-a67f-c75e589fa3a4  15:00            0            0
# 4  f72f3120-1f07-11ec-a67f-c75e589fa3a4  15:00            0            0
#
#   play_type                 wall_clock  \
# 0   kickoff  2021-09-26T20:25:58+00:00
# 1   kickoff  2021-09-26T20:25:58+00:00
# 2      pass  2021-09-26T20:26:38+00:00
# 3      pass  2021-09-26T20:26:38+00:00
# 4      pass  2021-09-26T20:26:38+00:00
#
#                                                                                                                         description  \
# 0                                                               G.Joseph kicks 65 yards from MIN 35 to the SEA End Zone. Touchback.
# 1                                                               G.Joseph kicks 65 yards from MIN 35 to the SEA End Zone. Touchback.
# 2  R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
# 3  R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
# 4  R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
#
#   fake_punt fake_field_goal screen_pass hash_mark play_action run_pass_option  \
# 0     False           False       False    Middle       False           False
# 1     False           False       False    Middle       False           False
# 2     False           False       False    Middle        True           False
# 3     False           False       False    Middle        True           False
# 4     False           False       False    Middle        True           False
#
#   start_situation.clock  start_situation.down  start_situation.yfd  \
# 0                 15:00                     0                    0
# 1                 15:00                     0                    0
# 2                 15:00                     1                   10
# 3                 15:00                     1                   10
# 4                 15:00                     1                   10
#
#   start_situation.possession.alias start_situation.location.alias  \
# 0                              MIN                            MIN
# 1                              MIN                            MIN
# 2                              SEA                            SEA
# 3                              SEA                            SEA
# 4                              SEA                            SEA
#
#    start_situation.location.yardline end_situation.clock  end_situation.down  \
# 0                                 35               15:00                   1
# 1                                 35               15:00                   1
# 2                                 25               14:24                   1
# 3                                 25               14:24                   1
# 4                                 25               14:24                   1
#
#    end_situation.yfd end_situation.possession.alias  \
# 0                 10                            SEA
# 1                 10                            SEA
# 2                 10                            SEA
# 3                 10                            SEA
# 4                 10                            SEA
#
#   end_situation.location.alias  end_situation.location.yardline  \
# 0                          SEA                               25
# 1                          SEA                               25
# 2                          SEA                               42
# 3                          SEA                               42
# 4                          SEA                               42
#
#    players_rushed  men_in_box play_direction  left_tightends  right_tightends  \
# 0             NaN         NaN            NaN             NaN              NaN
# 1             NaN         NaN            NaN             NaN              NaN
# 2               4           7          Right               0                2
# 3               4           7          Right               0                2
# 4               4           7          Right               0                2
#
#   pocket_location    qb_at_snap  huddle pass_route scoring_play  \
# 0             NaN           NaN     NaN        NaN          NaN
# 1             NaN           NaN     NaN        NaN          NaN
# 2      Boot Right  Under Center  Huddle      Cross          NaN
# 3      Boot Right  Under Center  Huddle      Cross          NaN
# 4      Boot Right  Under Center  Huddle      Cross          NaN
#
#   scoring_description stat_type  attempt  yards  \
# 0                 NaN      kick        1     65
# 1                 NaN    return      NaN    NaN
# 2                 NaN      pass        1     17
# 3                 NaN   receive      NaN     17
# 4                 NaN   defense      NaN    NaN
#
#                               player.id     player.name player.jersey  \
# 0  a2aab80d-174c-4639-beac-e2b70bb3625f     Greg Joseph            01
# 1                                   NaN             NaN           NaN
# 2  409d4cac-ee90-4470-9710-ebe671678339  Russell Wilson            03
# 3  754faf0f-40f7-45f0-b23b-6ce990ecaf26      DK Metcalf            14
# 4  c44b31cd-0480-4aa0-b500-12e9ba0765ac      Nick Vigil            59
#
#   player.position       player.sr_id                               team.id  \
# 0               K  sr:player:1184234  33405046-04ee-4058-a950-d606f8c30852
# 1             NaN                NaN  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 2              QB   sr:player:831309  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 3              WR  sr:player:1230010  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8
# 4              LB  sr:player:1074088  33405046-04ee-4058-a950-d606f8c30852
#
#   team.alias          team.sr_id  complete  att_yards  firstdown  inside_20  \
# 0        MIN  sr:competitor:4423       NaN        NaN        NaN        NaN
# 1        SEA  sr:competitor:4430       NaN        NaN        NaN        NaN
# 2        SEA  sr:competitor:4430         1         11          1          0
# 3        SEA  sr:competitor:4430       NaN        NaN          1          0
# 4        MIN  sr:competitor:4423       NaN        NaN        NaN        NaN
#
#    goaltogo  blitz  hurry  knockdown  pocket_time  on_target_throw  \
# 0       NaN    NaN    NaN        NaN          NaN              NaN
# 1       NaN    NaN    NaN        NaN          NaN              NaN
# 2         0      0      1          0            3                1
# 3         0    NaN    NaN        NaN          NaN              NaN
# 4       NaN      0      0          0          NaN              NaN
#
#    batted_pass  target  reception  yards_after_catch  dropped  catchable  \
# 0          NaN     NaN        NaN                NaN      NaN        NaN
# 1          NaN     NaN        NaN                NaN      NaN        NaN
# 2            0     NaN        NaN                NaN      NaN        NaN
# 3          NaN       1          1                  6        0          0
# 4            0     NaN        NaN                NaN      NaN        NaN
#
#    def_target  tackle  broken_tackles  yards_after_contact incompletion_type  \
# 0         NaN     NaN             NaN                  NaN               NaN
# 1         NaN     NaN             NaN                  NaN               NaN
# 2         NaN     NaN             NaN                  NaN               NaN
# 3         NaN     NaN             NaN                  NaN               NaN
# 4           1     NaN             NaN                  NaN               NaN
#
#    touchdown  endzone
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN

# %% [markdown]
# ## Modify dataset
# - We're now filtering our dataframe for pass plays
#   - We want the rows for the passer, receiver, and defensive pass interferences
#      - DPIs are a good indication of a receiver's skills because a defender feels he must commit DPI to defend against a catch

# %%
# Filter for padd and receive plays
sportradar = sportradar[
                        (sportradar['stat_type'] == 'pass') 
                        | (sportradar['stat_type'] == 'receive') 
                        | (
                           (sportradar['stat_type'] == 'penalty')
                           & (sportradar['description'].str.contains('defensive pass interference', case = False, na = False))
                          )
                        ]

# %% [markdown]
# ### Transfer passer-specific columns to receiver-specific rows
# - Here, we create new dummy columns for the passers and defenders if they committed DPI

# %%
# Create dummy column for quarterback name
sportradar['alias'] = sportradar.loc[sportradar['stat_type'] == 'pass']['player.name']
sportradar['alias'] = sportradar['alias'].apply(str)

# Create dummy column for defender name
sportradar['name'] = sportradar.loc[sportradar['stat_type'] == 'penalty']['player.name']
sportradar['name'] = sportradar['name'].apply(str)

# %%
sportradar['alias'].unique(), sportradar['alias'].dtype
# Out:
# (array(['Russell Wilson', 'nan', 'Kirk Cousins'], dtype=object), dtype('O'))

# %% [markdown]
# - We checked to make sure that Russell Wilson and Kirk Cousins are the only unique values for this column.
# - They were the only passers in this game.

# %%
# # Loop through the DataFrame and transfer passer data to receiver rows
# for idx, row in sportradar.iterrows():
#     if row['stat_type'] == 'pass':
#         # Find the corresponding receiver row for the same play
#         receiver_idx = sportradar[(sportradar['play_id'] == row['play_id']) & (sportradar['stat_type'] == 'receive')].index
#         # Update the receiver row with the passer data
#         if len(receiver_idx) > 0:
#             sportradar.loc[receiver_idx, 'qb_complete'] = row['complete']
#             sportradar.loc[receiver_idx, 'qb_att_yards'] = row['att_yards']
#             sportradar.loc[receiver_idx, 'qb_blitz'] = row['c']
#             sportradar.loc[receiver_idx, 'qb_hurry'] = row['hurry']
#             sportradar.loc[receiver_idx, 'qb_knockdown'] = row['knockdown']
#             sportradar.loc[receiver_idx, 'qb_pocket_time'] = row['pocket_time']
#             sportradar.loc[receiver_idx, 'qb_on_target_throw'] = row['on_target_throw']
#             sportradar.loc[receiver_idx, 'qb_batted_pass'] = row['batted_pass']
#             sportradar.loc[receiver_idx, 'qb_incompletion_type'] = row['incompletion_type']
#             sportradar.loc[receiver_idx, 'qb_name'] = row['alias']
            
# for idx, row in sportradar.iterrows():
#     if row['stat_type'] == 'penalty':
#         # Find the corresponding receiver row for the same play
#         defender_idx = sportradar[(sportradar['play_id'] == row['play_id']) & (sportradar['stat_type'] == 'receive')].index
#         # Update the receiver row with the passer data
#         if len(receiver_idx) > 0:
#             sportradar.loc[defender_idx, 'defender_name'] = row['name']

# # Create separate dataframe
# sportradar_wr = sportradar[sportradar['stat_type'] == 'receive'].copy()

# # Drop passer-specific columns in new dataframe
# sportradar_wr.drop(['complete', 'att_yards', 'blitz', 'hurry', 'knockdown', 'pocket_time', 'on_target_throw', 'batted_pass', 'incompletion_type'], axis=1, inplace=True, errors = 'ignore')

# %% [markdown]
# #### Passer data
# - Here, we create a separate passer data dataframe
# - We also create new columns that are just renamed versions of passer-specific columns
#   - Although these fields relate to the passer, they could still be helpful in understanding how a receiver plays
#     - e.g. Can a receiver be a primary target to "bail out" the QB when he's under duress (blitzed, hurried, or knocked down)?

# %%
# Extract passer data
passer_data = sportradar[sportradar['stat_type'] == 'pass'].copy()

# Rename passer columns
passer_columns = {
    'complete': 'qb_complete', 
    'att_yards': 'qb_att_yards', 
    'blitz': 'qb_blitz',
    'hurry': 'qb_hurry',
    'knockdown': 'qb_knockdown',
    'pocket_time': 'qb_pocket_time',
    'on_target_throw': 'qb_on_target_throw',
    'batted_pass': 'qb_batted_pass',
    'incompletion_type': 'qb_incompletion_type',
    'alias': 'qb_name'
}
passer_data.rename(columns=passer_columns, inplace=True)

# %% [markdown]
# #### Defender data
# - We do the same for defenders too

# %%
# Extract defender data
defender_data = sportradar[sportradar['stat_type'] == 'penalty'].copy()

# Rename defender columns (assuming 'name' represents defender's name)
defender_data.rename(columns={'name': 'defender_name'}, inplace=True)

# %% [markdown]
# #### Bringing the passer data into the receiver dataframe

# %%
# Extract receiver data and create a separate dataframe for it
sportradar_wr = sportradar[sportradar['stat_type'] == 'receive'].copy()

# Merge receiver data with passer data
# Can merge on the `play_id` field
sportradar_wr = sportradar_wr.merge(passer_data[['play_id', 'qb_complete', 'qb_att_yards', 'qb_blitz', 'qb_hurry', 'qb_knockdown', 'qb_pocket_time', 'qb_on_target_throw', 'qb_batted_pass', 'qb_incompletion_type', 'qb_name'
                                                ]], on='play_id', how='left')

# Merge receiver data with defender data
sportradar_wr = sportradar_wr.merge(defender_data[['play_id', 'defender_name']], on='play_id', how='left')

# Drop old passer-specific columns
sportradar_wr.drop(['complete', 'att_yards', 'blitz', 'hurry', 'knockdown', 'pocket_time', 'on_target_throw', 'batted_pass', 'incompletion_type', 'alias', 'name'], axis=1, inplace=True, errors = 'ignore')

# %% [markdown]
# We effectively filtered the game dataframe for the `receive` plays and then pulled in select passer-specific columns that are relevant to a receiver's playing style.

# %%
sportradar_wr.columns
# Out:
# Index(['game_id', 'sr_id', 'weather.condition', 'weather.humidity',
#        'weather.temp', 'weather.wind.speed', 'summary.season.year',
#        'summary.season.type', 'summary.week.sequence', 'summary.venue.surface',
#        'summary.venue.roof_type', 'summary.home.alias', 'summary.away.alias',
#        'period_type', 'number', 'scoring.home.id', 'scoring.home.alias',
#        'scoring.home.sr_id', 'scoring.away.id', 'scoring.away.alias',
#        'scoring.away.sr_id', 'event_id', 'team_sequence', 'type', 'play_id',
#        'clock', 'home_points', 'away_points', 'play_type', 'wall_clock',
#        'description', 'fake_punt', 'fake_field_goal', 'screen_pass',
#        'hash_mark', 'play_action', 'run_pass_option', 'start_situation.clock',
#        'start_situation.down', 'start_situation.yfd',
#        'start_situation.possession.alias', 'start_situation.location.alias',
#        'start_situation.location.yardline', 'end_situation.clock',
#        'end_situation.down', 'end_situation.yfd',
#        'end_situation.possession.alias', 'end_situation.location.alias',
#        'end_situation.location.yardline', 'players_rushed', 'men_in_box',
#        'play_direction', 'left_tightends', 'right_tightends',
#        'pocket_location', 'qb_at_snap', 'huddle', 'pass_route', 'scoring_play',
#        'scoring_description', 'stat_type', 'attempt', 'yards', 'player.id',
#        'player.name', 'player.jersey', 'player.position', 'player.sr_id',
#        'team.id', 'team.alias', 'team.sr_id', 'firstdown', 'inside_20',
#        'goaltogo', 'target', 'reception', 'yards_after_catch', 'dropped',
#        'catchable', 'def_target', 'tackle', 'broken_tackles',
#        'yards_after_contact', 'touchdown', 'endzone', 'qb_complete',
#        'qb_att_yards', 'qb_blitz', 'qb_hurry', 'qb_knockdown',
#        'qb_pocket_time', 'qb_on_target_throw', 'qb_batted_pass',
#        'qb_incompletion_type', 'qb_name', 'defender_name'],
#       dtype='object')

# %% [markdown]
# On DPI calls, the reception will be recorded as a null instead of a 0. Let's change these nulls to zeroes.

# %%
# Change reception nulls to zeros
sportradar_wr['reception'].fillna(0, inplace = True)

# %% [markdown]
# ### Delete columns that aren't in all games
# - Some game datasets have columns that differ slightly

# %%
sportradar_wr = sportradar_wr.drop(columns = ['game_type','weather.condition', 'lost','opp_rec','opp_rec_yards','interception','int_touchdown','int_yards'], errors = 'ignore')

# %% [markdown]
# ### Delete unnecesary columns
# - There are other versions of these columns that effectively say the same thing. These can be dropped.
# - Examples include home team, away team, player ID, game clock, and description
# - I know these columns are redundant having looked at all the columns before.

# %%
sportradar_wr = sportradar_wr.drop(columns = ['sr_id', 'type', 'play_type', 'stat_type', 'scoring.home.id', 'scoring.away.id', 'player.id', 'team.id', 'scoring.home.alias', 'scoring.away.alias', 'clock', 'wall_clock', 'scoring_description', 'attempt', 'start_situation_possession_alias',
                                                'end_situation_possession_alias',], errors = 'ignore')

# %% [markdown]
# ### Suffix removal
# - Removing some suffixes that only take up more column width
# - Also replacing periods with dashes

# %%
sportradar_wr = sportradar_wr.rename(columns = {col: col.replace('weather.', '') for col in sportradar_wr.columns})
# sportradar_wr.columns

# %%
sportradar_wr = sportradar_wr.rename(columns = {col: col.replace('summary.', '') for col in sportradar_wr.columns})
# sportradar_wr.columns

# %%
sportradar_wr = sportradar_wr.rename(columns = {col: col.replace('scoring.', '') for col in sportradar_wr.columns})
# sportradar_wr.columns

# %%
sportradar_wr = sportradar_wr.rename(columns = {col: col.replace('.', '_') for col in sportradar_wr.columns})
# sportradar_wr.columns

# %% [markdown]
# ### Overtime adjustment
# - For simplicity's sake, we should change the overtime period number from 1 to 5, and then drop the `period_type` column altogether.

# %%
sportradar_wr.loc[(sportradar_wr['period_type'] == 'overtime') & (sportradar_wr['number'] == 1), 'number'] = 5
sportradar_wr = sportradar_wr.drop(columns = ['period_type'], errors = 'ignore')

# %% [markdown]
# Tidying up some field names

# %%
sportradar_wr = sportradar_wr.rename(columns={'week_sequence': 'week', 'number': 'period', 'start_situation_clock': 'start_play_clock', 'start_situation_down': 'start_play_down', 'start_situation_yfd': 'start_play_yfd', 'start_situation_possession_alias': 'start_play_possession_alias', 'start_situation_location_yardline': 'start_play_yardline', 
                                              'start_situation_location_alias': 'start_play_field_side', 'end_situation_clock': 'end_play_clock', 'end_situation_down': 'end_play_down', 'end_situation_yfd': 'end_play_yfd', 'end_situation_possession_alias': 'end_play_possession_alias', 'end_situation_location_yardline': 'end_play_yardline', 
                                              'end_situation_location_alias': 'end_play_field_side', 'qb_blitz': 'blitz', 'qb_hurry': 'hurry', 'qb_knockdown': 'knockdown', 'qb_pocket_time': 'pocket_time', 'qb_complete': 'complete', 'qb_on_target_throw': 'on_target_throw', 'qb_batted_pass': 'batted_pass', 'qb_incompletion_type': 'incompletion_type', 'qb_att_yards': 'att_yards'})

# %%
sportradar_wr.columns
# Out:
# Index(['game_id', 'humidity', 'temp', 'wind_speed', 'season_year',
#        'season_type', 'week', 'venue_surface', 'venue_roof_type', 'home_alias',
#        'away_alias', 'period', 'home_sr_id', 'away_sr_id', 'event_id',
#        'team_sequence', 'play_id', 'home_points', 'away_points', 'description',
#        'fake_punt', 'fake_field_goal', 'screen_pass', 'hash_mark',
#        'play_action', 'run_pass_option', 'start_play_clock', 'start_play_down',
#        'start_play_yfd', 'start_play_possession_alias',
#        'start_play_field_side', 'start_play_yardline', 'end_play_clock',
#        'end_play_down', 'end_play_yfd', 'end_play_possession_alias',
#        'end_play_field_side', 'end_play_yardline', 'players_rushed',
#        'men_in_box', 'play_direction', 'left_tightends', 'right_tightends',
#        'pocket_location', 'qb_at_snap', 'huddle', 'pass_route', 'scoring_play',
#        'yards', 'player_name', 'player_jersey', 'player_position',
#        'player_sr_id', 'team_alias', 'team_sr_id', 'firstdown', 'inside_20',
#        'goaltogo', 'target', 'reception', 'yards_after_catch', 'dropped',
#        'catchable', 'def_target', 'tackle', 'broken_tackles',
#        'yards_after_contact', 'touchdown', 'endzone', 'complete', 'att_yards',
#        'blitz', 'hurry', 'knockdown', 'pocket_time', 'on_target_throw',
#        'batted_pass', 'incompletion_type', 'qb_name', 'defender_name'],
#       dtype='object')

# %% [markdown]
# ### Clock columns
# - Creating string versions of the play clock start, play clock end, and pocket times for easier readability
# - Converting the original string versions of the play clock fields to timedeltas.

# %%
# For time display in string format
sportradar_wr['start_play_clock_string'] = sportradar_wr['start_play_clock']
sportradar_wr['end_play_clock_string'] = sportradar_wr['end_play_clock']
sportradar_wr['pocket_time_string'] = sportradar_wr['pocket_time'].map('{:,.2f}'.format)

# To convert to timedelta
sportradar_wr['start_play_clock'] = pd.to_timedelta('00:' + sportradar_wr['start_play_clock'])
sportradar_wr['end_play_clock'] = pd.to_timedelta('00:' + sportradar_wr['end_play_clock'])

# %%
sportradar_wr['start_play_clock_string'].head()
# Out:
# 0    15:00
# 1    12:50
# 2    11:24
# 3    10:32
# 4     9:51
# Name: start_play_clock_string, dtype: object

# %% [markdown]
# ### Yardline adjustment
# - If the possession team is on its side of the field, 50 yards is added to the yardline
#   - This will make it easier to verify play distances

# %%
sportradar_wr.loc[(sportradar_wr['team_alias']) == (sportradar_wr['start_play_field_side'])][['start_play_field_side', 'team_alias', 'start_play_clock', 'start_play_down', 'start_play_yardline', 'end_play_yardline', 'description']]
# Out:
#    start_play_field_side team_alias start_play_clock  start_play_down  \
# 0                    SEA        SEA  0 days 00:15:00                1
# 4                    MIN        MIN  0 days 00:09:51                2
# 9                    SEA        SEA  0 days 00:05:14                3
# 10                   SEA        SEA  0 days 00:04:38                1
# 13                   MIN        MIN  0 days 00:15:00                2
# 14                   MIN        MIN  0 days 00:14:56                3
# 15                   SEA        SEA  0 days 00:14:09                1
# 16                   MIN        MIN  0 days 00:11:07                1
# 17                   MIN        MIN  0 days 00:09:40                1
# 22                   SEA        SEA  0 days 00:05:23                1
# 23                   SEA        SEA  0 days 00:04:41                2
# 26                   MIN        MIN  0 days 00:03:04                2
# 33                   SEA        SEA  0 days 00:00:16                1
# 34                   SEA        SEA  0 days 00:00:09                1
# 35                   SEA        SEA  0 days 00:00:01                1
# 36                   MIN        MIN  0 days 00:13:46                1
# 37                   MIN        MIN  0 days 00:13:02                2
# 43                   SEA        SEA  0 days 00:04:38                3
# 44                   MIN        MIN  0 days 00:03:48                1
# 45                   MIN        MIN  0 days 00:03:08                2
# 46                   MIN        MIN  0 days 00:01:49                2
# 47                   MIN        MIN  0 days 00:01:40                3
# 51                   SEA        SEA  0 days 00:13:21                2
# 52                   SEA        SEA  0 days 00:12:53                1
# 53                   SEA        SEA  0 days 00:12:33                2
# 54                   SEA        SEA  0 days 00:11:52                3
# 55                   MIN        MIN  0 days 00:10:24                2
# 58                   SEA        SEA  0 days 00:04:31                1
# 59                   SEA        SEA  0 days 00:04:12                1
# 62                   MIN        MIN  0 days 00:02:08                3
# 63                   SEA        SEA  0 days 00:00:23                1
# 64                   SEA        SEA  0 days 00:00:19                2
# 65                   SEA        SEA  0 days 00:00:13                1
# 66                   SEA        SEA  0 days 00:00:09                2
#
#     start_play_yardline  end_play_yardline  \
# 0                    25                 42
# 4                    37                 43
# 9                    28                 38
# 10                   38                 50
# 13                   27                 27
# 14                   27                 27
# 15                   35                 44
# 16                   15                 21
# 17                   27                 50
# 22                   21                 28
# 23                   28                 33
# 26                   36                 43
# 33                   25                 37
# 34                   37                 48
# 35                   48                 21
# 36                   37                 33
# 37                   33                 48
# 43                   27                 32
# 44                   15                 14
# 45                   14                 35
# 46                   40                 40
# 47                   40                 49
# 51                   26                 40
# 52                   40                 46
# 53                   46                 43
# 54                   43                 43
# 55                   44                 42
# 58                   25                 44
# 59                   44                 41
# 62                   45                 44
# 63                    1                  8
# 64                    8                 25
# 65                   25                 25
# 66                   25                 40
#
#                                                                                                                                                                                                                                                                                                                                                                                                  description
# 0                                                                                                                                                                                                                                                                           R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
# 4                                                                                                                                                                                                                                                                          K.Cousins pass short left complete to MIN 35. Catch made by A.Mattison at MIN 35. Gain of 20 yards. Tackled by J.Adams at SEA 43.
# 9                                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 36. Catch made by F.Swain at SEA 36. Gain of 10 yards. Tackled by B.Breeland at SEA 38.
# 10                                                                                                                                                                                                                                                                      R.Wilson pass short middle complete to SEA 50. Catch made by D.Metcalf at SEA 50. Gain of 12 yards. Tackled by B.Breeland at MIN 50.
# 13                                                                                                                                                                                                                                                                                                               K.Cousins steps back to pass. K.Cousins pass incomplete short right intended for T.Conklin.
# 14                                                                                                                                                                                                                                                                                                    K.Cousins steps back to pass. K.Cousins pass incomplete short right intended for A.Thielen (C.Dunlap).
# 15                                                                                                                                                                                                                                                               R.Wilson pass deep left complete to MIN 45. Catch made by D.Metcalf at MIN 45. Gain of 21 yards. Pushed out of bounds by X.Woods at MIN 44.
# 16                                                                                                                                                                                                                                                                       K.Cousins pass short middle complete to MIN 18. Catch made by A.Mattison at MIN 18. Gain of 6 yards. Tackled by J.Brooks at MIN 21.
# 17                                                                                                                                                                                                                                                                        K.Cousins pass short right complete to MIN 24. Catch made by A.Mattison at MIN 24. Gain of 23 yards. Tackled by U.Amadi at MIN 50.
# 22                                                                                                                                                                                                                                                                             R.Wilson pass short middle complete to SEA 17. Catch made by P.Hart at SEA 17. Gain of 7 yards. Tackled by H.Smith at SEA 28.
# 23                                                                                                                                                                                                                                                           R.Wilson pass short left complete to SEA 37. Catch made by W.Dissly at SEA 37. Gain of 39 yards. Pushed out of bounds by E.Kendricks at MIN 33.
# 26                                                                                                                                                                                                                                                                  K.Cousins pass short left complete to MIN 33. Catch made by A.Mattison at MIN 33. Gain of 7 yards. Tackled by J.Adams, P.Ford at MIN 43.
# 33                                                                                                                                                                                                                                                              R.Wilson pass short middle complete to SEA 30. Catch made by T.Homer at SEA 30. Gain of 12 yards. Tackled by N.Vigil, E.Kendricks at SEA 37.
# 34                                                                                                                                                                                                                                                                     R.Wilson pass complete to SEA 37. Catch made by G.Everett at SEA 37. Gain of 11 yards. Pushed out of bounds by M.Alexander at SEA 48.
# 35                                                                                                                                                                                                                                                                             R.Wilson pass short left complete to SEA 47. Catch made by T.Homer at SEA 47. Gain of 31 yards. Tackled by C.Bynum at MIN 21.
# 36                                                                                                                                                                                                                                                                       K.Cousins pass short right complete to MIN 30. Catch made by A.Thielen at MIN 30. Gain of -4 yards. Tackled by J.Brooks at MIN 37.
# 37                                                                                                                                                                                                                                                             K.Cousins pass short left complete to MIN 43. Catch made by J.Jefferson at MIN 43. Gain of 15 yards. Tackled by T.Flowers, U.Amadi at MIN 48.
# 43                                                                                                                                                                                                                                                                             R.Wilson pass short left complete to SEA 21. Catch made by T.Homer at SEA 21. Gain of 5 yards. Tackled by D.Hunter at SEA 32.
# 44                                                                                                                                                                                                                                                              K.Cousins pass short left complete to MIN 12. Catch made by A.Mattison at MIN 12. Gain of -1 yards. Tackled by J.Adams, B.Wagner at MIN 15.
# 45                                                                                                                                                                                                                                                                                     K.Cousins pass complete to MIN 33. Catch made by A.Thielen at MIN 33. Gain of 21 yards. Tackled by Q.Diggs at MIN 35.
# 46                                                                                                                                                                                                                                                                                                               K.Cousins steps back to pass. K.Cousins pass incomplete short right intended for A.Thielen.
# 47                                                                                                                                                                                                                                                   K.Cousins pass short right complete to MIN 46. Catch made by K.Osborn at MIN 46. Gain of 11 yards. Pushed out of bounds by Q.Diggs, J.Brooks at SEA 49.
# 51                                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 30. Catch made by G.Everett at SEA 30. Gain of 14 yards. Tackled by N.Vigil at SEA 40.
# 52  R.Wilson pass complete to SEA 46. Catch made by T.Lockett at SEA 46. Gain of 6 yards. T.Lockett FUMBLES, forced by B.Breeland. Fumble RECOVERED by MIN-D.Hunter at SEA 44. Tackled by at SEA 44. The Replay Official reviewed the fumble and the play was overturned. R.Wilson pass short right complete to SEA 46. Catch made by T.Lockett at SEA 46. Gain of 6 yards. Tackled by B.Breeland at SEA 46.
# 53                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 38. Catch made by C.Carson at SEA 38. Gain of -3 yards. Pushed out of bounds by E.Kendricks at SEA 43.
# 54                                                                                                                                                                                                                                                                                                                  R.Wilson steps back to pass. R.Wilson pass incomplete short middle intended for F.Swain.
# 55                                                                                                                                                                                                                                                            K.Cousins pass short right complete to SEA 49. Catch made by T.Conklin at SEA 49. Gain of 14 yards. Pushed out of bounds by J.Adams at SEA 42.
# 58                                                                                                                                                                                                                                                                           R.Wilson pass short left complete to SEA 40. Catch made by D.Metcalf at SEA 40. Gain of 19 yards. Tackled by H.Smith at SEA 44.
# 59                                                                                                                                                                                                                                     R.Wilson steps back to pass. R.Wilson pass incomplete short right intended for T.Lockett. PENALTY on MIN-E.Griffen, Roughing the Passer, 15 yards, accepted. No Play.
# 62                                                                                                                                                                                                                                                                      K.Cousins pass short right complete to SEA 44. Catch made by J.Jefferson at SEA 44. Gain of 11 yards. J.Jefferson ran out of bounds.
# 63                                                                                                                                                                                                                                                                              R.Wilson pass short right complete to SEA 8. Catch made by G.Everett at SEA 8. Gain of 7 yards. G.Everett ran out of bounds.
# 64                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 17. Catch made by G.Everett at SEA 17. Gain of 17 yards. Pushed out of bounds by B.Breeland at SEA 25.
# 65                                                                                                                                                                                                                                                                                                                  R.Wilson steps back to pass. R.Wilson pass incomplete short left intended for D.Metcalf.
# 66                                                                                                                                                                                                                                                              R.Wilson pass short right complete to SEA 32. Catch made by T.Lockett at SEA 32. Gain of 15 yards. Tackled by B.Breeland, N.Vigil at SEA 40.

# %% [markdown]
# - If the Seahawks have the ball and the ball is on the Seahawks 32 yard line, the effective yard line is 68.
#   - 50 yards of opponent territory + 18 yards away from midfield line = 68 effective yard line

# %%
sportradar_wr['effective_start_play_yardline'] = sportradar_wr['start_play_yardline']
sportradar_wr.loc[(sportradar_wr['team_alias']) == (sportradar_wr['start_play_field_side']), 'effective_start_play_yardline'] = 50 - sportradar_wr['start_play_yardline'] + 50

# %% [markdown]
# - If the Seahawks have the ball and then end the play on the the Seahawks 39 yard line, the effective yard line is 61.
#   - 50 yards of opponent territory + 11 yards away from midfield line = 61 effective yard line

# %%
sportradar_wr['effective_end_play_yardline'] = sportradar_wr['end_play_yardline']
sportradar_wr.loc[(sportradar_wr['team_alias']) == (sportradar_wr['end_play_field_side']), 'effective_end_play_yardline'] = 50 - sportradar_wr['end_play_yardline'] + 50

# %% [markdown]
# ### Re-ordering columns

# %%
sportradar_wr = sportradar_wr[['game_id','season_year','season_type','week','home_alias' ,'home_sr_id','away_alias' ,'away_sr_id', 'temp' ,'humidity' ,'wind_speed' ,'venue_surface' ,'venue_roof_type' ,'period' ,'event_id',
                                'team_sequence','play_id','home_points' ,'away_points' ,'description','start_play_clock', 'start_play_clock_string', 'start_play_down' ,'start_play_yfd' ,'start_play_yardline', 'effective_start_play_yardline', 'start_play_field_side', 'inside_20' ,
                                'goaltogo' ,'end_play_clock','end_play_clock_string', 'end_play_down','end_play_yfd', 'end_play_yardline', 'effective_end_play_yardline', 'end_play_field_side', 'firstdown','scoring_play','players_rushed','men_in_box','huddle',
                                'hash_mark' ,'qb_at_snap' ,'left_tightends' ,'right_tightends', 'qb_name', 'pocket_location' ,'play_direction', 'screen_pass' ,'play_action' ,'run_pass_option' ,'pass_route' ,'fake_punt' ,'fake_field_goal',
                                'defender_name', 'player_name' ,'player_jersey','player_position','player_sr_id','team_alias' ,'team_sr_id', 'blitz' ,'hurry' ,'knockdown' ,'pocket_time', 'pocket_time_string', 'on_target_throw' ,'batted_pass',
                                'incompletion_type' ,'target' ,'reception' ,'yards' ,'att_yards' ,'yards_after_catch', 'yards_after_contact' ,'broken_tackles' ,'dropped','catchable', 'touchdown']]

# %%
sportradar_wr.head()
# Out:
#                                 game_id  season_year season_type  week  \
# 0  7d06369a-382a-448a-b295-6da9eab53245         2021         REG     3
# 1  7d06369a-382a-448a-b295-6da9eab53245         2021         REG     3
# 2  7d06369a-382a-448a-b295-6da9eab53245         2021         REG     3
# 3  7d06369a-382a-448a-b295-6da9eab53245         2021         REG     3
# 4  7d06369a-382a-448a-b295-6da9eab53245         2021         REG     3
#
#   home_alias          home_sr_id away_alias          away_sr_id  temp  \
# 0        MIN  sr:competitor:4423        SEA  sr:competitor:4430    77
# 1        MIN  sr:competitor:4423        SEA  sr:competitor:4430    77
# 2        MIN  sr:competitor:4423        SEA  sr:competitor:4430    77
# 3        MIN  sr:competitor:4423        SEA  sr:competitor:4430    77
# 4        MIN  sr:competitor:4423        SEA  sr:competitor:4430    77
#
#    humidity  wind_speed venue_surface venue_roof_type  period  \
# 0        44           7    artificial            dome       1
# 1        44           7    artificial            dome       1
# 2        44           7    artificial            dome       1
# 3        44           7    artificial            dome       1
# 4        44           7    artificial            dome       1
#
#                                event_id  team_sequence  \
# 0  01ebde76-2065-4995-8871-5156d235c3fd              1
# 1  01ebde76-2065-4995-8871-5156d235c3fd              1
# 2  01ebde76-2065-4995-8871-5156d235c3fd              1
# 3  01ebde76-2065-4995-8871-5156d235c3fd              1
# 4  b67eb032-3253-4577-9387-8461866cdec0              1
#
#                                 play_id  home_points  away_points  \
# 0  f72f3120-1f07-11ec-a67f-c75e589fa3a4            0            0
# 1  4c3a6ea0-1f08-11ec-a67f-c75e589fa3a4            0            0
# 2  8e3944c0-1f08-11ec-a67f-c75e589fa3a4            0            0
# 3  b0cb36b0-1f08-11ec-a67f-c75e589fa3a4            0            6
# 4  86a1cc40-1f09-11ec-a67f-c75e589fa3a4            0            7
#
#                                                                                                                            description  \
# 0     R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
# 1       R.Wilson pass short right complete to MIN 42. Catch made by C.Carson at MIN 42. Gain of 5 yards. Tackled by N.Vigil at MIN 40.
# 2      R.Wilson pass short left complete to MIN 27. Catch made by D.Metcalf at MIN 27. Gain of 28 yards. Tackled by H.Smith at MIN 10.
# 3  R.Wilson pass short right complete to MIN 3. Catch made by D.Metcalf at MIN 3. Gain of 10 yards. D.Metcalf for 10 yards, TOUCHDOWN.
# 4    K.Cousins pass short left complete to MIN 35. Catch made by A.Mattison at MIN 35. Gain of 20 yards. Tackled by J.Adams at SEA 43.
#
#   start_play_clock start_play_clock_string  start_play_down  start_play_yfd  \
# 0  0 days 00:15:00                   15:00                1              10
# 1  0 days 00:12:50                   12:50                1              10
# 2  0 days 00:11:24                   11:24                3               3
# 3  0 days 00:10:32                   10:32                2              10
# 4  0 days 00:09:51                    9:51                2               3
#
#    start_play_yardline  effective_start_play_yardline start_play_field_side  \
# 0                   25                             75                   SEA
# 1                   45                             45                   MIN
# 2                   38                             38                   MIN
# 3                   10                             10                   MIN
# 4                   37                             63                   MIN
#
#    inside_20  goaltogo  end_play_clock end_play_clock_string  end_play_down  \
# 0          0         0 0 days 00:14:24                 14:24              1
# 1          0         0 0 days 00:12:02                 12:02              2
# 2          0         0 0 days 00:10:41                 10:41              1
# 3          1         1 0 days 00:10:26                 10:26              0
# 4          0         0 0 days 00:09:11                  9:11              1
#
#    end_play_yfd  end_play_yardline  effective_end_play_yardline  \
# 0            10                 42                           58
# 1             5                 40                           40
# 2            10                 10                           10
# 3             0                 15                           15
# 4            10                 43                           43
#
#   end_play_field_side  firstdown scoring_play  players_rushed  men_in_box  \
# 0                 SEA          1          NaN               4           7
# 1                 MIN          0          NaN               4           7
# 2                 MIN          1          NaN               4           7
# 3                 MIN          1         True               4           7
# 4                 SEA          1          NaN               4           8
#
#       huddle   hash_mark    qb_at_snap  left_tightends  right_tightends  \
# 0     Huddle      Middle  Under Center               0                2
# 1  No Huddle  Right Hash       Shotgun               0                1
# 2  No Huddle  Right Hash       Shotgun               0                1
# 3     Huddle  Right Hash       Shotgun               0                1
# 4     Huddle      Middle  Under Center               0                1
#
#           qb_name pocket_location  play_direction screen_pass play_action  \
# 0  Russell Wilson      Boot Right           Right       False        True
# 1  Russell Wilson          Middle           Right       False        True
# 2  Russell Wilson          Middle            Left       False       False
# 3  Russell Wilson          Middle  Right Sideline       False       False
# 4    Kirk Cousins          Middle   Left Sideline        True        True
#
#   run_pass_option         pass_route fake_punt fake_field_goal defender_name  \
# 0           False              Cross     False           False           NaN
# 1            True               Curl     False           False           NaN
# 2           False               Post     False           False           NaN
# 3           False                Out     False           False           NaN
# 4           False  Underneath Screen     False           False           NaN
#
#           player_name player_jersey player_position       player_sr_id  \
# 0          DK Metcalf            14              WR  sr:player:1230010
# 1        Chris Carson            32              RB  sr:player:1130199
# 2          DK Metcalf            14              WR  sr:player:1230010
# 3          DK Metcalf            14              WR  sr:player:1230010
# 4  Alexander Mattison            25              RB  sr:player:1197616
#
#   team_alias          team_sr_id  blitz  hurry  knockdown  pocket_time  \
# 0        SEA  sr:competitor:4430      0      1          0            3
# 1        SEA  sr:competitor:4430      0      0          0            3
# 2        SEA  sr:competitor:4430      0      0          0            3
# 3        SEA  sr:competitor:4430      0      0          0            2
# 4        MIN  sr:competitor:4423      0      0          0            3
#
#   pocket_time_string  on_target_throw  batted_pass incompletion_type  target  \
# 0               3.13                1            0               NaN       1
# 1               3.08                1            0               NaN       1
# 2               3.21                1            0               NaN       1
# 3               1.74                1            0               NaN       1
# 4               2.57                1            0               NaN       1
#
#    reception  yards  att_yards  yards_after_catch  yards_after_contact  \
# 0          1     17         11                  6                  NaN
# 1          1      5          3                  2                    0
# 2          1     28         11                 17                    2
# 3          1     10          7                  3                    1
# 4          1     20         -2                 22                    2
#
#    broken_tackles  dropped  catchable  touchdown
# 0             NaN        0          0        NaN
# 1             NaN        0          0        NaN
# 2             NaN        0          0        NaN
# 3               1        0          0          1
# 4             NaN        0          0        NaN

# %% [markdown]
# ### Fixing receiver features

# %% [markdown]
# #### Poorly thrown passes
# - If the pass is poorly thrown, it should not be considered on target or catchable

# %%
sportradar_wr.loc[(sportradar_wr['on_target_throw'] == 1) & (sportradar_wr['incompletion_type'] == 'Poorly Thrown')][['play_id', 'period', 'start_play_clock_string', 'player_name', 'on_target_throw', 'catchable', 'incompletion_type', 'description']]
# Out:
#                                  play_id  period start_play_clock_string  \
# 42  ec090b40-1f16-11ec-a9c1-1b4016cb3a46       3                    7:28
# 54  dffcfdc0-1f1b-11ec-a9c1-1b4016cb3a46       4                   11:52
# 65  7a5aac60-1f20-11ec-a9c1-1b4016cb3a46       4                   00:13
#
#          player_name  on_target_throw  catchable incompletion_type  \
# 42  Justin Jefferson                1          0     Poorly Thrown
# 54     Freddie Swain                1          1     Poorly Thrown
# 65        DK Metcalf                1          0     Poorly Thrown
#
#                                                                                       description
# 42  K.Cousins steps back to pass. K.Cousins pass incomplete short right intended for J.Jefferson.
# 54       R.Wilson steps back to pass. R.Wilson pass incomplete short middle intended for F.Swain.
# 65       R.Wilson steps back to pass. R.Wilson pass incomplete short left intended for D.Metcalf.

# %%
sportradar_wr.loc[(sportradar_wr['on_target_throw'] == 1) & (sportradar_wr['incompletion_type'] == 'Poorly Thrown'), 'on_target_throw'] = 0

# %%
sportradar_wr.loc[(sportradar_wr['catchable'] == 1) & (sportradar_wr['incompletion_type'] == 'Poorly Thrown'), 'catchable'] = 0

# %% [markdown]
# #### Dropped passes
# - Change `on_target_throw` to 1
# - Change `catchable` to 1

# %%
sportradar_wr.loc[sportradar_wr['incompletion_type'] == 'Dropped Pass'][['play_id', 'period', 'start_play_clock_string', 'player_name', 'on_target_throw', 'catchable', 'incompletion_type', 'description']]
# Out:
#                                  play_id  period start_play_clock_string  \
# 29  976035e0-1f12-11ec-acc0-f76b8dd971ea       2                   00:38
#
#          player_name  on_target_throw  catchable incompletion_type  \
# 29  Justin Jefferson                1          1      Dropped Pass
#
#                                                                                       description
# 29  K.Cousins steps back to pass. K.Cousins pass incomplete short right intended for J.Jefferson.

# %%
sportradar_wr.loc[(sportradar_wr['on_target_throw'] == 0) & (sportradar_wr['incompletion_type'] == 'Dropped Pass'), 'on_target_throw'] = 1

# %%
sportradar_wr.loc[(sportradar_wr['catchable'] == 0) & (sportradar_wr['incompletion_type'] == 'Dropped Pass'), 'catchable'] = 1

# %% [markdown]
# #### Defended passes
# - If pass was not batted...
#   - Change `on_target_throw` to 1
#   - Change `catchable` to 1

# %%
sportradar_wr.loc[sportradar_wr['incompletion_type'] == 'Pass Defended'][['play_id', 'period', 'start_play_clock_string', 'player_name', 'on_target_throw', 'catchable', 'incompletion_type', 'description']]
# Out:
#                                  play_id  period start_play_clock_string  \
# 14  add74e40-1f0c-11ec-89e9-8992a3cbf855       2                   14:56
# 60  9f6be110-1f1e-11ec-a9c1-1b4016cb3a46       4                    2:46
# 61  bceea880-1f1e-11ec-a9c1-1b4016cb3a46       4                    2:36
#
#      player_name  on_target_throw  catchable incompletion_type  \
# 14  Adam Thielen                0          0     Pass Defended
# 60    DK Metcalf                1          1     Pass Defended
# 61    Penny Hart                1          1     Pass Defended
#
#                                                                                                description
# 14  K.Cousins steps back to pass. K.Cousins pass incomplete short right intended for A.Thielen (C.Dunlap).
# 60       R.Wilson steps back to pass. R.Wilson pass incomplete deep left intended for D.Metcalf (X.Woods).
# 61          R.Wilson steps back to pass. R.Wilson pass incomplete deep left intended for P.Hart (H.Smith).

# %%
sportradar_wr.loc[(sportradar_wr['on_target_throw'] == 0) & (sportradar_wr['incompletion_type'] == 'Pass Defended') & (sportradar_wr['batted_pass'] == False), 'on_target_throw'] = 1

# %%
sportradar_wr.loc[(sportradar_wr['catchable'] == 0) & (sportradar_wr['incompletion_type'] == 'Pass Defended') & (sportradar_wr['batted_pass'] == False), 'catchable'] = 1

# %% [markdown]
# #### Caught passes

# %%
sportradar_wr.loc[(sportradar_wr['catchable'] == 0) & (sportradar_wr['reception'] == 1)][['play_id', 'period', 'start_play_clock_string', 'player_name', 'on_target_throw', 'catchable', 'incompletion_type', 'description']]
# Out:
#                                  play_id  period start_play_clock_string  \
# 0   f72f3120-1f07-11ec-a67f-c75e589fa3a4       1                   15:00
# 1   4c3a6ea0-1f08-11ec-a67f-c75e589fa3a4       1                   12:50
# 2   8e3944c0-1f08-11ec-a67f-c75e589fa3a4       1                   11:24
# 3   b0cb36b0-1f08-11ec-a67f-c75e589fa3a4       1                   10:32
# 4   86a1cc40-1f09-11ec-a67f-c75e589fa3a4       1                    9:51
# 5   9e800700-1f09-11ec-a67f-c75e589fa3a4       1                    9:11
# 6   cf6a9c40-1f09-11ec-b36d-a3b2acec3de6       1                    8:32
# 7   dabe15e0-1f09-11ec-b36d-a3b2acec3de6       1                    7:54
# 8   f6cb0630-1f09-11ec-b36d-a3b2acec3de6       1                    6:42
# 9   ca06a590-1f0a-11ec-b36d-a3b2acec3de6       1                    5:14
# 10  e3c698a0-1f0a-11ec-b36d-a3b2acec3de6       1                    4:38
# 11  424963d0-1f0b-11ec-b36d-a3b2acec3de6       1                    2:04
# 12  7b593d30-1f0b-11ec-b36d-a3b2acec3de6       1                    1:24
# 15  128b2eb0-1f0d-11ec-89e9-8992a3cbf855       2                   14:09
# 16  113a9d60-1f0e-11ec-89e9-8992a3cbf855       2                   11:07
# 17  63a98520-1f0e-11ec-89e9-8992a3cbf855       2                    9:40
# 18  b25ceb80-1f0e-11ec-89e9-8992a3cbf855       2                    7:25
# 19  c2afd830-1f0e-11ec-89e9-8992a3cbf855       2                    6:45
# 21  19c341c0-1f0f-11ec-89e9-8992a3cbf855       2                    5:32
# 22  fbbeaab0-1f0f-11ec-89e9-8992a3cbf855       2                    5:23
# 23  0c9c7240-1f10-11ec-89e9-8992a3cbf855       2                    4:41
# 25  a9e83cf0-1f10-11ec-89e9-8992a3cbf855       2                    4:03
# 26  712b9730-1f11-11ec-acc0-f76b8dd971ea       2                    3:04
# 27  54079c20-1f12-11ec-acc0-f76b8dd971ea       2                    1:31
# 28  7b2b7240-1f12-11ec-acc0-f76b8dd971ea       2                   00:57
# 30  c448f1f0-1f12-11ec-acc0-f76b8dd971ea       2                   00:29
# 31  db457f40-1f12-11ec-acc0-f76b8dd971ea       2                   00:24
# 32  0a490500-1f13-11ec-acc0-f76b8dd971ea       2                   00:20
# 33  69b2d4d0-1f13-11ec-acc0-f76b8dd971ea       2                   00:16
# 34  93c195e0-1f13-11ec-acc0-f76b8dd971ea       2                   00:09
# 35  b904c520-1f13-11ec-acc0-f76b8dd971ea       2                   00:01
# 36  f5453310-1f15-11ec-a9c1-1b4016cb3a46       3                   13:46
# 37  17958820-1f16-11ec-a9c1-1b4016cb3a46       3                   13:02
# 38  362af810-1f16-11ec-a9c1-1b4016cb3a46       3                   12:05
# 40  8e79a0c0-1f16-11ec-a9c1-1b4016cb3a46       3                   10:03
# 41  be988190-1f16-11ec-a9c1-1b4016cb3a46       3                    8:48
# 43  067cc880-1f18-11ec-a9c1-1b4016cb3a46       3                    4:38
# 44  76099b60-1f18-11ec-a9c1-1b4016cb3a46       3                    3:48
# 45  af0f89b0-1f18-11ec-a9c1-1b4016cb3a46       3                    3:08
# 47  f896a0a0-1f18-11ec-a9c1-1b4016cb3a46       3                    1:40
# 48  2c26da70-1f19-11ec-a9c1-1b4016cb3a46       3                   00:21
# 49  53450b40-1f19-11ec-a9c1-1b4016cb3a46       4                   15:00
# 51  132d0ba0-1f1b-11ec-a9c1-1b4016cb3a46       4                   13:21
# 52  2d901c80-1f1b-11ec-a9c1-1b4016cb3a46       4                   12:53
# 53  be2e34c0-1f1b-11ec-a9c1-1b4016cb3a46       4                   12:33
# 55  94860840-1f1c-11ec-a9c1-1b4016cb3a46       4                   10:24
# 56  e07f57b0-1f1c-11ec-a9c1-1b4016cb3a46       4                    8:21
# 57  63975ee0-1f1d-11ec-a9c1-1b4016cb3a46       4                    4:54
# 58  25f47360-1f1e-11ec-a9c1-1b4016cb3a46       4                    4:31
# 62  4b97a780-1f1f-11ec-a9c1-1b4016cb3a46       4                    2:08
# 63  46f66490-1f20-11ec-a9c1-1b4016cb3a46       4                   00:23
# 64  6a04d980-1f20-11ec-a9c1-1b4016cb3a46       4                   00:19
# 66  857ae100-1f20-11ec-a9c1-1b4016cb3a46       4                   00:09
#
#            player_name  on_target_throw  catchable incompletion_type  \
# 0           DK Metcalf                1          0               NaN
# 1         Chris Carson                1          0               NaN
# 2           DK Metcalf                1          0               NaN
# 3           DK Metcalf                1          0               NaN
# 4   Alexander Mattison                1          0               NaN
# 5        Tyler Conklin                1          0               NaN
# 6     Justin Jefferson                1          0               NaN
# 7     Justin Jefferson                1          0               NaN
# 8        Tyler Conklin                1          0               NaN
# 9        Freddie Swain                1          0               NaN
# 10          DK Metcalf                1          0               NaN
# 11       Tyler Lockett                1          0               NaN
# 12      Gerald Everett                1          0               NaN
# 15          DK Metcalf                1          0               NaN
# 16  Alexander Mattison                1          0               NaN
# 17  Alexander Mattison                1          0               NaN
# 18    Justin Jefferson                1          0               NaN
# 19       Tyler Conklin                1          0               NaN
# 21        Adam Thielen                1          0               NaN
# 22          Penny Hart                1          0               NaN
# 23         Will Dissly                1          0               NaN
# 25       Tyler Lockett                1          0               NaN
# 26  Alexander Mattison                1          0               NaN
# 27  Alexander Mattison                1          0               NaN
# 28        Adam Thielen                1          0               NaN
# 30    Justin Jefferson                1          0               NaN
# 31       Tyler Conklin                1          0               NaN
# 32    Justin Jefferson                1          0               NaN
# 33        Travis Homer                1          0               NaN
# 34      Gerald Everett                1          0               NaN
# 35        Travis Homer                1          0               NaN
# 36        Adam Thielen                1          0               NaN
# 37    Justin Jefferson                1          0               NaN
# 38       Tyler Conklin                1          0               NaN
# 40    Justin Jefferson                1          0               NaN
# 41        Adam Thielen                1          0               NaN
# 43        Travis Homer                1          0               NaN
# 44  Alexander Mattison                1          0               NaN
# 45        Adam Thielen                1          0               NaN
# 47         K.J. Osborn                1          0               NaN
# 48    Justin Jefferson                1          0               NaN
# 49       Tyler Conklin                1          0               NaN
# 51      Gerald Everett                1          0               NaN
# 52       Tyler Lockett                1          0               NaN
# 53        Chris Carson                1          0               NaN
# 55       Tyler Conklin                1          0               NaN
# 56         K.J. Osborn                1          0               NaN
# 57        Adam Thielen                1          0               NaN
# 58          DK Metcalf                1          0               NaN
# 62    Justin Jefferson                1          0               NaN
# 63      Gerald Everett                1          0               NaN
# 64      Gerald Everett                1          0               NaN
# 66       Tyler Lockett                1          0               NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                  description
# 0                                                                                                                                                                                                                                                                           R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
# 1                                                                                                                                                                                                                                                                             R.Wilson pass short right complete to MIN 42. Catch made by C.Carson at MIN 42. Gain of 5 yards. Tackled by N.Vigil at MIN 40.
# 2                                                                                                                                                                                                                                                                            R.Wilson pass short left complete to MIN 27. Catch made by D.Metcalf at MIN 27. Gain of 28 yards. Tackled by H.Smith at MIN 10.
# 3                                                                                                                                                                                                                                                                        R.Wilson pass short right complete to MIN 3. Catch made by D.Metcalf at MIN 3. Gain of 10 yards. D.Metcalf for 10 yards, TOUCHDOWN.
# 4                                                                                                                                                                                                                                                                          K.Cousins pass short left complete to MIN 35. Catch made by A.Mattison at MIN 35. Gain of 20 yards. Tackled by J.Adams at SEA 43.
# 5                                                                                                                                                                                                                                                                         K.Cousins pass short left complete to SEA 32. Catch made by T.Conklin at SEA 32. Gain of 17 yards. Tackled by T.Flowers at SEA 26.
# 6                                                                                                                                                                                                                                                               K.Cousins pass short left complete to SEA 27. Catch made by J.Jefferson at SEA 27. Gain of 8 yards. Tackled by T.Flowers, J.Adams at SEA 18.
# 7                                                                                                                                                                                                                                                                        K.Cousins pass short left complete to SEA 13. Catch made by J.Jefferson at SEA 13. Gain of 10 yards. Tackled by T.Flowers at SEA 8.
# 8                                                                                                                                                                                                                                                                                     K.Cousins pass complete to SEA 1. Catch made by T.Conklin at SEA 1. Gain of 7 yards. T.Conklin for 7 yards, TOUCHDOWN.
# 9                                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 36. Catch made by F.Swain at SEA 36. Gain of 10 yards. Tackled by B.Breeland at SEA 38.
# 10                                                                                                                                                                                                                                                                      R.Wilson pass short middle complete to SEA 50. Catch made by D.Metcalf at SEA 50. Gain of 12 yards. Tackled by B.Breeland at MIN 50.
# 11                                                                                                                                                                                     R.Wilson pass short left complete to MIN 40. Catch made by T.Lockett at MIN 40. Gain of 3 yards. Tackled by H.Smith at MIN 30. PENALTY on SEA-A.Collins, Offensive Illegal Block Above the Waist, 10 yards, accepted.
# 12                                                                                                                                                                                                                                                                            R.Wilson pass short left complete to MIN 43. Catch made by G.Everett at MIN 43. Gain of 5 yards. Tackled by H.Smith at MIN 35.
# 15                                                                                                                                                                                                                                                               R.Wilson pass deep left complete to MIN 45. Catch made by D.Metcalf at MIN 45. Gain of 21 yards. Pushed out of bounds by X.Woods at MIN 44.
# 16                                                                                                                                                                                                                                                                       K.Cousins pass short middle complete to MIN 18. Catch made by A.Mattison at MIN 18. Gain of 6 yards. Tackled by J.Brooks at MIN 21.
# 17                                                                                                                                                                                                                                                                        K.Cousins pass short right complete to MIN 24. Catch made by A.Mattison at MIN 24. Gain of 23 yards. Tackled by U.Amadi at MIN 50.
# 18                                                                                                                                                                                                                                                                       K.Cousins pass short middle complete to SEA 25. Catch made by J.Jefferson at SEA 25. Gain of 26 yards. Tackled by D.Reed at SEA 12.
# 19                                                                                                                                                                                                                                                                             K.Cousins pass short left complete to SEA 6. Catch made by T.Conklin at SEA 6. Gain of 7 yards. Tackled by B.Wagner at SEA 5.
# 21                                                                                                                                                                                                                                                                    K.Cousins pass complete to SEA End Zone. Catch made by A.Thielen at SEA End Zone. Gain of 15 yards. A.Thielen for 15 yards, TOUCHDOWN.
# 22                                                                                                                                                                                                                                                                             R.Wilson pass short middle complete to SEA 17. Catch made by P.Hart at SEA 17. Gain of 7 yards. Tackled by H.Smith at SEA 28.
# 23                                                                                                                                                                                                                                                           R.Wilson pass short left complete to SEA 37. Catch made by W.Dissly at SEA 37. Gain of 39 yards. Pushed out of bounds by E.Kendricks at MIN 33.
# 25                                                                                                                                                                                                                                                            R.Wilson pass short left complete to MIN 26. Catch made by T.Lockett at MIN 26. Gain of 7 yards. Pushed out of bounds by P.Peterson at MIN 26.
# 26                                                                                                                                                                                                                                                                  K.Cousins pass short left complete to MIN 33. Catch made by A.Mattison at MIN 33. Gain of 7 yards. Tackled by J.Adams, P.Ford at MIN 43.
# 27                                                                                                                                                                                                                                                             K.Cousins pass short middle complete to SEA 40. Catch made by A.Mattison at SEA 40. Gain of 4 yards. Tackled by B.Wagner; C.Barton at SEA 39.
# 28                                                                                                                                                                                                                                                                                      K.Cousins pass complete to SEA 30. Catch made by A.Thielen at SEA 30. Gain of 7 yards. Tackled by U.Amadi at SEA 30.
# 30                                                                                                                                                                                                                                                                       K.Cousins pass short middle complete to SEA 19. Catch made by J.Jefferson at SEA 19. Gain of 9 yards. Tackled by U.Amadi at SEA 19.
# 31                                                                                                                                                                                                                                                                          K.Cousins pass short right complete to SEA 16. Catch made by T.Conklin at SEA 16. Gain of 16 yards. Tackled by J.Adams at SEA 3.
# 32                                                                                                                                                                                                                                                                  K.Cousins pass complete to SEA End Zone. Catch made by J.Jefferson at SEA End Zone. Gain of 3 yards. J.Jefferson for 3 yards, TOUCHDOWN.
# 33                                                                                                                                                                                                                                                              R.Wilson pass short middle complete to SEA 30. Catch made by T.Homer at SEA 30. Gain of 12 yards. Tackled by N.Vigil, E.Kendricks at SEA 37.
# 34                                                                                                                                                                                                                                                                     R.Wilson pass complete to SEA 37. Catch made by G.Everett at SEA 37. Gain of 11 yards. Pushed out of bounds by M.Alexander at SEA 48.
# 35                                                                                                                                                                                                                                                                             R.Wilson pass short left complete to SEA 47. Catch made by T.Homer at SEA 47. Gain of 31 yards. Tackled by C.Bynum at MIN 21.
# 36                                                                                                                                                                                                                                                                       K.Cousins pass short right complete to MIN 30. Catch made by A.Thielen at MIN 30. Gain of -4 yards. Tackled by J.Brooks at MIN 37.
# 37                                                                                                                                                                                                                                                             K.Cousins pass short left complete to MIN 43. Catch made by J.Jefferson at MIN 43. Gain of 15 yards. Tackled by T.Flowers, U.Amadi at MIN 48.
# 38                                                                                                                                                                                                                                                                           K.Cousins pass short left complete to SEA 47. Catch made by T.Conklin at SEA 47. Gain of 5 yards. Tackled by U.Amadi at SEA 43.
# 40                                                                                                                                                                                                                                                                                               K.Cousins pass complete to SEA 26. Catch made by J.Jefferson at SEA 26. Gain of 8 yards. ran out of bounds.
# 41                                                                                                                                                                                                                                                                            K.Cousins pass short left complete to SEA 18. Catch made by A.Thielen at SEA 18. Gain of 9 yards. Tackled by P.Ford at SEA 14.
# 43                                                                                                                                                                                                                                                                             R.Wilson pass short left complete to SEA 21. Catch made by T.Homer at SEA 21. Gain of 5 yards. Tackled by D.Hunter at SEA 32.
# 44                                                                                                                                                                                                                                                              K.Cousins pass short left complete to MIN 12. Catch made by A.Mattison at MIN 12. Gain of -1 yards. Tackled by J.Adams, B.Wagner at MIN 15.
# 45                                                                                                                                                                                                                                                                                     K.Cousins pass complete to MIN 33. Catch made by A.Thielen at MIN 33. Gain of 21 yards. Tackled by Q.Diggs at MIN 35.
# 47                                                                                                                                                                                                                                                   K.Cousins pass short right complete to MIN 46. Catch made by K.Osborn at MIN 46. Gain of 11 yards. Pushed out of bounds by Q.Diggs, J.Brooks at SEA 49.
# 48                                                                                                                                                                                                                                                                      K.Cousins pass short middle complete to SEA 34. Catch made by J.Jefferson at SEA 34. Gain of 28 yards. Tackled by Q.Diggs at SEA 21.
# 49                                                                                                                                                                                                                                                                                     K.Cousins pass complete to SEA 17. Catch made by T.Conklin at SEA 17. Gain of 4 yards. Tackled by J.Brooks at SEA 17.
# 51                                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 30. Catch made by G.Everett at SEA 30. Gain of 14 yards. Tackled by N.Vigil at SEA 40.
# 52  R.Wilson pass complete to SEA 46. Catch made by T.Lockett at SEA 46. Gain of 6 yards. T.Lockett FUMBLES, forced by B.Breeland. Fumble RECOVERED by MIN-D.Hunter at SEA 44. Tackled by at SEA 44. The Replay Official reviewed the fumble and the play was overturned. R.Wilson pass short right complete to SEA 46. Catch made by T.Lockett at SEA 46. Gain of 6 yards. Tackled by B.Breeland at SEA 46.
# 53                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 38. Catch made by C.Carson at SEA 38. Gain of -3 yards. Pushed out of bounds by E.Kendricks at SEA 43.
# 55                                                                                                                                                                                                                                                            K.Cousins pass short right complete to SEA 49. Catch made by T.Conklin at SEA 49. Gain of 14 yards. Pushed out of bounds by J.Adams at SEA 42.
# 56                                                                                                                                                                                                                                                                           K.Cousins pass short left complete to SEA 32. Catch made by K.Osborn at SEA 32. Gain of 15 yards. Tackled by U.Amadi at SEA 22.
# 57                                                                                                                                                                                                                                                                            K.Cousins pass short left complete to SEA 5. Catch made by A.Thielen at SEA 5. Gain of 2 yards. Tackled by T.Flowers at SEA 1.
# 58                                                                                                                                                                                                                                                                           R.Wilson pass short left complete to SEA 40. Catch made by D.Metcalf at SEA 40. Gain of 19 yards. Tackled by H.Smith at SEA 44.
# 62                                                                                                                                                                                                                                                                      K.Cousins pass short right complete to SEA 44. Catch made by J.Jefferson at SEA 44. Gain of 11 yards. J.Jefferson ran out of bounds.
# 63                                                                                                                                                                                                                                                                              R.Wilson pass short right complete to SEA 8. Catch made by G.Everett at SEA 8. Gain of 7 yards. G.Everett ran out of bounds.
# 64                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 17. Catch made by G.Everett at SEA 17. Gain of 17 yards. Pushed out of bounds by B.Breeland at SEA 25.
# 66                                                                                                                                                                                                                                                              R.Wilson pass short right complete to SEA 32. Catch made by T.Lockett at SEA 32. Gain of 15 yards. Tackled by B.Breeland, N.Vigil at SEA 40.

# %% [markdown]
# ## New receiver columns
# - We should create new features that capture the nuances of player style based on:
#   - Utilization by route run
#   - Physical attributes
#   - Reliability in clutch situations
#   - Contact tolerance
#   - The ability to create separation from a defender

# %% [markdown]
# ### Catches of poorly thrown passes
# - To capture when a receiver bails out a quarterback by managing to catch an off-target pass
#   - Demonstrates a receiver's overall "catch radius"
#     - A combination of body control, height, arm length, hand size, and ball tracking ability
# - Seems to only be recorded when a penalty is called.
#   - Not sure if this dataset actually records catches of poorly thrown passes or assumes they don't get caught by default.
#   - Still going to keep this feature just in case.

# %%
sportradar_wr.loc[(sportradar_wr['on_target_throw'] == 0) & (sportradar_wr['reception'] == 1) & (~sportradar_wr['description'].str.contains('penalty', case = False, na = False))][['play_id', 'period', 'start_play_clock_string', 'player_name', 'on_target_throw', 'catchable', 'incompletion_type', 'description']]
# Out:
# Empty DataFrame
# Columns: [play_id, period, start_play_clock_string, player_name, on_target_throw, catchable, incompletion_type, description]
# Index: []

# %%
sportradar_wr['difficult_attempt'] = False
sportradar_wr.loc[(sportradar_wr['on_target_throw'] == 0) & (~sportradar_wr['description'].str.contains('penalty', case = False, na = False)), 'difficult_attempt'] = True

# %%
sportradar_wr['difficult_catch'] = False
sportradar_wr.loc[(sportradar_wr['on_target_throw'] == 0) & (sportradar_wr['reception'] == 1) & (~sportradar_wr['description'].str.contains('penalty', case = False, na = False)), 'difficult_catch'] = True

# %% [markdown]
# ### Adverse weather catches
# - Can the receiver keep his footing when there's heavy rain? Can he catch a wet ball?
# - If OR:
#   - Temp is 32 F or less
#   - Wind speed is 10 MPH or greater
#   - Humidity is 70% or greater

# %%
sportradar_wr.loc[(sportradar_wr['temp'] <= 32) | (sportradar_wr['wind_speed'] >= 10) | (sportradar_wr['humidity'] >= 70 )][['play_id', 'period', 'start_play_clock_string', 'player_name', 'on_target_throw', 'catchable', 'incompletion_type', 'description']]
# Out:
# Empty DataFrame
# Columns: [play_id, period, start_play_clock_string, player_name, on_target_throw, catchable, incompletion_type, description]
# Index: []

# %%
sportradar_wr['weather_attempt'] = False
sportradar_wr.loc[((sportradar_wr['temp'] <= 32) | (sportradar_wr['wind_speed'] >= 10) | (sportradar_wr['humidity'] >= 70 )) & (sportradar_wr['reception'] == 1), 'weather_attempt'] = True

# %%
sportradar_wr['weather_catch'] = False
sportradar_wr.loc[((sportradar_wr['temp'] <= 32) | (sportradar_wr['wind_speed'] >= 10) | (sportradar_wr['humidity'] >= 70 )) & (sportradar_wr['reception'] == 1), 'weather_catch'] = True

# %% [markdown]
# ### QB bail-out catches
# - Does the receiver know when the QB is under duress, and does he know when and where to make himself open for a pass to prevent a loss of yardage?
# - Catches made when the quarterback is under duress (if OR):
#   - If QB scrambled
#   - If QB was hurried
#   - If QB was blitzed
#   - If QB was knocked down

# %%
sportradar_wr.loc[(
                    (sportradar_wr['pocket_location'] == 'Scramble Left') 
                    | (sportradar_wr['pocket_location'] == 'Scramble Right') 
                    | (sportradar_wr['hurry'] == True) 
                    | (sportradar_wr['blitz'] == True) 
                    | (sportradar_wr['knockdown'] == True)
                  ) & (sportradar_wr['reception'] == 1)][['play_id', 'period', 'start_play_clock_string', 'qb_name', 'pocket_location', 
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'on_target_throw', 'description']]
# Out:
#                                  play_id  period start_play_clock_string  \
# 0   f72f3120-1f07-11ec-a67f-c75e589fa3a4       1                   15:00
# 5   9e800700-1f09-11ec-a67f-c75e589fa3a4       1                    9:11
# 7   dabe15e0-1f09-11ec-b36d-a3b2acec3de6       1                    7:54
# 9   ca06a590-1f0a-11ec-b36d-a3b2acec3de6       1                    5:14
# 10  e3c698a0-1f0a-11ec-b36d-a3b2acec3de6       1                    4:38
# 21  19c341c0-1f0f-11ec-89e9-8992a3cbf855       2                    5:32
# 23  0c9c7240-1f10-11ec-89e9-8992a3cbf855       2                    4:41
# 28  7b2b7240-1f12-11ec-acc0-f76b8dd971ea       2                   00:57
# 37  17958820-1f16-11ec-a9c1-1b4016cb3a46       3                   13:02
# 38  362af810-1f16-11ec-a9c1-1b4016cb3a46       3                   12:05
# 41  be988190-1f16-11ec-a9c1-1b4016cb3a46       3                    8:48
# 44  76099b60-1f18-11ec-a9c1-1b4016cb3a46       3                    3:48
# 48  2c26da70-1f19-11ec-a9c1-1b4016cb3a46       3                   00:21
# 53  be2e34c0-1f1b-11ec-a9c1-1b4016cb3a46       4                   12:33
# 55  94860840-1f1c-11ec-a9c1-1b4016cb3a46       4                   10:24
# 56  e07f57b0-1f1c-11ec-a9c1-1b4016cb3a46       4                    8:21
#
#            qb_name pocket_location  hurry  blitz  knockdown  players_rushed  \
# 0   Russell Wilson      Boot Right      1      0          0               4
# 5     Kirk Cousins      Boot Right      0      1          0               5
# 7     Kirk Cousins          Middle      0      1          0               5
# 9   Russell Wilson          Middle      0      1          0               6
# 10  Russell Wilson          Middle      0      1          1               5
# 21    Kirk Cousins          Middle      0      1          0               5
# 23  Russell Wilson          Middle      0      1          0               5
# 28    Kirk Cousins          Middle      0      1          0               5
# 37    Kirk Cousins          Middle      0      1          1               6
# 38    Kirk Cousins   Scramble Left      1      0          0               4
# 41    Kirk Cousins          Middle      1      1          0               5
# 44    Kirk Cousins          Middle      0      0          1               4
# 48    Kirk Cousins          Middle      0      1          0               5
# 53  Russell Wilson  Scramble Right      1      1          0               5
# 55    Kirk Cousins          Middle      0      1          0               5
# 56    Kirk Cousins          Middle      0      1          1               6
#
#    pocket_time_string         pass_route         player_name  att_yards  \
# 0                3.13              Cross          DK Metcalf         11
# 5                3.25              Cross       Tyler Conklin         11
# 7                1.78                Out    Justin Jefferson          5
# 9                1.59              Slant       Freddie Swain          8
# 10               2.25               Post          DK Metcalf         12
# 21               2.36               Post        Adam Thielen         15
# 23               2.46              Cross         Will Dissly          9
# 28               2.25               Curl        Adam Thielen          7
# 37               2.75               Curl    Justin Jefferson         10
# 38               2.60               Flat       Tyler Conklin          1
# 41               1.21                Out        Adam Thielen          5
# 44               2.00  Underneath Screen  Alexander Mattison         -3
# 48               2.51               Post    Justin Jefferson         15
# 53               1.53  Underneath Screen        Chris Carson         -8
# 55               2.36              Cross       Tyler Conklin          7
# 56               1.11              Cross         K.J. Osborn          5
#
#     yards  yards_after_catch  on_target_throw  \
# 0      17                  6                1
# 5      17                  6                1
# 7      10                  5                1
# 9      10                  2                1
# 10     12                  0                1
# 21     15                  0                1
# 23     39                 30                1
# 28      7                  0                1
# 37     15                  5                1
# 38      5                  4                1
# 41      9                  4                1
# 44     -1                  2                1
# 48     28                 13                1
# 53     -3                  5                1
# 55     14                  7                1
# 56     15                 10                1
#
#                                                                                                                                          description
# 0                   R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
# 5                 K.Cousins pass short left complete to SEA 32. Catch made by T.Conklin at SEA 32. Gain of 17 yards. Tackled by T.Flowers at SEA 26.
# 7                K.Cousins pass short left complete to SEA 13. Catch made by J.Jefferson at SEA 13. Gain of 10 yards. Tackled by T.Flowers at SEA 8.
# 9                  R.Wilson pass short right complete to SEA 36. Catch made by F.Swain at SEA 36. Gain of 10 yards. Tackled by B.Breeland at SEA 38.
# 10              R.Wilson pass short middle complete to SEA 50. Catch made by D.Metcalf at SEA 50. Gain of 12 yards. Tackled by B.Breeland at MIN 50.
# 21            K.Cousins pass complete to SEA End Zone. Catch made by A.Thielen at SEA End Zone. Gain of 15 yards. A.Thielen for 15 yards, TOUCHDOWN.
# 23   R.Wilson pass short left complete to SEA 37. Catch made by W.Dissly at SEA 37. Gain of 39 yards. Pushed out of bounds by E.Kendricks at MIN 33.
# 28                              K.Cousins pass complete to SEA 30. Catch made by A.Thielen at SEA 30. Gain of 7 yards. Tackled by U.Amadi at SEA 30.
# 37     K.Cousins pass short left complete to MIN 43. Catch made by J.Jefferson at MIN 43. Gain of 15 yards. Tackled by T.Flowers, U.Amadi at MIN 48.
# 38                   K.Cousins pass short left complete to SEA 47. Catch made by T.Conklin at SEA 47. Gain of 5 yards. Tackled by U.Amadi at SEA 43.
# 41                    K.Cousins pass short left complete to SEA 18. Catch made by A.Thielen at SEA 18. Gain of 9 yards. Tackled by P.Ford at SEA 14.
# 44      K.Cousins pass short left complete to MIN 12. Catch made by A.Mattison at MIN 12. Gain of -1 yards. Tackled by J.Adams, B.Wagner at MIN 15.
# 48              K.Cousins pass short middle complete to SEA 34. Catch made by J.Jefferson at SEA 34. Gain of 28 yards. Tackled by Q.Diggs at SEA 21.
# 53  R.Wilson pass short right complete to SEA 38. Catch made by C.Carson at SEA 38. Gain of -3 yards. Pushed out of bounds by E.Kendricks at SEA 43.
# 55    K.Cousins pass short right complete to SEA 49. Catch made by T.Conklin at SEA 49. Gain of 14 yards. Pushed out of bounds by J.Adams at SEA 42.
# 56                   K.Cousins pass short left complete to SEA 32. Catch made by K.Osborn at SEA 32. Gain of 15 yards. Tackled by U.Amadi at SEA 22.

# %%
sportradar_wr['qb_bf_attempt'] = False
sportradar_wr.loc[(
                    (sportradar_wr['pocket_location'] == 'Scramble Left') 
                    | (sportradar_wr['pocket_location'] == 'Scramble Right') 
                    | (sportradar_wr['hurry'] == True) 
                    | (sportradar_wr['blitz'] == True) 
                    | (sportradar_wr['knockdown'] == True)
                  ) , 'qb_bf_attempt'] = True

sportradar_wr['qb_bf_catch'] = False
sportradar_wr.loc[(
                    (sportradar_wr['pocket_location'] == 'Scramble Left') 
                    | (sportradar_wr['pocket_location'] == 'Scramble Right') 
                    | (sportradar_wr['hurry'] == True) 
                    | (sportradar_wr['blitz'] == True) 
                    | (sportradar_wr['knockdown'] == True)
                  ) 
                  & (sportradar_wr['reception'] == 1), 'qb_bf_catch'] = True

# %% [markdown]
# ### Clutch catches
# - Does the receiver sustain drives by converting first downs or catching touchdowns near the end of close games? Or does he buckle under the pressure?
# - If AND:
#   - 4th quarter or overtime AND 4 or fewer minutes left in period
#   - Difference of one score (8 or fewer points)
#   - Converts first down or is touchdown

# %%
sportradar_wr.loc[(
                    (sportradar_wr['period'] >= 4) & (sportradar_wr['start_play_clock'] < pd.Timedelta(minutes=4)) 
                    & (
                        (
                            (sportradar_wr['team_alias'] == sportradar_wr['home_alias']) & (abs(sportradar_wr['away_points'] - sportradar_wr['home_points']) <= 8)
                        )
                      | (
                            (sportradar_wr['team_alias'] == sportradar_wr['away_alias']) & (abs(sportradar_wr['home_points'] - sportradar_wr['away_points']) <= 8)
                        )
                      )
                    & (
                        (sportradar_wr['att_yards'] >= sportradar_wr['start_play_yfd'])
                      )
                  ) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'qb_name', 'pocket_location', 'firstdown', 'goaltogo',
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'on_target_throw', 'description']]
# Out:
# Empty DataFrame
# Columns: [play_id, home_points, away_points, period, start_play_clock_string, qb_name, pocket_location, firstdown, goaltogo, hurry, blitz, knockdown, players_rushed, pocket_time_string, pass_route, player_name, att_yards, yards, yards_after_catch, on_target_throw, description]
# Index: []

# %%
sportradar_wr.columns
# Out:
# Index(['game_id', 'season_year', 'season_type', 'week', 'home_alias',
#        'home_sr_id', 'away_alias', 'away_sr_id', 'temp', 'humidity',
#        'wind_speed', 'venue_surface', 'venue_roof_type', 'period', 'event_id',
#        'team_sequence', 'play_id', 'home_points', 'away_points', 'description',
#        'start_play_clock', 'start_play_clock_string', 'start_play_down',
#        'start_play_yfd', 'start_play_yardline',
#        'effective_start_play_yardline', 'start_play_field_side', 'inside_20',
#        'goaltogo', 'end_play_clock', 'end_play_clock_string', 'end_play_down',
#        'end_play_yfd', 'end_play_yardline', 'effective_end_play_yardline',
#        'end_play_field_side', 'firstdown', 'scoring_play', 'players_rushed',
#        'men_in_box', 'huddle', 'hash_mark', 'qb_at_snap', 'left_tightends',
#        'right_tightends', 'qb_name', 'pocket_location', 'play_direction',
#        'screen_pass', 'play_action', 'run_pass_option', 'pass_route',
#        'fake_punt', 'fake_field_goal', 'defender_name', 'player_name',
#        'player_jersey', 'player_position', 'player_sr_id', 'team_alias',
#        'team_sr_id', 'blitz', 'hurry', 'knockdown', 'pocket_time',
#        'pocket_time_string', 'on_target_throw', 'batted_pass',
#        'incompletion_type', 'target', 'reception', 'yards', 'att_yards',
#        'yards_after_catch', 'yards_after_contact', 'broken_tackles', 'dropped',
#        'catchable', 'touchdown', 'difficult_attempt', 'difficult_catch',
#        'weather_attempt', 'weather_catch', 'qb_bf_attempt', 'qb_bf_catch'],
#       dtype='object')

# %%
sportradar_wr['clutch_catch'] = False
sportradar_wr.loc[(
                    (sportradar_wr['period'] >= 4) & (sportradar_wr['start_play_clock'] < pd.Timedelta(minutes=4)) 
                    & (
                        (
                            (sportradar_wr['team_alias'] == sportradar_wr['home_alias']) & (abs(sportradar_wr['away_points'] - sportradar_wr['home_points']) <= 8)
                        )
                      | (
                            (sportradar_wr['team_alias'] == sportradar_wr['away_alias']) & (abs(sportradar_wr['home_points'] - sportradar_wr['away_points']) <= 8)
                        )
                      )
                    & (
                        (sportradar_wr['att_yards'] >= sportradar_wr['start_play_yfd'])
                      )
                  ) & (sportradar_wr['reception'] == 1), 'clutch_catch'
                ] = True

# %%
sportradar_wr[(sportradar_wr['goaltogo'] == 1) & (sportradar_wr['start_play_yardline'] >= 10)][['period', 'start_play_clock', 'start_play_down', 'inside_20', 'start_play_yfd', 'goaltogo', 'start_play_yardline', 'att_yards', 'description']]
# Out:
#    period start_play_clock  start_play_down  inside_20  start_play_yfd  \
# 3       1  0 days 00:10:32                2          1              10
#
#    goaltogo  start_play_yardline  att_yards  \
# 3         1                   10          7
#
#                                                                                                                            description
# 3  R.Wilson pass short right complete to MIN 3. Catch made by D.Metcalf at MIN 3. Gain of 10 yards. D.Metcalf for 10 yards, TOUCHDOWN.

# %% [markdown]
# ### Conversion catches
# - Does the receiver sustain drives or catch touchdowns when the drive is in jeopardy?
# - The offensive team's 3rd down is commonly regarded as the last practical down of a drive
#   - Although the offensive team has 4 downs to sustain a drive or score, the 4th down is commonly used to kick the ball in one of two ways:
#     - Kicking a field goal for 3 points, provided that the offensive team is within the placekicker's range
#     - Punting the ball to move it downfield so that the opposing team starts with worse field position when it receives the punt
#   - If the offensive team attempts a pass or run play on 4th down and fails to convert a 1st down or score, the referee declares a "turnover on downs" and the opposing team takes possession of the ball where it was downed on the failed conversion attempt
#     - Due to the difficulty, pressure, and cost of converting on 4th down, offensive teams typically use the 4th down to punt or kick a field goal
# - If OR:
#   - 3rd down or greater and converts 1st down
#   - 3rd down or greater and scores TD

# %%
sportradar_wr.loc[(
                    (
                        ((sportradar_wr['start_play_down'] >= 3) & (sportradar_wr['firstdown'] == 1)) | ((sportradar_wr['start_play_down'] >= 3) & (sportradar_wr['touchdown'] == 1))
                    )
                  ) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'qb_name', 'pocket_location', 'goaltogo',
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 2   8e3944c0-1f08-11ec-a67f-c75e589fa3a4            0            0       1
# 9   ca06a590-1f0a-11ec-b36d-a3b2acec3de6            7            7       1
# 21  19c341c0-1f0f-11ec-89e9-8992a3cbf855           13           17       2
# 28  7b2b7240-1f12-11ec-acc0-f76b8dd971ea           14           17       2
# 30  c448f1f0-1f12-11ec-acc0-f76b8dd971ea           14           17       2
# 40  8e79a0c0-1f16-11ec-a9c1-1b4016cb3a46           21           17       3
# 47  f896a0a0-1f18-11ec-a9c1-1b4016cb3a46           24           17       3
# 56  e07f57b0-1f1c-11ec-a9c1-1b4016cb3a46           27           17       4
# 62  4b97a780-1f1f-11ec-a9c1-1b4016cb3a46           30           17       4
#
#    start_play_clock_string         qb_name pocket_location  goaltogo  hurry  \
# 2                    11:24  Russell Wilson          Middle         0      0
# 9                     5:14  Russell Wilson          Middle         0      0
# 21                    5:32    Kirk Cousins          Middle         0      0
# 28                   00:57    Kirk Cousins          Middle         0      0
# 30                   00:29    Kirk Cousins          Middle         0      0
# 40                   10:03    Kirk Cousins          Middle         0      0
# 47                    1:40    Kirk Cousins          Middle         0      0
# 56                    8:21    Kirk Cousins          Middle         0      0
# 62                    2:08    Kirk Cousins          Middle         0      0
#
#     blitz  knockdown  players_rushed pocket_time_string pass_route  \
# 2       0          0               4               3.21       Post
# 9       1          0               6               1.59      Slant
# 21      1          0               5               2.36       Post
# 28      1          0               5               2.25       Curl
# 30      0          0               4               1.78      Slant
# 40      0          0               4               1.89        Out
# 47      0          0               4               1.87        Out
# 56      1          1               6               1.11      Cross
# 62      0          0               4               2.16        Out
#
#          player_name  att_yards  yards  yards_after_catch  on_target_throw  \
# 2         DK Metcalf         11     28                 17                1
# 9      Freddie Swain          8     10                  2                1
# 21      Adam Thielen         15     15                  0                1
# 28      Adam Thielen          7      7                  0                1
# 30  Justin Jefferson          9      9                  0                1
# 40  Justin Jefferson          8      8                  0                1
# 47       K.J. Osborn          6     11                  5                1
# 56       K.J. Osborn          5     15                 10                1
# 62  Justin Jefferson         11     11                  0                1
#
#     firstdown  touchdown  \
# 2           1        NaN
# 9           1        NaN
# 21          1          1
# 28          1        NaN
# 30          1        NaN
# 40          1        NaN
# 47          1        NaN
# 56          1        NaN
# 62          1        NaN
#
#                                                                                                                                                 description
# 2                           R.Wilson pass short left complete to MIN 27. Catch made by D.Metcalf at MIN 27. Gain of 28 yards. Tackled by H.Smith at MIN 10.
# 9                         R.Wilson pass short right complete to SEA 36. Catch made by F.Swain at SEA 36. Gain of 10 yards. Tackled by B.Breeland at SEA 38.
# 21                   K.Cousins pass complete to SEA End Zone. Catch made by A.Thielen at SEA End Zone. Gain of 15 yards. A.Thielen for 15 yards, TOUCHDOWN.
# 28                                     K.Cousins pass complete to SEA 30. Catch made by A.Thielen at SEA 30. Gain of 7 yards. Tackled by U.Amadi at SEA 30.
# 30                      K.Cousins pass short middle complete to SEA 19. Catch made by J.Jefferson at SEA 19. Gain of 9 yards. Tackled by U.Amadi at SEA 19.
# 40                                              K.Cousins pass complete to SEA 26. Catch made by J.Jefferson at SEA 26. Gain of 8 yards. ran out of bounds.
# 47  K.Cousins pass short right complete to MIN 46. Catch made by K.Osborn at MIN 46. Gain of 11 yards. Pushed out of bounds by Q.Diggs, J.Brooks at SEA 49.
# 56                          K.Cousins pass short left complete to SEA 32. Catch made by K.Osborn at SEA 32. Gain of 15 yards. Tackled by U.Amadi at SEA 22.
# 62                     K.Cousins pass short right complete to SEA 44. Catch made by J.Jefferson at SEA 44. Gain of 11 yards. J.Jefferson ran out of bounds.

# %%
sportradar_wr['conversion_attempt'] = False
sportradar_wr.loc[
                    (sportradar_wr['start_play_down'] >= 3) & (sportradar_wr['att_yards'] >= sportradar_wr['start_play_yfd']),
                    'conversion_attempt'
                ] = True

sportradar_wr['conversion_catch'] = False
sportradar_wr.loc[
                    (sportradar_wr['start_play_down'] >= 3) & ((sportradar_wr['firstdown'] == 1) | (sportradar_wr['touchdown'] == 1)) & (sportradar_wr['reception'] == 1),
                    'conversion_catch'
                ] = True

# %% [markdown]
# ### Red zone touchdown catches
# - Touchdown catches from the 20 yardline or closer
# - Completing a pass in the red zone is difficult because the play starts from within the 20 yardline, making the 22 players bunched very closely together
#   - There is much less room for receivers to create horizontal separation from defenders
#   - Taller receivers are favored on redzone pass plays because they can use their height, arm length, and jumping ability to create separation

# %%
sportradar_wr.loc[(
                    (
                        (sportradar_wr['inside_20'] == 1) & (sportradar_wr['touchdown'] == 1)
                    )
                  ) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 3   b0cb36b0-1f08-11ec-a67f-c75e589fa3a4            0            6       1
# 8   f6cb0630-1f09-11ec-b36d-a3b2acec3de6            6            7       1
# 21  19c341c0-1f0f-11ec-89e9-8992a3cbf855           13           17       2
# 32  0a490500-1f13-11ec-acc0-f76b8dd971ea           20           17       2
#
#    start_play_clock_string  start_play_down  start_play_yardline  inside_20  \
# 3                    10:32                2                   10          1
# 8                     6:42                2                    7          1
# 21                    5:32                3                   15          1
# 32                   00:20                1                    3          1
#
#     goaltogo         qb_name pocket_location  hurry  blitz  knockdown  \
# 3          1  Russell Wilson          Middle      0      0          0
# 8          1    Kirk Cousins          Middle      0      0          0
# 21         0    Kirk Cousins          Middle      0      1          0
# 32         1    Kirk Cousins          Middle      0      0          0
#
#     players_rushed pocket_time_string pass_route       player_name  att_yards  \
# 3                4               1.74        Out        DK Metcalf          7
# 8                3               2.15        Out     Tyler Conklin          6
# 21               5               2.36       Post      Adam Thielen         15
# 32               4               2.30        Out  Justin Jefferson          3
#
#     yards  yards_after_catch  on_target_throw  firstdown  touchdown  \
# 3      10                  3                1          1          1
# 8       7                  1                1          1          1
# 21     15                  0                1          1          1
# 32      3                  0                1          1          1
#
#                                                                                                                                  description
# 3        R.Wilson pass short right complete to MIN 3. Catch made by D.Metcalf at MIN 3. Gain of 10 yards. D.Metcalf for 10 yards, TOUCHDOWN.
# 8                     K.Cousins pass complete to SEA 1. Catch made by T.Conklin at SEA 1. Gain of 7 yards. T.Conklin for 7 yards, TOUCHDOWN.
# 21    K.Cousins pass complete to SEA End Zone. Catch made by A.Thielen at SEA End Zone. Gain of 15 yards. A.Thielen for 15 yards, TOUCHDOWN.
# 32  K.Cousins pass complete to SEA End Zone. Catch made by J.Jefferson at SEA End Zone. Gain of 3 yards. J.Jefferson for 3 yards, TOUCHDOWN.

# %%
sportradar_wr['redzone_attempt'] = False
sportradar_wr.loc[(
                    (sportradar_wr['inside_20'] == 1) & (sportradar_wr['att_yards'] >= sportradar_wr['start_play_yfd'])
                  ), 'redzone_attempt'] = True

sportradar_wr['redzone_catch'] = False
sportradar_wr.loc[(
                    (sportradar_wr['inside_20'] == 1) & (sportradar_wr['touchdown'] == 1)
                  )
                   & (sportradar_wr['reception'] == 1), 'redzone_catch'] = True

# %% [markdown]
# ### Catches by route
# - Elite route runners are able to change direction very quickly without telegraphing their intentions to their defenders
# - Routes that feature quick direction change, such as the curl, require that the receiver have these traits:
# - Rapid acceleration
# - Rapid deceleration - The ability to stop movement in one direction with very few steps
#   - If a receiver "pitter-patters," the defender knows he intends to stop and change directions
# - Flexible ankles
# - Hip mobility
# - Leverage intuition
#   - "Inside leverage" - When a receiver is positioned with his defender closer to the nearest lateral boundary, making the receiver closer to the "inside" of the field
#   - "Outside leverage" - When a receiver is positioned closer to the nearest lateral boundary than his defender, making the receiver closer to the "outside" of the field
#   - Understanding leverage tells a receiver:
#     - When to expect the pass without looking back at the QB
#     - What kind of pass the QB will throw
# - Not every elite receiver is an elite route runner.
#   - Some can run a limited "route tree," running only relatively straight routes that take advantage of their speed.

# %%
routes = ['In', 'Slant', 'Corner', 'Flat', 'Curl', 'WR Screen', 'Out', 'Go', 'Cross', 'Post', 'Comeback', 'Underneath Screen']

for r in routes:
    sportradar_wr[r.replace(' ', '_').lower() + '_attempt'] = False
    sportradar_wr.loc[ (sportradar_wr['pass_route'] == r), r.replace(' ', '_').lower() + '_attempt'] = True

for r in routes:
    sportradar_wr[r.replace(' ', '_').lower()+'_catch'] = False
    sportradar_wr.loc[ (sportradar_wr['pass_route'] == r) & (sportradar_wr['reception'] == 1), r.replace(' ', '_').lower()+'_catch'] = True

# %%
# routes = ['Cross', 'Curl', 'Post', 'Underneath Screen', 'Flat', 'Slant', 'WR Screen', 'Comeback', 'Go', 'In']

# for r in routes:
#     sportradar_wr[r.replace(' ', '_').lower()+'_catch'] = False
#     sportradar_wr.loc[ (sportradar_wr['pass_route'] == r) & (sportradar_wr['reception'] == 1), r.replace(' ', '_').lower()+'_catch'] = True

# %% [markdown]
# ### Deep catch
# - A pass play can result in a large gain, but this can be achieved by a short pass to a receiver who gains many yards after the catch
# - This metric is meant to capture receivers who are frequently relied on to catch deep passes - passes that travel 20+ yards through the air before a catch attempt is made

# %%
sportradar_wr.loc[ (sportradar_wr['att_yards'] >= 20) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 15  128b2eb0-1f0d-11ec-89e9-8992a3cbf855            7           10       2
#
#    start_play_clock_string  start_play_down  start_play_yardline  inside_20  \
# 15                   14:09                1                   35          0
#
#     goaltogo         qb_name pocket_location  hurry  blitz  knockdown  \
# 15         0  Russell Wilson          Middle      0      0          0
#
#     players_rushed pocket_time_string pass_route player_name  att_yards  \
# 15               4               2.58   Comeback  DK Metcalf         20
#
#     yards  yards_after_catch  on_target_throw  firstdown  touchdown  \
# 15     21                  1                1          1        NaN
#
#                                                                                                                                     description
# 15  R.Wilson pass deep left complete to MIN 45. Catch made by D.Metcalf at MIN 45. Gain of 21 yards. Pushed out of bounds by X.Woods at MIN 44.

# %%
sportradar_wr['deep_attempt'] = False
sportradar_wr.loc[ (sportradar_wr['att_yards'] >= 20), 'deep_attempt'] = True

# %%
sportradar_wr['deep_catch'] = False
sportradar_wr.loc[ (sportradar_wr['att_yards'] >= 20) & (sportradar_wr['reception'] == 1), 'deep_catch'] = True

# %% [markdown]
# ### Large YAC catch
# - Some receivers, such as Deebo Samuel, excel at catching short passes and gaining many yards after the catch
#   - This requires great vision, lateral agility, and acceleration
# - Catches with 10+ yards after catch

# %%
sportradar_wr.loc[ (sportradar_wr['yards_after_catch'] >= 10) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 2   8e3944c0-1f08-11ec-a67f-c75e589fa3a4            0            0       1
# 4   86a1cc40-1f09-11ec-a67f-c75e589fa3a4            0            7       1
# 11  424963d0-1f0b-11ec-b36d-a3b2acec3de6            7            7       1
# 17  63a98520-1f0e-11ec-89e9-8992a3cbf855            7           17       2
# 18  b25ceb80-1f0e-11ec-89e9-8992a3cbf855            7           17       2
# 22  fbbeaab0-1f0f-11ec-89e9-8992a3cbf855           14           17       2
# 23  0c9c7240-1f10-11ec-89e9-8992a3cbf855           14           17       2
# 26  712b9730-1f11-11ec-acc0-f76b8dd971ea           14           17       2
# 31  db457f40-1f12-11ec-acc0-f76b8dd971ea           14           17       2
# 34  93c195e0-1f13-11ec-acc0-f76b8dd971ea           21           17       2
# 35  b904c520-1f13-11ec-acc0-f76b8dd971ea           21           17       2
# 43  067cc880-1f18-11ec-a9c1-1b4016cb3a46           24           17       3
# 48  2c26da70-1f19-11ec-a9c1-1b4016cb3a46           24           17       3
# 51  132d0ba0-1f1b-11ec-a9c1-1b4016cb3a46           27           17       4
# 56  e07f57b0-1f1c-11ec-a9c1-1b4016cb3a46           27           17       4
#
#    start_play_clock_string  start_play_down  start_play_yardline  inside_20  \
# 2                    11:24                3                   38          0
# 4                     9:51                2                   37          0
# 11                    2:04                2                   33          0
# 17                    9:40                1                   27          0
# 18                    7:25                1                   38          0
# 22                    5:23                1                   21          0
# 23                    4:41                2                   28          0
# 26                    3:04                2                   36          0
# 31                   00:24                1                   19          1
# 34                   00:09                1                   37          0
# 35                   00:01                1                   48          0
# 43                    4:38                3                   27          0
# 48                   00:21                2                   49          0
# 51                   13:21                2                   26          0
# 56                    8:21                3                   37          0
#
#     goaltogo         qb_name pocket_location  hurry  blitz  knockdown  \
# 2          0  Russell Wilson          Middle      0      0          0
# 4          0    Kirk Cousins          Middle      0      0          0
# 11         0  Russell Wilson          Middle      0      0          0
# 17         0    Kirk Cousins          Middle      0      0          0
# 18         0    Kirk Cousins          Middle      0      0          0
# 22         0  Russell Wilson          Middle      0      0          0
# 23         0  Russell Wilson          Middle      0      1          0
# 26         0    Kirk Cousins          Middle      0      0          0
# 31         0    Kirk Cousins          Middle      0      0          0
# 34         0  Russell Wilson          Middle      0      0          0
# 35         0  Russell Wilson          Middle      0      0          0
# 43         0  Russell Wilson          Middle      0      0          0
# 48         0    Kirk Cousins          Middle      0      1          0
# 51         0  Russell Wilson          Middle      0      0          0
# 56         0    Kirk Cousins          Middle      0      1          1
#
#     players_rushed pocket_time_string         pass_route         player_name  \
# 2                4               3.21               Post          DK Metcalf
# 4                4               2.57  Underneath Screen  Alexander Mattison
# 11               4               2.47  Underneath Screen       Tyler Lockett
# 17               4               2.24  Underneath Screen  Alexander Mattison
# 18               4               2.56               Post    Justin Jefferson
# 22               4               0.22               Flat          Penny Hart
# 23               5               2.46              Cross         Will Dissly
# 26               3               2.02  Underneath Screen  Alexander Mattison
# 31               4               1.52              Slant       Tyler Conklin
# 34               4               2.69               Flat      Gerald Everett
# 35               4               2.51               Flat        Travis Homer
# 43               4               1.69  Underneath Screen        Travis Homer
# 48               5               2.51               Post    Justin Jefferson
# 51               4               2.15               Curl      Gerald Everett
# 56               6               1.11              Cross         K.J. Osborn
#
#     att_yards  yards  yards_after_catch  on_target_throw  firstdown  \
# 2          11     28                 17                1          1
# 4          -2     20                 22                1          1
# 11         -7      3                 10                1          0
# 17         -3     23                 26                1          1
# 18         13     26                 13                1          1
# 22         -4      7                 11                1          0
# 23          9     39                 30                1          1
# 26         -3      7                 10                1          0
# 31          3     16                 13                1          1
# 34          0     11                 11                1          1
# 35         -1     31                 32                1          1
# 43         -6      5                 11                1          0
# 48         15     28                 13                1          1
# 51          4     14                 10                1          1
# 56          5     15                 10                1          1
#
#     touchdown  \
# 2         NaN
# 4         NaN
# 11        NaN
# 17        NaN
# 18        NaN
# 22        NaN
# 23        NaN
# 26        NaN
# 31        NaN
# 34        NaN
# 35        NaN
# 43        NaN
# 48        NaN
# 51        NaN
# 56        NaN
#
#                                                                                                                                                                                                               description
# 2                                                                                         R.Wilson pass short left complete to MIN 27. Catch made by D.Metcalf at MIN 27. Gain of 28 yards. Tackled by H.Smith at MIN 10.
# 4                                                                                       K.Cousins pass short left complete to MIN 35. Catch made by A.Mattison at MIN 35. Gain of 20 yards. Tackled by J.Adams at SEA 43.
# 11  R.Wilson pass short left complete to MIN 40. Catch made by T.Lockett at MIN 40. Gain of 3 yards. Tackled by H.Smith at MIN 30. PENALTY on SEA-A.Collins, Offensive Illegal Block Above the Waist, 10 yards, accepted.
# 17                                                                                     K.Cousins pass short right complete to MIN 24. Catch made by A.Mattison at MIN 24. Gain of 23 yards. Tackled by U.Amadi at MIN 50.
# 18                                                                                    K.Cousins pass short middle complete to SEA 25. Catch made by J.Jefferson at SEA 25. Gain of 26 yards. Tackled by D.Reed at SEA 12.
# 22                                                                                          R.Wilson pass short middle complete to SEA 17. Catch made by P.Hart at SEA 17. Gain of 7 yards. Tackled by H.Smith at SEA 28.
# 23                                                                        R.Wilson pass short left complete to SEA 37. Catch made by W.Dissly at SEA 37. Gain of 39 yards. Pushed out of bounds by E.Kendricks at MIN 33.
# 26                                                                               K.Cousins pass short left complete to MIN 33. Catch made by A.Mattison at MIN 33. Gain of 7 yards. Tackled by J.Adams, P.Ford at MIN 43.
# 31                                                                                       K.Cousins pass short right complete to SEA 16. Catch made by T.Conklin at SEA 16. Gain of 16 yards. Tackled by J.Adams at SEA 3.
# 34                                                                                  R.Wilson pass complete to SEA 37. Catch made by G.Everett at SEA 37. Gain of 11 yards. Pushed out of bounds by M.Alexander at SEA 48.
# 35                                                                                          R.Wilson pass short left complete to SEA 47. Catch made by T.Homer at SEA 47. Gain of 31 yards. Tackled by C.Bynum at MIN 21.
# 43                                                                                          R.Wilson pass short left complete to SEA 21. Catch made by T.Homer at SEA 21. Gain of 5 yards. Tackled by D.Hunter at SEA 32.
# 48                                                                                   K.Cousins pass short middle complete to SEA 34. Catch made by J.Jefferson at SEA 34. Gain of 28 yards. Tackled by Q.Diggs at SEA 21.
# 51                                                                                       R.Wilson pass short right complete to SEA 30. Catch made by G.Everett at SEA 30. Gain of 14 yards. Tackled by N.Vigil at SEA 40.
# 56                                                                                        K.Cousins pass short left complete to SEA 32. Catch made by K.Osborn at SEA 32. Gain of 15 yards. Tackled by U.Amadi at SEA 22.

# %%
sportradar_wr['large_yac_catch'] = False
sportradar_wr.loc[ (sportradar_wr['yards_after_catch'] >= 10) & (sportradar_wr['reception'] == 1), 'large_yac_catch'] = True

# %% [markdown]
# ### Play action catch
# - A play action play is when the quarterback takes the snap from directly "under center" (right behind the center), runs backward, and fakes a hand-off to the running back
#   - This play design fakes a run attempt, causing defenders to get "drawn up" leaving the deeper parts of the field more open for a receiver to exploit
# - Catches made from play action

# %%
sportradar_wr.loc[ (sportradar_wr['play_action'] == True) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 0   f72f3120-1f07-11ec-a67f-c75e589fa3a4            0            0       1
# 1   4c3a6ea0-1f08-11ec-a67f-c75e589fa3a4            0            0       1
# 4   86a1cc40-1f09-11ec-a67f-c75e589fa3a4            0            7       1
# 5   9e800700-1f09-11ec-a67f-c75e589fa3a4            0            7       1
# 10  e3c698a0-1f0a-11ec-b36d-a3b2acec3de6            7            7       1
# 11  424963d0-1f0b-11ec-b36d-a3b2acec3de6            7            7       1
# 16  113a9d60-1f0e-11ec-89e9-8992a3cbf855            7           17       2
# 23  0c9c7240-1f10-11ec-89e9-8992a3cbf855           14           17       2
# 32  0a490500-1f13-11ec-acc0-f76b8dd971ea           20           17       2
# 38  362af810-1f16-11ec-a9c1-1b4016cb3a46           21           17       3
# 49  53450b40-1f19-11ec-a9c1-1b4016cb3a46           24           17       4
#
#    start_play_clock_string  start_play_down  start_play_yardline  inside_20  \
# 0                    15:00                1                   25          0
# 1                    12:50                1                   45          0
# 4                     9:51                2                   37          0
# 5                     9:11                1                   43          0
# 10                    4:38                1                   38          0
# 11                    2:04                2                   33          0
# 16                   11:07                1                   15          0
# 23                    4:41                2                   28          0
# 32                   00:20                1                    3          1
# 38                   12:05                2                   48          0
# 49                   15:00                1                   21          0
#
#     goaltogo         qb_name pocket_location  hurry  blitz  knockdown  \
# 0          0  Russell Wilson      Boot Right      1      0          0
# 1          0  Russell Wilson          Middle      0      0          0
# 4          0    Kirk Cousins          Middle      0      0          0
# 5          0    Kirk Cousins      Boot Right      0      1          0
# 10         0  Russell Wilson          Middle      0      1          1
# 11         0  Russell Wilson          Middle      0      0          0
# 16         0    Kirk Cousins          Middle      0      0          0
# 23         0  Russell Wilson          Middle      0      1          0
# 32         1    Kirk Cousins          Middle      0      0          0
# 38         0    Kirk Cousins   Scramble Left      1      0          0
# 49         0    Kirk Cousins          Middle      0      0          0
#
#     players_rushed pocket_time_string         pass_route         player_name  \
# 0                4               3.13              Cross          DK Metcalf
# 1                4               3.08               Curl        Chris Carson
# 4                4               2.57  Underneath Screen  Alexander Mattison
# 5                5               3.25              Cross       Tyler Conklin
# 10               5               2.25               Post          DK Metcalf
# 11               4               2.47  Underneath Screen       Tyler Lockett
# 16               4               2.92               Curl  Alexander Mattison
# 23               5               2.46              Cross         Will Dissly
# 32               4               2.30                Out    Justin Jefferson
# 38               4               2.60               Flat       Tyler Conklin
# 49               4               3.51              Cross       Tyler Conklin
#
#     att_yards  yards  yards_after_catch  on_target_throw  firstdown  \
# 0          11     17                  6                1          1
# 1           3      5                  2                1          0
# 4          -2     20                 22                1          1
# 5          11     17                  6                1          1
# 10         12     12                  0                1          1
# 11         -7      3                 10                1          0
# 16          3      6                  3                1          0
# 23          9     39                 30                1          1
# 32          3      3                  0                1          1
# 38          1      5                  4                1          0
# 49          4      4                  0                1          0
#
#     touchdown  \
# 0         NaN
# 1         NaN
# 4         NaN
# 5         NaN
# 10        NaN
# 11        NaN
# 16        NaN
# 23        NaN
# 32          1
# 38        NaN
# 49        NaN
#
#                                                                                                                                                                                                               description
# 0                                                                                        R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
# 1                                                                                          R.Wilson pass short right complete to MIN 42. Catch made by C.Carson at MIN 42. Gain of 5 yards. Tackled by N.Vigil at MIN 40.
# 4                                                                                       K.Cousins pass short left complete to MIN 35. Catch made by A.Mattison at MIN 35. Gain of 20 yards. Tackled by J.Adams at SEA 43.
# 5                                                                                      K.Cousins pass short left complete to SEA 32. Catch made by T.Conklin at SEA 32. Gain of 17 yards. Tackled by T.Flowers at SEA 26.
# 10                                                                                   R.Wilson pass short middle complete to SEA 50. Catch made by D.Metcalf at SEA 50. Gain of 12 yards. Tackled by B.Breeland at MIN 50.
# 11  R.Wilson pass short left complete to MIN 40. Catch made by T.Lockett at MIN 40. Gain of 3 yards. Tackled by H.Smith at MIN 30. PENALTY on SEA-A.Collins, Offensive Illegal Block Above the Waist, 10 yards, accepted.
# 16                                                                                    K.Cousins pass short middle complete to MIN 18. Catch made by A.Mattison at MIN 18. Gain of 6 yards. Tackled by J.Brooks at MIN 21.
# 23                                                                        R.Wilson pass short left complete to SEA 37. Catch made by W.Dissly at SEA 37. Gain of 39 yards. Pushed out of bounds by E.Kendricks at MIN 33.
# 32                                                                               K.Cousins pass complete to SEA End Zone. Catch made by J.Jefferson at SEA End Zone. Gain of 3 yards. J.Jefferson for 3 yards, TOUCHDOWN.
# 38                                                                                        K.Cousins pass short left complete to SEA 47. Catch made by T.Conklin at SEA 47. Gain of 5 yards. Tackled by U.Amadi at SEA 43.
# 49                                                                                                  K.Cousins pass complete to SEA 17. Catch made by T.Conklin at SEA 17. Gain of 4 yards. Tackled by J.Brooks at SEA 17.

# %%
sportradar_wr['play_action_attempt'] = False
sportradar_wr.loc[ (sportradar_wr['play_action'] == True), 'play_action_attempt'] = True

# %%
sportradar_wr['play_action_catch'] = False
sportradar_wr.loc[ (sportradar_wr['play_action'] == True) & (sportradar_wr['reception'] == 1), 'play_action_catch'] = True

# %% [markdown]
# ### RPO catch
# - A run-pass option is similar to a play action design in that it is a fake designed to deceive defenses, but the quarterback has multiple options.
# - Unlike a play action concept, the QB does not turn his back toward the defense. He keeps his eyes downfield at all times. With his eyes downfield, he motions as if he's handing the ball off to the running back. He has 3 options:
#   - Complete the hand-off to the running back
#   - Keep the ball, thus faking the hand-off, and run
#   - Keep the ball, thus faking the hand-off, and pass
# - Catches made on a run-pass option

# %%
sportradar_wr.loc[ (sportradar_wr['run_pass_option'] == True) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 1   4c3a6ea0-1f08-11ec-a67f-c75e589fa3a4            0            0       1
# 32  0a490500-1f13-11ec-acc0-f76b8dd971ea           20           17       2
# 38  362af810-1f16-11ec-a9c1-1b4016cb3a46           21           17       3
#
#    start_play_clock_string  start_play_down  start_play_yardline  inside_20  \
# 1                    12:50                1                   45          0
# 32                   00:20                1                    3          1
# 38                   12:05                2                   48          0
#
#     goaltogo         qb_name pocket_location  hurry  blitz  knockdown  \
# 1          0  Russell Wilson          Middle      0      0          0
# 32         1    Kirk Cousins          Middle      0      0          0
# 38         0    Kirk Cousins   Scramble Left      1      0          0
#
#     players_rushed pocket_time_string pass_route       player_name  att_yards  \
# 1                4               3.08       Curl      Chris Carson          3
# 32               4               2.30        Out  Justin Jefferson          3
# 38               4               2.60       Flat     Tyler Conklin          1
#
#     yards  yards_after_catch  on_target_throw  firstdown  touchdown  \
# 1       5                  2                1          0        NaN
# 32      3                  0                1          1          1
# 38      5                  4                1          0        NaN
#
#                                                                                                                                  description
# 1             R.Wilson pass short right complete to MIN 42. Catch made by C.Carson at MIN 42. Gain of 5 yards. Tackled by N.Vigil at MIN 40.
# 32  K.Cousins pass complete to SEA End Zone. Catch made by J.Jefferson at SEA End Zone. Gain of 3 yards. J.Jefferson for 3 yards, TOUCHDOWN.
# 38           K.Cousins pass short left complete to SEA 47. Catch made by T.Conklin at SEA 47. Gain of 5 yards. Tackled by U.Amadi at SEA 43.

# %%
sportradar_wr['rpo_attempt'] = False
sportradar_wr.loc[ (sportradar_wr['run_pass_option'] == True), 'rpo_attempt'] = True

# %%
sportradar_wr['rpo_catch'] = False
sportradar_wr.loc[ (sportradar_wr['run_pass_option'] == True) & (sportradar_wr['reception'] == 1), 'rpo_catch'] = True

# %% [markdown]
# ### Tackle-breaker catch
# - Some receives use their size and strength to bully defenders, inviting contact that fatigues defenders over the course of the game
# - Tired defenders refer to the dilemma of tackling a physical ball carrier as a "business decision"
#   - "Expend more energy and get hurt trying to tackle him, or let him run by me?"
# - Catches after which the receiver breaks a tackle

# %%
sportradar_wr.loc[ (sportradar_wr['broken_tackles'] >= 1) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'yards_after_contact', 'broken_tackles', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 3   b0cb36b0-1f08-11ec-a67f-c75e589fa3a4            0            6       1
# 12  7b593d30-1f0b-11ec-b36d-a3b2acec3de6            7            7       1
# 17  63a98520-1f0e-11ec-89e9-8992a3cbf855            7           17       2
# 23  0c9c7240-1f10-11ec-89e9-8992a3cbf855           14           17       2
# 34  93c195e0-1f13-11ec-acc0-f76b8dd971ea           21           17       2
# 35  b904c520-1f13-11ec-acc0-f76b8dd971ea           21           17       2
# 51  132d0ba0-1f1b-11ec-a9c1-1b4016cb3a46           27           17       4
#
#    start_play_clock_string  start_play_down  start_play_yardline  inside_20  \
# 3                    10:32                2                   10          1
# 12                    1:24                2                   40          0
# 17                    9:40                1                   27          0
# 23                    4:41                2                   28          0
# 34                   00:09                1                   37          0
# 35                   00:01                1                   48          0
# 51                   13:21                2                   26          0
#
#     goaltogo         qb_name pocket_location  hurry  blitz  knockdown  \
# 3          1  Russell Wilson          Middle      0      0          0
# 12         0  Russell Wilson          Middle      0      0          0
# 17         0    Kirk Cousins          Middle      0      0          0
# 23         0  Russell Wilson          Middle      0      1          0
# 34         0  Russell Wilson          Middle      0      0          0
# 35         0  Russell Wilson          Middle      0      0          0
# 51         0  Russell Wilson          Middle      0      0          0
#
#     players_rushed pocket_time_string         pass_route         player_name  \
# 3                4               1.74                Out          DK Metcalf
# 12               4               0.73          WR Screen      Gerald Everett
# 17               4               2.24  Underneath Screen  Alexander Mattison
# 23               5               2.46              Cross         Will Dissly
# 34               4               2.69               Flat      Gerald Everett
# 35               4               2.51               Flat        Travis Homer
# 51               4               2.15               Curl      Gerald Everett
#
#     att_yards  yards  yards_after_catch  yards_after_contact  broken_tackles  \
# 3           7     10                  3                    1               1
# 12         -3      5                  8                    3               1
# 17         -3     23                 26                    6               1
# 23          9     39                 30                   18               1
# 34          0     11                 11                    4               1
# 35         -1     31                 32                   14               1
# 51          4     14                 10                    7               1
#
#     on_target_throw  firstdown  touchdown  \
# 3                 1          1          1
# 12                1          0        NaN
# 17                1          1        NaN
# 23                1          1        NaN
# 34                1          1        NaN
# 35                1          1        NaN
# 51                1          1        NaN
#
#                                                                                                                                         description
# 3               R.Wilson pass short right complete to MIN 3. Catch made by D.Metcalf at MIN 3. Gain of 10 yards. D.Metcalf for 10 yards, TOUCHDOWN.
# 12                   R.Wilson pass short left complete to MIN 43. Catch made by G.Everett at MIN 43. Gain of 5 yards. Tackled by H.Smith at MIN 35.
# 17               K.Cousins pass short right complete to MIN 24. Catch made by A.Mattison at MIN 24. Gain of 23 yards. Tackled by U.Amadi at MIN 50.
# 23  R.Wilson pass short left complete to SEA 37. Catch made by W.Dissly at SEA 37. Gain of 39 yards. Pushed out of bounds by E.Kendricks at MIN 33.
# 34            R.Wilson pass complete to SEA 37. Catch made by G.Everett at SEA 37. Gain of 11 yards. Pushed out of bounds by M.Alexander at SEA 48.
# 35                    R.Wilson pass short left complete to SEA 47. Catch made by T.Homer at SEA 47. Gain of 31 yards. Tackled by C.Bynum at MIN 21.
# 51                 R.Wilson pass short right complete to SEA 30. Catch made by G.Everett at SEA 30. Gain of 14 yards. Tackled by N.Vigil at SEA 40.

# %%
sportradar_wr['tackle_breaker_catch'] = False
sportradar_wr.loc[ (sportradar_wr['broken_tackles'] >= 1) & (sportradar_wr['reception'] == 1), 'tackle_breaker_catch'] = True

# %% [markdown]
# ### Beast catch
# - Similar in intent to the tackle-breaker catch, but focuses on receivers who gain many yards after being contacted by a defender
# - Catches that result in 10 or more yards after contact

# %%
sportradar_wr.loc[ (sportradar_wr['yards_after_contact'] >= 10) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 
                                                            'att_yards', 'yards', 'yards_after_catch', 'yards_after_contact', 'broken_tackles', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 23  0c9c7240-1f10-11ec-89e9-8992a3cbf855           14           17       2
# 35  b904c520-1f13-11ec-acc0-f76b8dd971ea           21           17       2
#
#    start_play_clock_string  start_play_down  start_play_yardline  inside_20  \
# 23                    4:41                2                   28          0
# 35                   00:01                1                   48          0
#
#     goaltogo         qb_name pocket_location  hurry  blitz  knockdown  \
# 23         0  Russell Wilson          Middle      0      1          0
# 35         0  Russell Wilson          Middle      0      0          0
#
#     players_rushed pocket_time_string pass_route   player_name  att_yards  \
# 23               5               2.46      Cross   Will Dissly          9
# 35               4               2.51       Flat  Travis Homer         -1
#
#     yards  yards_after_catch  yards_after_contact  broken_tackles  \
# 23     39                 30                   18               1
# 35     31                 32                   14               1
#
#     on_target_throw  firstdown  touchdown  \
# 23                1          1        NaN
# 35                1          1        NaN
#
#                                                                                                                                         description
# 23  R.Wilson pass short left complete to SEA 37. Catch made by W.Dissly at SEA 37. Gain of 39 yards. Pushed out of bounds by E.Kendricks at MIN 33.
# 35                    R.Wilson pass short left complete to SEA 47. Catch made by T.Homer at SEA 47. Gain of 31 yards. Tackled by C.Bynum at MIN 21.

# %%
sportradar_wr['beast_catch'] = False
sportradar_wr.loc[ (sportradar_wr['yards_after_contact'] >= 10) & (sportradar_wr['reception'] == 1), 'beast_catch'] = True

# %% [markdown]
# ### Hurry-up catch
# - Catches made on plays before which there was no huddle
# - Measures a receiver's knowledge of the playbook and what their role is without detailed explanation
# - Demonstrates receiver's chemistry with QB and whether they can be trusted to be ready at all times
# - Crucial in time-limited situations

# %%
sportradar_wr.loc[ (sportradar_wr['huddle'] == 'No Huddle') & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                            'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 'att_yards', 'yards', 'yards_after_catch', 'yards_after_contact', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 1   4c3a6ea0-1f08-11ec-a67f-c75e589fa3a4            0            0       1
# 2   8e3944c0-1f08-11ec-a67f-c75e589fa3a4            0            0       1
# 9   ca06a590-1f0a-11ec-b36d-a3b2acec3de6            7            7       1
# 15  128b2eb0-1f0d-11ec-89e9-8992a3cbf855            7           10       2
# 27  54079c20-1f12-11ec-acc0-f76b8dd971ea           14           17       2
# 38  362af810-1f16-11ec-a9c1-1b4016cb3a46           21           17       3
# 51  132d0ba0-1f1b-11ec-a9c1-1b4016cb3a46           27           17       4
# 52  2d901c80-1f1b-11ec-a9c1-1b4016cb3a46           27           17       4
# 64  6a04d980-1f20-11ec-a9c1-1b4016cb3a46           30           17       4
#
#    start_play_clock_string  start_play_down  start_play_yardline  inside_20  \
# 1                    12:50                1                   45          0
# 2                    11:24                3                   38          0
# 9                     5:14                3                   28          0
# 15                   14:09                1                   35          0
# 27                    1:31                1                   43          0
# 38                   12:05                2                   48          0
# 51                   13:21                2                   26          0
# 52                   12:53                1                   40          0
# 64                   00:19                2                    8          0
#
#     goaltogo         qb_name pocket_location  hurry  blitz  knockdown  \
# 1          0  Russell Wilson          Middle      0      0          0
# 2          0  Russell Wilson          Middle      0      0          0
# 9          0  Russell Wilson          Middle      0      1          0
# 15         0  Russell Wilson          Middle      0      0          0
# 27         0    Kirk Cousins          Middle      0      0          0
# 38         0    Kirk Cousins   Scramble Left      1      0          0
# 51         0  Russell Wilson          Middle      0      0          0
# 52         0  Russell Wilson          Middle      0      0          0
# 64         0  Russell Wilson          Middle      0      0          0
#
#     players_rushed pocket_time_string pass_route         player_name  \
# 1                4               3.08       Curl        Chris Carson
# 2                4               3.21       Post          DK Metcalf
# 9                6               1.59      Slant       Freddie Swain
# 15               4               2.58   Comeback          DK Metcalf
# 27               4               2.23       Curl  Alexander Mattison
# 38               4               2.60       Flat       Tyler Conklin
# 51               4               2.15       Curl      Gerald Everett
# 52               4               2.20       Curl       Tyler Lockett
# 64               3               2.30        Out      Gerald Everett
#
#     att_yards  yards  yards_after_catch  yards_after_contact  on_target_throw  \
# 1           3      5                  2                    0                1
# 2          11     28                 17                    2                1
# 9           8     10                  2                  NaN                1
# 15         20     21                  1                  NaN                1
# 27          3      4                  1                    0                1
# 38          1      5                  4                    2                1
# 51          4     14                 10                    7                1
# 52          6      6                  0                  NaN                1
# 64          9     17                  8                    1                1
#
#     firstdown  touchdown  \
# 1           0        NaN
# 2           1        NaN
# 9           1        NaN
# 15          1        NaN
# 27          0        NaN
# 38          0        NaN
# 51          1        NaN
# 52          0        NaN
# 64          1        NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                  description
# 1                                                                                                                                                                                                                                                                             R.Wilson pass short right complete to MIN 42. Catch made by C.Carson at MIN 42. Gain of 5 yards. Tackled by N.Vigil at MIN 40.
# 2                                                                                                                                                                                                                                                                            R.Wilson pass short left complete to MIN 27. Catch made by D.Metcalf at MIN 27. Gain of 28 yards. Tackled by H.Smith at MIN 10.
# 9                                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 36. Catch made by F.Swain at SEA 36. Gain of 10 yards. Tackled by B.Breeland at SEA 38.
# 15                                                                                                                                                                                                                                                               R.Wilson pass deep left complete to MIN 45. Catch made by D.Metcalf at MIN 45. Gain of 21 yards. Pushed out of bounds by X.Woods at MIN 44.
# 27                                                                                                                                                                                                                                                             K.Cousins pass short middle complete to SEA 40. Catch made by A.Mattison at SEA 40. Gain of 4 yards. Tackled by B.Wagner; C.Barton at SEA 39.
# 38                                                                                                                                                                                                                                                                           K.Cousins pass short left complete to SEA 47. Catch made by T.Conklin at SEA 47. Gain of 5 yards. Tackled by U.Amadi at SEA 43.
# 51                                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 30. Catch made by G.Everett at SEA 30. Gain of 14 yards. Tackled by N.Vigil at SEA 40.
# 52  R.Wilson pass complete to SEA 46. Catch made by T.Lockett at SEA 46. Gain of 6 yards. T.Lockett FUMBLES, forced by B.Breeland. Fumble RECOVERED by MIN-D.Hunter at SEA 44. Tackled by at SEA 44. The Replay Official reviewed the fumble and the play was overturned. R.Wilson pass short right complete to SEA 46. Catch made by T.Lockett at SEA 46. Gain of 6 yards. Tackled by B.Breeland at SEA 46.
# 64                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 17. Catch made by G.Everett at SEA 17. Gain of 17 yards. Pushed out of bounds by B.Breeland at SEA 25.

# %%
sportradar_wr['hurry_up_attempt'] = False
sportradar_wr.loc[ (sportradar_wr['huddle'] == 'No Huddle'), 'hurry_up_attempt'] = True

# %%
sportradar_wr['hurry_up_catch'] = False
sportradar_wr.loc[ (sportradar_wr['huddle'] == 'No Huddle') & (sportradar_wr['reception'] == 1), 'hurry_up_catch'] = True

# %% [markdown]
# ### Deep sideline catch
# - 20 or more air yards
# - Near one of the sidelines
# - Gauges receiver's ability to be a vertical threat, maintain spatial awareness, and maintain body control when attempting the catch and staying inbounds

# %%
sportradar_wr.loc[(
                    (sportradar_wr['play_direction'] == 'Right Sideline') | (sportradar_wr['play_direction'] == 'Left Sideline')
                  )
                  & (sportradar_wr['att_yards'] >= 20)
                  & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                        'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 'att_yards', 'yards', 'yards_after_catch', 'yards_after_contact', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 15  128b2eb0-1f0d-11ec-89e9-8992a3cbf855            7           10       2
#
#    start_play_clock_string  start_play_down  start_play_yardline  inside_20  \
# 15                   14:09                1                   35          0
#
#     goaltogo         qb_name pocket_location  hurry  blitz  knockdown  \
# 15         0  Russell Wilson          Middle      0      0          0
#
#     players_rushed pocket_time_string pass_route player_name  att_yards  \
# 15               4               2.58   Comeback  DK Metcalf         20
#
#     yards  yards_after_catch  yards_after_contact  on_target_throw  firstdown  \
# 15     21                  1                  NaN                1          1
#
#     touchdown  \
# 15        NaN
#
#                                                                                                                                     description
# 15  R.Wilson pass deep left complete to MIN 45. Catch made by D.Metcalf at MIN 45. Gain of 21 yards. Pushed out of bounds by X.Woods at MIN 44.

# %%
sportradar_wr['deep_sideline_attempt'] = False
sportradar_wr.loc[(
                    (sportradar_wr['play_direction'] == 'Right Sideline') | (sportradar_wr['play_direction'] == 'Left Sideline')
                  )
                  & (sportradar_wr['att_yards'] >= 20)
                  , 'deep_sideline_attempt'] = True

# %%
sportradar_wr['deep_sideline_catch'] = False
sportradar_wr.loc[(
                    (sportradar_wr['play_direction'] == 'Right Sideline') | (sportradar_wr['play_direction'] == 'Left Sideline')
                  )
                  & (sportradar_wr['att_yards'] >= 20)
                  & (sportradar_wr['reception'] == 1), 'deep_sideline_catch'] = True

# %% [markdown]
# ### DPI drawn
# - Receivers who frequently draw defensive pass interference calls worry defenders who don't want to surrender a big yardage gain

# %%
sportradar_wr.loc[sportradar_wr['defender_name'].notnull()
                 ][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                        'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 'att_yards', 'yards', 'yards_after_catch', 'yards_after_contact', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
# Empty DataFrame
# Columns: [play_id, home_points, away_points, period, start_play_clock_string, start_play_down, start_play_yardline, inside_20, goaltogo, qb_name, pocket_location, hurry, blitz, knockdown, players_rushed, pocket_time_string, pass_route, player_name, att_yards, yards, yards_after_catch, yards_after_contact, on_target_throw, firstdown, touchdown, description]
# Index: []

# %%
sportradar_wr['dpi_drawn'] = False
sportradar_wr.loc[sportradar_wr['defender_name'].notnull(), 'dpi_drawn'] = True

# %% [markdown]
# ### Possession-saver catch
# - A "possession receiver" is usually a tall, strong receiver who lacks speed, but can reliably make contested catches for short to intermediate yardage at the line to gain
# - By catching passes intended for them at the line to gain, they sustain drives

# %%
sportradar_wr.loc[(sportradar_wr['att_yards'] >= sportradar_wr['start_play_yfd']) & (sportradar_wr['reception'] == 1)][['play_id', 'home_points', 'away_points', 'period', 'start_play_clock_string', 'start_play_down', 'start_play_yfd', 'start_play_yardline', 'inside_20', 'goaltogo', 'qb_name', 'pocket_location', 
                                                        'hurry', 'blitz', 'knockdown', 'players_rushed', 'pocket_time_string', 'pass_route', 'player_name', 'att_yards', 'yards', 'yards_after_catch', 'yards_after_contact', 'on_target_throw', 'firstdown', 'touchdown', 'description']]
# Out:
#                                  play_id  home_points  away_points  period  \
# 0   f72f3120-1f07-11ec-a67f-c75e589fa3a4            0            0       1
# 2   8e3944c0-1f08-11ec-a67f-c75e589fa3a4            0            0       1
# 5   9e800700-1f09-11ec-a67f-c75e589fa3a4            0            7       1
# 7   dabe15e0-1f09-11ec-b36d-a3b2acec3de6            0            7       1
# 9   ca06a590-1f0a-11ec-b36d-a3b2acec3de6            7            7       1
# 10  e3c698a0-1f0a-11ec-b36d-a3b2acec3de6            7            7       1
# 15  128b2eb0-1f0d-11ec-89e9-8992a3cbf855            7           10       2
# 18  b25ceb80-1f0e-11ec-89e9-8992a3cbf855            7           17       2
# 21  19c341c0-1f0f-11ec-89e9-8992a3cbf855           13           17       2
# 23  0c9c7240-1f10-11ec-89e9-8992a3cbf855           14           17       2
# 28  7b2b7240-1f12-11ec-acc0-f76b8dd971ea           14           17       2
# 30  c448f1f0-1f12-11ec-acc0-f76b8dd971ea           14           17       2
# 32  0a490500-1f13-11ec-acc0-f76b8dd971ea           20           17       2
# 40  8e79a0c0-1f16-11ec-a9c1-1b4016cb3a46           21           17       3
# 45  af0f89b0-1f18-11ec-a9c1-1b4016cb3a46           24           17       3
# 47  f896a0a0-1f18-11ec-a9c1-1b4016cb3a46           24           17       3
# 48  2c26da70-1f19-11ec-a9c1-1b4016cb3a46           24           17       3
# 55  94860840-1f1c-11ec-a9c1-1b4016cb3a46           27           17       4
# 56  e07f57b0-1f1c-11ec-a9c1-1b4016cb3a46           27           17       4
# 58  25f47360-1f1e-11ec-a9c1-1b4016cb3a46           30           17       4
# 62  4b97a780-1f1f-11ec-a9c1-1b4016cb3a46           30           17       4
# 64  6a04d980-1f20-11ec-a9c1-1b4016cb3a46           30           17       4
#
#    start_play_clock_string  start_play_down  start_play_yfd  \
# 0                    15:00                1              10
# 2                    11:24                3               3
# 5                     9:11                1              10
# 7                     7:54                2               2
# 9                     5:14                3               7
# 10                    4:38                1              10
# 15                   14:09                1              10
# 18                    7:25                1              10
# 21                    5:32                3              13
# 23                    4:41                2               3
# 28                   00:57                3               4
# 30                   00:29                3               8
# 32                   00:20                1               3
# 40                   10:03                3               4
# 45                    3:08                2              11
# 47                    1:40                3               5
# 48                   00:21                2              10
# 55                   10:24                2               1
# 56                    8:21                3               5
# 58                    4:31                1              10
# 62                    2:08                3               8
# 64                   00:19                2               3
#
#     start_play_yardline  inside_20  goaltogo         qb_name pocket_location  \
# 0                    25          0         0  Russell Wilson      Boot Right
# 2                    38          0         0  Russell Wilson          Middle
# 5                    43          0         0    Kirk Cousins      Boot Right
# 7                    18          1         0    Kirk Cousins          Middle
# 9                    28          0         0  Russell Wilson          Middle
# 10                   38          0         0  Russell Wilson          Middle
# 15                   35          0         0  Russell Wilson          Middle
# 18                   38          0         0    Kirk Cousins          Middle
# 21                   15          1         0    Kirk Cousins          Middle
# 23                   28          0         0  Russell Wilson          Middle
# 28                   37          0         0    Kirk Cousins          Middle
# 30                   28          0         0    Kirk Cousins          Middle
# 32                    3          1         1    Kirk Cousins          Middle
# 40                   34          0         0    Kirk Cousins          Middle
# 45                   14          0         0    Kirk Cousins          Middle
# 47                   40          0         0    Kirk Cousins          Middle
# 48                   49          0         0    Kirk Cousins          Middle
# 55                   44          0         0    Kirk Cousins          Middle
# 56                   37          0         0    Kirk Cousins          Middle
# 58                   25          0         0  Russell Wilson          Middle
# 62                   45          0         0    Kirk Cousins          Middle
# 64                    8          0         0  Russell Wilson          Middle
#
#     hurry  blitz  knockdown  players_rushed pocket_time_string pass_route  \
# 0       1      0          0               4               3.13      Cross
# 2       0      0          0               4               3.21       Post
# 5       0      1          0               5               3.25      Cross
# 7       0      1          0               5               1.78        Out
# 9       0      1          0               6               1.59      Slant
# 10      0      1          1               5               2.25       Post
# 15      0      0          0               4               2.58   Comeback
# 18      0      0          0               4               2.56       Post
# 21      0      1          0               5               2.36       Post
# 23      0      1          0               5               2.46      Cross
# 28      0      1          0               5               2.25       Curl
# 30      0      0          0               4               1.78      Slant
# 32      0      0          0               4               2.30        Out
# 40      0      0          0               4               1.89        Out
# 45      0      0          0               4               3.10       Post
# 47      0      0          0               4               1.87        Out
# 48      0      1          0               5               2.51       Post
# 55      0      1          0               5               2.36      Cross
# 56      0      1          1               6               1.11      Cross
# 58      0      0          0               4               2.16       Post
# 62      0      0          0               4               2.16        Out
# 64      0      0          0               3               2.30        Out
#
#          player_name  att_yards  yards  yards_after_catch  \
# 0         DK Metcalf         11     17                  6
# 2         DK Metcalf         11     28                 17
# 5      Tyler Conklin         11     17                  6
# 7   Justin Jefferson          5     10                  5
# 9      Freddie Swain          8     10                  2
# 10        DK Metcalf         12     12                  0
# 15        DK Metcalf         20     21                  1
# 18  Justin Jefferson         13     26                 13
# 21      Adam Thielen         15     15                  0
# 23       Will Dissly          9     39                 30
# 28      Adam Thielen          7      7                  0
# 30  Justin Jefferson          9      9                  0
# 32  Justin Jefferson          3      3                  0
# 40  Justin Jefferson          8      8                  0
# 45      Adam Thielen         19     21                  2
# 47       K.J. Osborn          6     11                  5
# 48  Justin Jefferson         15     28                 13
# 55     Tyler Conklin          7     14                  7
# 56       K.J. Osborn          5     15                 10
# 58        DK Metcalf         15     19                  4
# 62  Justin Jefferson         11     11                  0
# 64    Gerald Everett          9     17                  8
#
#     yards_after_contact  on_target_throw  firstdown  touchdown  \
# 0                   NaN                1          1        NaN
# 2                     2                1          1        NaN
# 5                     1                1          1        NaN
# 7                     3                1          1        NaN
# 9                   NaN                1          1        NaN
# 10                  NaN                1          1        NaN
# 15                  NaN                1          1        NaN
# 18                    3                1          1        NaN
# 21                  NaN                1          1          1
# 23                   18                1          1        NaN
# 28                  NaN                1          1        NaN
# 30                  NaN                1          1        NaN
# 32                  NaN                1          1          1
# 40                  NaN                1          1        NaN
# 45                    0                1          1        NaN
# 47                    3                1          1        NaN
# 48                    3                1          1        NaN
# 55                    2                1          1        NaN
# 56                    8                1          1        NaN
# 58                  NaN                1          1        NaN
# 62                  NaN                1          1        NaN
# 64                    1                1          1        NaN
#
#                                                                                                                                                 description
# 0                          R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
# 2                           R.Wilson pass short left complete to MIN 27. Catch made by D.Metcalf at MIN 27. Gain of 28 yards. Tackled by H.Smith at MIN 10.
# 5                        K.Cousins pass short left complete to SEA 32. Catch made by T.Conklin at SEA 32. Gain of 17 yards. Tackled by T.Flowers at SEA 26.
# 7                       K.Cousins pass short left complete to SEA 13. Catch made by J.Jefferson at SEA 13. Gain of 10 yards. Tackled by T.Flowers at SEA 8.
# 9                         R.Wilson pass short right complete to SEA 36. Catch made by F.Swain at SEA 36. Gain of 10 yards. Tackled by B.Breeland at SEA 38.
# 10                     R.Wilson pass short middle complete to SEA 50. Catch made by D.Metcalf at SEA 50. Gain of 12 yards. Tackled by B.Breeland at MIN 50.
# 15              R.Wilson pass deep left complete to MIN 45. Catch made by D.Metcalf at MIN 45. Gain of 21 yards. Pushed out of bounds by X.Woods at MIN 44.
# 18                      K.Cousins pass short middle complete to SEA 25. Catch made by J.Jefferson at SEA 25. Gain of 26 yards. Tackled by D.Reed at SEA 12.
# 21                   K.Cousins pass complete to SEA End Zone. Catch made by A.Thielen at SEA End Zone. Gain of 15 yards. A.Thielen for 15 yards, TOUCHDOWN.
# 23          R.Wilson pass short left complete to SEA 37. Catch made by W.Dissly at SEA 37. Gain of 39 yards. Pushed out of bounds by E.Kendricks at MIN 33.
# 28                                     K.Cousins pass complete to SEA 30. Catch made by A.Thielen at SEA 30. Gain of 7 yards. Tackled by U.Amadi at SEA 30.
# 30                      K.Cousins pass short middle complete to SEA 19. Catch made by J.Jefferson at SEA 19. Gain of 9 yards. Tackled by U.Amadi at SEA 19.
# 32                 K.Cousins pass complete to SEA End Zone. Catch made by J.Jefferson at SEA End Zone. Gain of 3 yards. J.Jefferson for 3 yards, TOUCHDOWN.
# 40                                              K.Cousins pass complete to SEA 26. Catch made by J.Jefferson at SEA 26. Gain of 8 yards. ran out of bounds.
# 45                                    K.Cousins pass complete to MIN 33. Catch made by A.Thielen at MIN 33. Gain of 21 yards. Tackled by Q.Diggs at MIN 35.
# 47  K.Cousins pass short right complete to MIN 46. Catch made by K.Osborn at MIN 46. Gain of 11 yards. Pushed out of bounds by Q.Diggs, J.Brooks at SEA 49.
# 48                     K.Cousins pass short middle complete to SEA 34. Catch made by J.Jefferson at SEA 34. Gain of 28 yards. Tackled by Q.Diggs at SEA 21.
# 55           K.Cousins pass short right complete to SEA 49. Catch made by T.Conklin at SEA 49. Gain of 14 yards. Pushed out of bounds by J.Adams at SEA 42.
# 56                          K.Cousins pass short left complete to SEA 32. Catch made by K.Osborn at SEA 32. Gain of 15 yards. Tackled by U.Amadi at SEA 22.
# 58                          R.Wilson pass short left complete to SEA 40. Catch made by D.Metcalf at SEA 40. Gain of 19 yards. Tackled by H.Smith at SEA 44.
# 62                     K.Cousins pass short right complete to SEA 44. Catch made by J.Jefferson at SEA 44. Gain of 11 yards. J.Jefferson ran out of bounds.
# 64         R.Wilson pass short right complete to SEA 17. Catch made by G.Everett at SEA 17. Gain of 17 yards. Pushed out of bounds by B.Breeland at SEA 25.

# %%
sportradar_wr['possession_saver_attempt'] = False
sportradar_wr.loc[(sportradar_wr['att_yards'] >= sportradar_wr['start_play_yfd']), 'possession_saver_attempt'] = True

sportradar_wr['possession_saver_catch'] = False
sportradar_wr.loc[(sportradar_wr['att_yards'] >= sportradar_wr['start_play_yfd']) & (sportradar_wr['reception'] == 1), 'possession_saver_catch'] = True

# %% [markdown]
# # ADDITIONAL EXPLORATION
# - Some more exploration of the data

# %%
sportradar_wr['play_id'].nunique(), sportradar_wr.shape
# Original shape was 67 x 124. Corrected it by adding the Out and Curl route attempt and catch columns. Now 67 x 128.
# Out:
# (67, (67, 128))

# %% [markdown]
# - Checking to see if all touchdown plays have "end zone" in the description.
# - More than 2 TDs were scored in this game, so that appears not to be the case.

# %%
sportradar_wr[sportradar_wr['description'].str.contains('end zone', case = False, na = False)][['period', 'start_play_clock_string', 'start_play_yfd', 'start_play_yardline', 'start_play_field_side', 'player_name', 'att_yards', 'description']]
# Out:
#     period start_play_clock_string  start_play_yfd  start_play_yardline  \
# 21       2                    5:32              13                   15
# 32       2                   00:20               3                    3
#
#    start_play_field_side       player_name  att_yards  \
# 21                   SEA      Adam Thielen         15
# 32                   SEA  Justin Jefferson          3
#
#                                                                                                                                  description
# 21    K.Cousins pass complete to SEA End Zone. Catch made by A.Thielen at SEA End Zone. Gain of 15 yards. A.Thielen for 15 yards, TOUCHDOWN.
# 32  K.Cousins pass complete to SEA End Zone. Catch made by J.Jefferson at SEA End Zone. Gain of 3 yards. J.Jefferson for 3 yards, TOUCHDOWN.

# %% [markdown]
# - Checking to see how the yardline adjustment looks.
# - It appears to be working properly.
#   - In row 9, the play ends with Seahawks, who are on offense, endin with the ball on their own 38
#     - 38 is 12 yards away from midfield. Past midfield, Seattle has another 50 yards of opponent territory to cover before reaching the end zone.
#     - The effective yardline is 12 + 50 = 62.

# %%
sportradar_wr[(sportradar_wr['team_alias'] == 'SEA') & (sportradar_wr['start_play_field_side'] == 'SEA')][['period', 'start_play_clock_string', 'start_play_yfd', 'start_play_yardline', 'effective_start_play_yardline', 'yards', 'end_play_yardline', 'effective_end_play_yardline', 
                                                                                                           'start_play_field_side', 'player_name', 'att_yards', 'description']]
# Out:
#     period start_play_clock_string  start_play_yfd  start_play_yardline  \
# 0        1                   15:00              10                   25
# 9        1                    5:14               7                   28
# 10       1                    4:38              10                   38
# 15       2                   14:09              10                   35
# 22       2                    5:23              10                   21
# 23       2                    4:41               3                   28
# 33       2                   00:16              10                   25
# 34       2                   00:09              10                   37
# 35       2                   00:01              10                   48
# 43       3                    4:38              19                   27
# 51       4                   13:21               9                   26
# 52       4                   12:53              10                   40
# 53       4                   12:33               4                   46
# 54       4                   11:52               7                   43
# 58       4                    4:31              10                   25
# 59       4                    4:12              10                   44
# 63       4                   00:23              10                    1
# 64       4                   00:19               3                    8
# 65       4                   00:13              10                   25
# 66       4                   00:09              10                   25
#
#     effective_start_play_yardline  yards  end_play_yardline  \
# 0                              75     17                 42
# 9                              72     10                 38
# 10                             62     12                 50
# 15                             65     21                 44
# 22                             79      7                 28
# 23                             72     39                 33
# 33                             75     12                 37
# 34                             63     11                 48
# 35                             52     31                 21
# 43                             73      5                 32
# 51                             74     14                 40
# 52                             60      6                 46
# 53                             54     -3                 43
# 54                             57    NaN                 43
# 58                             75     19                 44
# 59                             56    NaN                 41
# 63                             99      7                  8
# 64                             92     17                 25
# 65                             75    NaN                 25
# 66                             75     15                 40
#
#     effective_end_play_yardline start_play_field_side     player_name  \
# 0                            58                   SEA      DK Metcalf
# 9                            62                   SEA   Freddie Swain
# 10                           50                   SEA      DK Metcalf
# 15                           44                   SEA      DK Metcalf
# 22                           72                   SEA      Penny Hart
# 23                           33                   SEA     Will Dissly
# 33                           63                   SEA    Travis Homer
# 34                           52                   SEA  Gerald Everett
# 35                           21                   SEA    Travis Homer
# 43                           68                   SEA    Travis Homer
# 51                           60                   SEA  Gerald Everett
# 52                           54                   SEA   Tyler Lockett
# 53                           57                   SEA    Chris Carson
# 54                           57                   SEA   Freddie Swain
# 58                           56                   SEA      DK Metcalf
# 59                           41                   SEA   Tyler Lockett
# 63                           92                   SEA  Gerald Everett
# 64                           75                   SEA  Gerald Everett
# 65                           75                   SEA      DK Metcalf
# 66                           60                   SEA   Tyler Lockett
#
#     att_yards  \
# 0          11
# 9           8
# 10         12
# 15         20
# 22         -4
# 23          9
# 33          5
# 34          0
# 35         -1
# 43         -6
# 51          4
# 52          6
# 53         -8
# 54         12
# 58         15
# 59          0
# 63          7
# 64          9
# 65          6
# 66          7
#
#                                                                                                                                                                                                                                                                                                                                                                                                  description
# 0                                                                                                                                                                                                                                                                           R.Wilson pass short right complete to SEA 36. Catch made by D.Metcalf at SEA 36. Gain of 17 yards. Tackled by H.Smith at SEA 42.
# 9                                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 36. Catch made by F.Swain at SEA 36. Gain of 10 yards. Tackled by B.Breeland at SEA 38.
# 10                                                                                                                                                                                                                                                                      R.Wilson pass short middle complete to SEA 50. Catch made by D.Metcalf at SEA 50. Gain of 12 yards. Tackled by B.Breeland at MIN 50.
# 15                                                                                                                                                                                                                                                               R.Wilson pass deep left complete to MIN 45. Catch made by D.Metcalf at MIN 45. Gain of 21 yards. Pushed out of bounds by X.Woods at MIN 44.
# 22                                                                                                                                                                                                                                                                             R.Wilson pass short middle complete to SEA 17. Catch made by P.Hart at SEA 17. Gain of 7 yards. Tackled by H.Smith at SEA 28.
# 23                                                                                                                                                                                                                                                           R.Wilson pass short left complete to SEA 37. Catch made by W.Dissly at SEA 37. Gain of 39 yards. Pushed out of bounds by E.Kendricks at MIN 33.
# 33                                                                                                                                                                                                                                                              R.Wilson pass short middle complete to SEA 30. Catch made by T.Homer at SEA 30. Gain of 12 yards. Tackled by N.Vigil, E.Kendricks at SEA 37.
# 34                                                                                                                                                                                                                                                                     R.Wilson pass complete to SEA 37. Catch made by G.Everett at SEA 37. Gain of 11 yards. Pushed out of bounds by M.Alexander at SEA 48.
# 35                                                                                                                                                                                                                                                                             R.Wilson pass short left complete to SEA 47. Catch made by T.Homer at SEA 47. Gain of 31 yards. Tackled by C.Bynum at MIN 21.
# 43                                                                                                                                                                                                                                                                             R.Wilson pass short left complete to SEA 21. Catch made by T.Homer at SEA 21. Gain of 5 yards. Tackled by D.Hunter at SEA 32.
# 51                                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 30. Catch made by G.Everett at SEA 30. Gain of 14 yards. Tackled by N.Vigil at SEA 40.
# 52  R.Wilson pass complete to SEA 46. Catch made by T.Lockett at SEA 46. Gain of 6 yards. T.Lockett FUMBLES, forced by B.Breeland. Fumble RECOVERED by MIN-D.Hunter at SEA 44. Tackled by at SEA 44. The Replay Official reviewed the fumble and the play was overturned. R.Wilson pass short right complete to SEA 46. Catch made by T.Lockett at SEA 46. Gain of 6 yards. Tackled by B.Breeland at SEA 46.
# 53                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 38. Catch made by C.Carson at SEA 38. Gain of -3 yards. Pushed out of bounds by E.Kendricks at SEA 43.
# 54                                                                                                                                                                                                                                                                                                                  R.Wilson steps back to pass. R.Wilson pass incomplete short middle intended for F.Swain.
# 58                                                                                                                                                                                                                                                                           R.Wilson pass short left complete to SEA 40. Catch made by D.Metcalf at SEA 40. Gain of 19 yards. Tackled by H.Smith at SEA 44.
# 59                                                                                                                                                                                                                                     R.Wilson steps back to pass. R.Wilson pass incomplete short right intended for T.Lockett. PENALTY on MIN-E.Griffen, Roughing the Passer, 15 yards, accepted. No Play.
# 63                                                                                                                                                                                                                                                                              R.Wilson pass short right complete to SEA 8. Catch made by G.Everett at SEA 8. Gain of 7 yards. G.Everett ran out of bounds.
# 64                                                                                                                                                                                                                                                          R.Wilson pass short right complete to SEA 17. Catch made by G.Everett at SEA 17. Gain of 17 yards. Pushed out of bounds by B.Breeland at SEA 25.
# 65                                                                                                                                                                                                                                                                                                                  R.Wilson steps back to pass. R.Wilson pass incomplete short left intended for D.Metcalf.
# 66                                                                                                                                                                                                                                                              R.Wilson pass short right complete to SEA 32. Catch made by T.Lockett at SEA 32. Gain of 15 yards. Tackled by B.Breeland, N.Vigil at SEA 40.

# %%
sportradar_wr['play_direction'].unique()
# Out:
# array(['Right', 'Left', 'Right Sideline', 'Left Sideline', 'Middle', nan],
#       dtype=object)

# %%
sportradar_wr['qb_at_snap'].unique()
# Out:
# array(['Under Center', 'Shotgun', nan], dtype=object)

# %%
sportradar_wr['pass_route'].unique()
# Out:
# array(['Cross', 'Curl', 'Post', 'Out', 'Underneath Screen', 'Flat',
#        'Slant', 'WR Screen', 'Comeback', 'Go', 'In', nan], dtype=object)

# %%
sportradar_wr.columns
# Out:
# Index(['game_id', 'season_year', 'season_type', 'week', 'home_alias',
#        'home_sr_id', 'away_alias', 'away_sr_id', 'temp', 'humidity',
#        'wind_speed', 'venue_surface', 'venue_roof_type', 'period', 'event_id',
#        'team_sequence', 'play_id', 'home_points', 'away_points', 'description',
#        'start_play_clock', 'start_play_clock_string', 'start_play_down',
#        'start_play_yfd', 'start_play_yardline',
#        'effective_start_play_yardline', 'start_play_field_side', 'inside_20',
#        'goaltogo', 'end_play_clock', 'end_play_clock_string', 'end_play_down',
#        'end_play_yfd', 'end_play_yardline', 'effective_end_play_yardline',
#        'end_play_field_side', 'firstdown', 'scoring_play', 'players_rushed',
#        'men_in_box', 'huddle', 'hash_mark', 'qb_at_snap', 'left_tightends',
#        'right_tightends', 'qb_name', 'pocket_location', 'play_direction',
#        'screen_pass', 'play_action', 'run_pass_option', 'pass_route',
#        'fake_punt', 'fake_field_goal', 'defender_name', 'player_name',
#        'player_jersey', 'player_position', 'player_sr_id', 'team_alias',
#        'team_sr_id', 'blitz', 'hurry', 'knockdown', 'pocket_time',
#        'pocket_time_string', 'on_target_throw', 'batted_pass',
#        'incompletion_type', 'target', 'reception', 'yards', 'att_yards',
#        'yards_after_catch', 'yards_after_contact', 'broken_tackles', 'dropped',
#        'catchable', 'touchdown', 'difficult_attempt', 'difficult_catch',
#        'weather_attempt', 'weather_catch', 'qb_bf_attempt', 'qb_bf_catch',
#        'clutch_catch', 'conversion_catch', 'redzone_catch', 'in_attempt',
#        'slant_attempt', 'corner_attempt', 'flat_attempt', 'curl_attempt',
#        'wr_screen_attempt', 'out_attempt', 'go_attempt', 'cross_attempt',
#        'post_attempt', 'comeback_attempt', 'underneath_screen_attempt',
#        'in_catch', 'slant_catch', 'corner_catch', 'flat_catch', 'curl_catch',
#        'wr_screen_catch', 'out_catch', 'go_catch', 'cross_catch', 'post_catch',
#        'comeback_catch', 'underneath_screen_catch', 'deep_attempt',
#        'deep_catch', 'large_yac_catch', 'play_action_attempt',
#        'play_action_catch', 'rpo_attempt', 'rpo_catch', 'tackle_breaker_catch',
#        'beast_catch', 'hurry_up_attempt', 'hurry_up_catch',
#        'deep_sideline_attempt', 'deep_sideline_catch', 'dpi_drawn',
#        'possession_saver_attempt', 'possession_saver_catch'],
#       dtype='object')

# %% [markdown]
# # CONCLUSION
# - We can now apply this series of cleaning and feature engineering steps to every game in the 2022 season.
